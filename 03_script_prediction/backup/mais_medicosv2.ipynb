# %% [markdown]
# # Predictive analysis of Mais Médicos retention

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
from pycaret.classification import *
import shap

# %% [markdown]
# Reading dataframe

# %%
df_original = pd.read_excel("base_tratadav2.xlsx")
df_original.head()
# Out:
#     ano   competen  codufmun  ibge_aloc municipio_destino uf_destino     cnes  \
# 0  2019 2019-06-01    240580     240580       JOAO CAMARA         RN  2474689
# 1  2019 2019-06-01    220020     220020       AGUA BRANCA         PI  2368455
# 2  2019 2019-10-01    520310     520310            BALIZA         GO  2500132
# 3  2019 2019-09-01    290195     290195          APUAREMA         BA  7050062
# 4  2019 2019-09-01    130340     130340         PARINTINS         AM  9640347
#
#    tp_unid                                     fantasia  \
# 0        2                          PSF 2 SAO FRANCISCO
# 1        2  POSTO DE SAUDE OTACIANA MARIA DO NASCIMENTO
# 2        2                     ESF MARLENE NERY RIBEIRO
# 3        2                                 USF OTACIANO
# 4        2   UNIDADE BASICA DE SAUDE DO BAIRRO DA UNIAO
#
#                          nomeprof  ...  vagas_medicina_milhab orcamento_saude  \
# 0  MARLIO EVERTON MACEDO DE PAIVA  ...                    0.0          617.07
# 1            ANA MARIA REGO COSTA  ...                    0.0          997.20
# 2            RUBENS NOVAIS XAVIER  ...                    0.0          785.85
# 3          HERALDO ROCHA DE JESUS  ...                    0.0          578.33
# 4              KEDMA TAVARES BUAS  ...                    0.0          469.07
#
#   esgotamento_sanitario taxa_homicidio ideb_anosiniciais ideb_anosfinais  \
# 0                 35.43         51.495               4.2             3.0
# 1                 35.77         11.487               6.0             4.9
# 2                  0.00         38.926               6.2             4.9
# 3                  0.00         40.928               4.2             3.4
# 4                  0.00         21.002               5.0             4.4
#
#    investimento_infraestrutura equipamentos_esportivos equpamentos_culturais  \
# 0                     1076.540                   2.878                 5.756
# 1                     3447.022                  46.112                34.584
# 2                     2781.115                  20.032                20.032
# 3                     4027.146                  13.587                27.174
# 4                     3341.453                   1.767                 1.767
#
#    distancia_capital
# 0               81.0
# 1              101.0
# 2              420.0
# 3              343.0
# 4              369.0
#
# [5 rows x 52 columns]

# %% [markdown]
# Selecting only features which will be useful

# %%
df_original.columns
# Out:
# Index(['ano', 'competen', 'codufmun', 'ibge_aloc', 'municipio_destino',
#        'uf_destino', 'cnes', 'tp_unid', 'fantasia', 'nomeprof', 'cns_prof',
#        'cpf_prof', 'data_nascimento', 'data_formacao', 'participou_pmmb',
#        'sexo', 'ch_total', 'alocacao', 'atuacao_previa_no_municipio',
#        'anos_atuacao_mesmo_municipio', 'media_vinculos',
#        'meses_no_local_alocado', 'churn', 'uf_final', 'idade_em_anos',
#        'Prorrogado', 'anos_formacao', 'leitos_hospitalar_municipal_estadual',
#        'leitos_hospitalares_cirurgico_clinico_complementar',
#        'leitos_instalacao_fisica_urgencia',
#        'leitos_instalacao_fisica_ambulatorial',
#        'leitos_instalacao_fisical_cirurgico',
#        'leitos_instalacao_fisica_obstetrico', 'enfermeiro', 'tec_aux_enf',
#        'agente_saude', 'dentista', 'populacao', 'porte', 'pib_percapita',
#        'tx_pop_ocupada', 'cobertura_saude', 'vagas_medicina_milhab',
#        'orcamento_saude', 'esgotamento_sanitario', 'taxa_homicidio',
#        'ideb_anosiniciais', 'ideb_anosfinais', 'investimento_infraestrutura',
#        'equipamentos_esportivos', 'equpamentos_culturais',
#        'distancia_capital'],
#       dtype='object')

# %%
df_original.isna().sum()
# Out:
# ano                                                     0
# competen                                                0
# codufmun                                                0
# ibge_aloc                                               0
# municipio_destino                                       0
# uf_destino                                              0
# cnes                                                    0
# tp_unid                                                 0
# fantasia                                                0
# nomeprof                                                0
# cns_prof                                                0
# cpf_prof                                                0
# data_nascimento                                         0
# data_formacao                                           0
# participou_pmmb                                       349
# sexo                                                    0
# ch_total                                                0
# alocacao                                                0
# atuacao_previa_no_municipio                             0
# anos_atuacao_mesmo_municipio                            0
# media_vinculos                                          0
# meses_no_local_alocado                                  0
# churn                                                   0
# uf_final                                                0
# idade_em_anos                                           0
# Prorrogado                                              0
# anos_formacao                                           0
# leitos_hospitalar_municipal_estadual                   11
# leitos_hospitalares_cirurgico_clinico_complementar     11
# leitos_instalacao_fisica_urgencia                      11
# leitos_instalacao_fisica_ambulatorial                  11
# leitos_instalacao_fisical_cirurgico                    11
# leitos_instalacao_fisica_obstetrico                    11
# enfermeiro                                              4
# tec_aux_enf                                             4
# agente_saude                                            4
# dentista                                                4
# populacao                                               0
# porte                                                   0
# pib_percapita                                           0
# tx_pop_ocupada                                          0
# cobertura_saude                                         0
# vagas_medicina_milhab                                   0
# orcamento_saude                                         0
# esgotamento_sanitario                                   0
# taxa_homicidio                                          0
# ideb_anosiniciais                                      26
# ideb_anosfinais                                       304
# investimento_infraestrutura                             0
# equipamentos_esportivos                                 0
# equpamentos_culturais                                   0
# distancia_capital                                       0
# dtype: int64

# %%
df_churn = df_original.loc[:,('uf_destino',
                        'sexo',
                         'atuacao_previa_no_municipio',
                         'anos_atuacao_mesmo_municipio', 
                         'media_vinculos', 
                         'idade_em_anos',
                         'anos_formacao',
                         'leitos_instalacao_fisica_urgencia',
                        'agente_saude', 
                        'dentista',
                        'enfermeiro', 
                        'tec_aux_enf', 
                        'porte', 
                        'pib_percapita',
                        'tx_pop_ocupada', 
                        'cobertura_saude', 
                        'vagas_medicina_milhab',
                        'orcamento_saude', 
                        'esgotamento_sanitario', 
                        'taxa_homicidio',
                        'ideb_anosiniciais',
                        'ideb_anosfinais',
                        'investimento_infraestrutura',
                        'equipamentos_esportivos', 
                        'equpamentos_culturais',
                        'churn',
                        'distancia_capital')]

df_churn.head()
# Out:
#   uf_destino    sexo atuacao_previa_no_municipio  \
# 0         RN    Male                         Não
# 1         PI  Female                         Não
# 2         GO    Male                         Não
# 3         BA    Male                         Não
# 4         AM  Female                         Não
#
#    anos_atuacao_mesmo_municipio  media_vinculos  idade_em_anos  anos_formacao  \
# 0                           0.0        1.000000      54.094456       0.084873
# 1                           0.0        1.000000      44.654346       0.084873
# 2                           0.0        1.290323      48.147844       1.333333
# 3                           0.0        1.000000      48.533881       0.917180
# 4                           0.0        1.222222      44.060233       0.999316
#
#    leitos_instalacao_fisica_urgencia  agente_saude  dentista  ...  \
# 0                                7.0      5.166667  1.000000  ...
# 1                                4.0      6.166667  1.000000  ...
# 2                                8.0     10.333333  0.833333  ...
# 3                                5.0      8.333333  1.000000  ...
# 4                               10.0     15.166667  2.000000  ...
#
#    orcamento_saude  esgotamento_sanitario taxa_homicidio  ideb_anosiniciais  \
# 0           617.07                  35.43         51.495                4.2
# 1           997.20                  35.77         11.487                6.0
# 2           785.85                   0.00         38.926                6.2
# 3           578.33                   0.00         40.928                4.2
# 4           469.07                   0.00         21.002                5.0
#
#    ideb_anosfinais  investimento_infraestrutura  equipamentos_esportivos  \
# 0              3.0                     1076.540                    2.878
# 1              4.9                     3447.022                   46.112
# 2              4.9                     2781.115                   20.032
# 3              3.4                     4027.146                   13.587
# 4              4.4                     3341.453                    1.767
#
#    equpamentos_culturais      churn  distancia_capital
# 0                  5.756     migrou               81.0
# 1                 34.584  permanece              101.0
# 2                 20.032     migrou              420.0
# 3                 27.174     migrou              343.0
# 4                  1.767     migrou              369.0
#
# [5 rows x 27 columns]

# %%
#Codificando a variavel churn
df_churn['churn'] = df_churn['churn'].map({'migrou': 1, 'permanece': 0})

df_churn.head()
# Out:
#   uf_destino    sexo atuacao_previa_no_municipio  \
# 0         RN    Male                         Não
# 1         PI  Female                         Não
# 2         GO    Male                         Não
# 3         BA    Male                         Não
# 4         AM  Female                         Não
#
#    anos_atuacao_mesmo_municipio  media_vinculos  idade_em_anos  anos_formacao  \
# 0                           0.0        1.000000      54.094456       0.084873
# 1                           0.0        1.000000      44.654346       0.084873
# 2                           0.0        1.290323      48.147844       1.333333
# 3                           0.0        1.000000      48.533881       0.917180
# 4                           0.0        1.222222      44.060233       0.999316
#
#    leitos_instalacao_fisica_urgencia  agente_saude  dentista  ...  \
# 0                                7.0      5.166667  1.000000  ...
# 1                                4.0      6.166667  1.000000  ...
# 2                                8.0     10.333333  0.833333  ...
# 3                                5.0      8.333333  1.000000  ...
# 4                               10.0     15.166667  2.000000  ...
#
#    orcamento_saude  esgotamento_sanitario taxa_homicidio  ideb_anosiniciais  \
# 0           617.07                  35.43         51.495                4.2
# 1           997.20                  35.77         11.487                6.0
# 2           785.85                   0.00         38.926                6.2
# 3           578.33                   0.00         40.928                4.2
# 4           469.07                   0.00         21.002                5.0
#
#    ideb_anosfinais  investimento_infraestrutura  equipamentos_esportivos  \
# 0              3.0                     1076.540                    2.878
# 1              4.9                     3447.022                   46.112
# 2              4.9                     2781.115                   20.032
# 3              3.4                     4027.146                   13.587
# 4              4.4                     3341.453                    1.767
#
#    equpamentos_culturais  churn  distancia_capital
# 0                  5.756      1               81.0
# 1                 34.584      0              101.0
# 2                 20.032      1              420.0
# 3                 27.174      1              343.0
# 4                  1.767      1              369.0
#
# [5 rows x 27 columns]

# %%
clf1 = setup(data = df_churn, 
             target = 'churn',
             train_size=0.7,
             normalize=True,
             normalize_method='minmax',
             fix_imbalance=True,
             remove_multicollinearity=True,
             remove_outliers = True,
             ordinal_features = {"porte":["PP I", "PP II", "MP", "GP", "Metropole"]},
             fold=10,
            session_id = 5049)

# Acessando os dados de treino e teste completos (todas as variáveis)
transformed_train_df = get_config('X_train')  # Variáveis independentes transformadas
transformed_train_df['churn'] = get_config('y_train')  # Adicionando a variável alvo

# Caso queira visualizar ou salvar os dados completos
transformed_train_df.to_csv('transformed_train_df.csv', index=False)

clf1
# Out:
# <style type="text/css">
# #T_b8d08_row11_col1, #T_b8d08_row17_col1, #T_b8d08_row19_col1, #T_b8d08_row21_col1, #T_b8d08_row23_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b8d08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8d08_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b8d08_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8d08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8d08_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b8d08_row0_col1" class="data row0 col1" >5049</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b8d08_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b8d08_row1_col1" class="data row1 col1" >churn</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b8d08_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b8d08_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b8d08_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b8d08_row3_col1" class="data row3 col1" >(1647, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b8d08_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b8d08_row4_col1" class="data row4 col1" >(1633, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b8d08_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b8d08_row5_col1" class="data row5 col1" >(1138, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b8d08_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b8d08_row6_col1" class="data row6 col1" >(495, 52)</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b8d08_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_b8d08_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b8d08_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_b8d08_row8_col1" class="data row8 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b8d08_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_b8d08_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b8d08_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_b8d08_row10_col1" class="data row10 col1" >19.2%</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b8d08_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_b8d08_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b8d08_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_b8d08_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b8d08_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_b8d08_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b8d08_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_b8d08_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b8d08_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_b8d08_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b8d08_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_b8d08_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b8d08_row17_col0" class="data row17 col0" >Remove multicollinearity</td>
#       <td id="T_b8d08_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b8d08_row18_col0" class="data row18 col0" >Multicollinearity threshold</td>
#       <td id="T_b8d08_row18_col1" class="data row18 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b8d08_row19_col0" class="data row19 col0" >Remove outliers</td>
#       <td id="T_b8d08_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b8d08_row20_col0" class="data row20 col0" >Outliers threshold</td>
#       <td id="T_b8d08_row20_col1" class="data row20 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b8d08_row21_col0" class="data row21 col0" >Fix imbalance</td>
#       <td id="T_b8d08_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b8d08_row22_col0" class="data row22 col0" >Fix imbalance method</td>
#       <td id="T_b8d08_row22_col1" class="data row22 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b8d08_row23_col0" class="data row23 col0" >Normalize</td>
#       <td id="T_b8d08_row23_col1" class="data row23 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b8d08_row24_col0" class="data row24 col0" >Normalize method</td>
#       <td id="T_b8d08_row24_col1" class="data row24 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b8d08_row25_col0" class="data row25 col0" >Fold Generator</td>
#       <td id="T_b8d08_row25_col1" class="data row25 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b8d08_row26_col0" class="data row26 col0" >Fold Number</td>
#       <td id="T_b8d08_row26_col1" class="data row26 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_b8d08_row27_col0" class="data row27 col0" >CPU Jobs</td>
#       <td id="T_b8d08_row27_col1" class="data row27 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_b8d08_row28_col0" class="data row28 col0" >Use GPU</td>
#       <td id="T_b8d08_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_b8d08_row29_col0" class="data row29 col0" >Log Experiment</td>
#       <td id="T_b8d08_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b8d08_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_b8d08_row30_col0" class="data row30 col0" >Experi

# %%
clf1.train_transformed
# Out:
#       uf_destino_MA  uf_destino_TO  uf_destino_ES  uf_destino_CE  \
# 300             1.0            0.0            0.0            0.0
# 1267            0.0            1.0            0.0            0.0
# 767             0.0            0.0            1.0            0.0
# 495             0.0            0.0            0.0            1.0
# 266             0.0            0.0            0.0            0.0
# ...             ...            ...            ...            ...
# 1686            0.0            0.0            0.0            0.0
# 1687            0.0            0.0            0.0            0.0
# 1688            0.0            0.0            0.0            0.0
# 1689            0.0            0.0            0.0            0.0
# 1690            0.0            0.0            0.0            1.0
#
#       uf_destino_BA  uf_destino_MG  uf_destino_PE  uf_destino_PA  \
# 300             0.0            0.0            0.0       0.000000
# 1267            0.0            0.0            0.0       0.000000
# 767             0.0            0.0            0.0       0.000000
# 495             0.0            0.0            0.0       0.000000
# 266             1.0            0.0            0.0       0.000000
# ...             ...            ...            ...            ...
# 1686            0.0            0.0            0.0       0.369792
# 1687            0.0            0.0            0.0       1.000000
# 1688            0.0            0.0            0.0       0.000000
# 1689            0.0            0.0            0.0       0.000000
# 1690            0.0            0.0            0.0       0.000000
#
#       uf_destino_SP  uf_destino_RJ  ...  orcamento_saude  \
# 300        0.000000            0.0  ...         0.054657
# 1267       0.000000            0.0  ...         0.085695
# 767        0.000000            0.0  ...         0.103658
# 495        0.000000            0.0  ...         0.081301
# 266        0.000000            0.0  ...         0.098017
# ...             ...            ...  ...              ...
# 1686       0.000000            0.0  ...         0.065041
# 1687       0.000000            0.0  ...         0.051778
# 1688       0.000000            0.0  ...         0.093925
# 1689       0.343867            0.0  ...         0.091206
# 1690       0.000000            0.0  ...         0.080221
#
#       esgotamento_sanitario  taxa_homicidio  ideb_anosiniciais  \
# 300                0.000000        0.311668           0.180328
# 1267               0.000000        0.231003           0.114754
# 767                0.471800        0.256498           0.508197
# 495                0.000000        0.150905           0.524590
# 266                0.077000        0.164645           0.245902
# ...                     ...             ...                ...
# 1686               0.043921        0.075958           0.216018
# 1687               0.301800        0.232859           0.360656
# 1688               0.276832        0.211781           0.336167
# 1689               0.336199        0.242539           0.150903
# 1690               0.693300        0.000000           0.573771
#
#       ideb_anosfinais  investimento_infraestrutura  equipamentos_esportivos  \
# 300          0.259259                     0.100057                 0.045502
# 1267         0.379244                     0.075531                 0.111625
# 767          0.379244                     0.184189                 0.041013
# 495          0.555556                     0.084661                 0.024180
# 266          0.203704                     0.153377                 0.012633
# ...               ...                          ...                      ...
# 1686         0.403355                     0.088280                 0.036060
# 1687         0.500000                     0.107228                 0.000965
# 1688         0.361042                     0.064671                 0.016152
# 1689         0.239765                     0.097749                 0.025184
# 1690         0.444444                     0.130018                 0.027207
#
#       equpamentos_culturais  distancia_capital  churn
# 300                0.037278           0.274120      1
# 1267               0.137174           0.241312      0
# 767                0.100801           0.084302      0
# 495                0.029715           0.240726      1
# 266                0.054332           0.196201      1
# ...                     ...                ...    ...
# 1686               0.091683           0.415758      1
# 1687               0.001186           0.011655      1
# 1688               0.019081           0.063371      1
# 1689               0.086151           0.093730      1
# 1690               0.033434           0.053837      1
#
# [1138 rows x 52 columns]

# %%
best_model = compare_models(n_select = 5)
# Out:
# <style type="text/css">
# #T_eb591 th {
#   text-align: left;
# }
# #T_eb591_row0_col0, #T_eb591_row0_col2, #T_eb591_row0_col4, #T_eb591_row0_col7, #T_eb591_row1_col0, #T_eb591_row1_col2, #T_eb591_row1_col3, #T_eb591_row1_col4, #T_eb591_row1_col5, #T_eb591_row1_col6, #T_eb591_row2_col0, #T_eb591_row2_col1, #T_eb591_row2_col2, #T_eb591_row2_col3, #T_eb591_row2_col4, #T_eb591_row2_col5, #T_eb591_row2_col6, #T_eb591_row2_col7, #T_eb591_row3_col0, #T_eb591_row3_col1, #T_eb591_row3_col3, #T_eb591_row3_col4, #T_eb591_row3_col5, #T_eb591_row3_col6, #T_eb591_row3_col7, #T_eb591_row4_col0, #T_eb591_row4_col1, #T_eb591_row4_col2, #T_eb591_row4_col3, #T_eb591_row4_col4, #T_eb591_row4_col5, #T_eb591_row4_col6, #T_eb591_row4_col7, #T_eb591_row5_col0, #T_eb591_row5_col1, #T_eb591_row5_col2, #T_eb591_row5_col3, #T_eb591_row5_col4, #T_eb591_row5_col5, #T_eb591_row5_col6, #T_eb591_row5_col7, #T_eb591_row6_col0, #T_eb591_row6_col1, #T_eb591_row6_col2, #T_eb591_row6_col3, #T_eb591_row6_col4, #T_eb591_row6_col5, #T_eb591_row6_col6, #T_eb591_row6_col7, #T_eb591_row7_col0, #T_eb591_row7_col1, #T_eb591_row7_col2, #T_eb591_row7_col3, #T_eb591_row7_col4, #T_eb591_row7_col5, #T_eb591_row7_col6, #T_eb591_row7_col7, #T_eb591_row8_col0, #T_eb591_row8_col1, #T_eb591_row8_col2, #T_eb591_row8_col3, #T_eb591_row8_col4, #T_eb591_row8_col5, #T_eb591_row8_col6, #T_eb591_row8_col7, #T_eb591_row9_col0, #T_eb591_row9_col1, #T_eb591_row9_col2, #T_eb591_row9_col3, #T_eb591_row9_col4, #T_eb591_row9_col5, #T_eb591_row9_col6, #T_eb591_row9_col7, #T_eb591_row10_col0, #T_eb591_row10_col1, #T_eb591_row10_col2, #T_eb591_row10_col3, #T_eb591_row10_col5, #T_eb591_row10_col6, #T_eb591_row10_col7, #T_eb591_row11_col0, #T_eb591_row11_col1, #T_eb591_row11_col2, #T_eb591_row11_col3, #T_eb591_row11_col4, #T_eb591_row11_col5, #T_eb591_row11_col6, #T_eb591_row11_col7, #T_eb591_row12_col0, #T_eb591_row12_col1, #T_eb591_row12_col2, #T_eb591_row12_col3, #T_eb591_row12_col4, #T_eb591_row12_col5, #T_eb591_row12_col6, #T_eb591_row12_col7, #T_eb591_row13_col0, #T_eb591_row13_col1, #T_eb591_row13_col2, #T_eb591_row13_col3, #T_eb591_row13_col4, #T_eb591_row13_col5, #T_eb591_row13_col6, #T_eb591_row13_col7 {
#   text-align: left;
# }
# #T_eb591_row0_col1, #T_eb591_row0_col3, #T_eb591_row0_col5, #T_eb591_row0_col6, #T_eb591_row1_col1, #T_eb591_row1_col7, #T_eb591_row3_col2, #T_eb591_row10_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_eb591_row0_col8, #T_eb591_row1_col8, #T_eb591_row2_col8, #T_eb591_row3_col8, #T_eb591_row4_col8, #T_eb591_row5_col8, #T_eb591_row6_col8, #T_eb591_row7_col8, #T_eb591_row8_col8, #T_eb591_row9_col8, #T_eb591_row11_col8, #T_eb591_row12_col8, #T_eb591_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_eb591_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_eb591">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb591_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eb591_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_eb591_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_eb591_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_eb591_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_eb591_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_eb591_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_eb591_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_eb591_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb591_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_eb591_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_eb591_row0_col1" class="data row0 col1" >0.6337</td>
#       <td id="T_eb591_row0_col2" class="data row0 col2" >0.6752</td>
#       <td id="T_eb591_row0_col3" class="data row0 col3" >0.6311</td>
#       <td id="T_eb591_row0_col4" class="data row0 col4" >0.6246</td>
#       <td id="T_eb591_row0_col5" class="data row0 col5" >0.6270</td>
#       <td id="T_eb591_row0_col6" class="data row0 col6" >0.2672</td>
#       <td id="T_eb591_row0_col7" class="data row0 col7" >0.2678</td>
#       <td id="T_eb591_row0_col8" class="data row0 col8" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_eb591_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_eb591_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_eb591_row1_col1" class="data row1 col1" >0.6337</td>
#       <td id="T_eb591_row1_col2" class="data row1 col2" >0.6790</td>
#       <td id="T_eb591_row1_col3" class="data row1 col3" >0.5781</td>
#       <td id="T_eb591_row1_col4" class="data row1 col4" >0.6412</td>
#       <td id="T_eb591_row1_col5" class="data row1 col5" >0.6069</td>
#       <td id="T_eb591_row1_col6" class="data row1 col6" >0.2658</td>
#       <td id="T_eb591_row1_col7" class="data row1 col7" >0.2680</td>
#       <td id="T_eb591_row1_col8" class="data row1 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_eb591_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_eb591_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_eb591_row2_col1" class="data row2 col1" >0.6302</td>
#       <td id="T_eb591_row2_col2" class="data row2 col2" >0.6804</td>
#       <td id="T_eb591_row2_col3" class="data row2 col3" >0.5746</td>
#       <td id="T_eb591_row2_col4" class="data row2 col4" >0.6389</td>
#       <td id="T_eb591_row2_col5" class="data row2 col5" >0.6038</td>
#       <td id="T_eb591_row2_col6" class="data row2 col6" >0.2590</td>
#       <td id="T_eb591_row2_col7" class="data row2 col7" >0.2614</td>
#       <td id="T_eb591_row2_col8" class="data row2 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_eb591_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_eb591_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_eb591_row3_col1" class="data row3 col1" >0.6250</td>
#       <td id="T_eb591_row3_col2" class="data row3 col2" >0.6806</td>
#       <td id="T_eb591_row3_col3" class="data row3 col3" >0.5799</td>
#       <td id="T_eb591_row3_col4" class="data row3 col4" >0.6294</td>
#       <td id="T_eb591_row3_col5" class="data row3 col5" >0.6023</td>
#       <td id="T_eb591_row3_col6" class="data row3 col6" >0.2488</td>
#       <td id="T_eb591_row3_col7" class="data row3 col7" >0.2507</td>
#       <td id="T_eb591_row3_col8" class="data row3 col8" >0.7310</td>
#     </tr>
#     <tr>
#       <th id="T_eb591_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_eb591_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_eb591_row4_col1" class="data row4 col1" >0.6250</td>
#       <td id="T_eb591_row4_col2" class="data row4 col2" >0.6683</td>
#       <td id="T_eb591_row4_col3" class="data row4 col3" >0.6134</td>
#       <td id="T_eb591_row4_col4" class="data row4 col4" >0.6178</td>
#       <td id="T_eb591_row4_col5" class="data row4 col5" >0.6151</td>
#       <td id="T_eb591_row4_col6" class="data row4 col6" >0.2495</td>
#       <td id="T_eb591_row4_col7" class="data row4 col7" >0.2498</td>
#       <td id="T_eb591_row4_col8" class="data row4 col8" >0.1780</td>
#     </tr>
#     <tr>
#       <th id="T_eb591_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_eb591_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_eb591_row5_col1" class="data row5 col1" >0.6241</td>
#       <td id="T_eb591_row5_col2" class="data row5 col2" >0.6594</td>
#       <td id="T_eb591_row5_col3" class="data row5 col3" >0.6223</td>
#       <td id="T_eb591_row5_col4" class="data row5 col4" >0.6148</td>
#       <td id="T_eb591_row5_col5" class="data row5 col5" >0.6176</td>
#       <td id="T_eb591_row5_col6" class="data row5 col6" >0.2481</td>
#       <td id="T_eb591_row5_col7" class="data row5 col7" >0.2488</td>
#       <td
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
tuned_model_rf = tune_model(best_model[0])
tuned_model_rf
# Out:
# <style type="text/css">
# #T_35af4_row10_col0, #T_35af4_row10_col1, #T_35af4_row10_col2, #T_35af4_row10_col3, #T_35af4_row10_col4, #T_35af4_row10_col5, #T_35af4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_35af4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35af4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_35af4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_35af4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_35af4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_35af4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_35af4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_35af4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35af4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35af4_row0_col0" class="data row0 col0" >0.6207</td>
#       <td id="T_35af4_row0_col1" class="data row0 col1" >0.6827</td>
#       <td id="T_35af4_row0_col2" class="data row0 col2" >0.5965</td>
#       <td id="T_35af4_row0_col3" class="data row0 col3" >0.6182</td>
#       <td id="T_35af4_row0_col4" class="data row0 col4" >0.6071</td>
#       <td id="T_35af4_row0_col5" class="data row0 col5" >0.2407</td>
#       <td id="T_35af4_row0_col6" class="data row0 col6" >0.2408</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35af4_row1_col0" class="data row1 col0" >0.6724</td>
#       <td id="T_35af4_row1_col1" class="data row1 col1" >0.7138</td>
#       <td id="T_35af4_row1_col2" class="data row1 col2" >0.6667</td>
#       <td id="T_35af4_row1_col3" class="data row1 col3" >0.6667</td>
#       <td id="T_35af4_row1_col4" class="data row1 col4" >0.6667</td>
#       <td id="T_35af4_row1_col5" class="data row1 col5" >0.3446</td>
#       <td id="T_35af4_row1_col6" class="data row1 col6" >0.3446</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35af4_row2_col0" class="data row2 col0" >0.5478</td>
#       <td id="T_35af4_row2_col1" class="data row2 col1" >0.6021</td>
#       <td id="T_35af4_row2_col2" class="data row2 col2" >0.5789</td>
#       <td id="T_35af4_row2_col3" class="data row2 col3" >0.5410</td>
#       <td id="T_35af4_row2_col4" class="data row2 col4" >0.5593</td>
#       <td id="T_35af4_row2_col5" class="data row2 col5" >0.0961</td>
#       <td id="T_35af4_row2_col6" class="data row2 col6" >0.0964</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35af4_row3_col0" class="data row3 col0" >0.6870</td>
#       <td id="T_35af4_row3_col1" class="data row3 col1" >0.7319</td>
#       <td id="T_35af4_row3_col2" class="data row3 col2" >0.6316</td>
#       <td id="T_35af4_row3_col3" class="data row3 col3" >0.7059</td>
#       <td id="T_35af4_row3_col4" class="data row3 col4" >0.6667</td>
#       <td id="T_35af4_row3_col5" class="data row3 col5" >0.3733</td>
#       <td id="T_35af4_row3_col6" class="data row3 col6" >0.3754</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35af4_row4_col0" class="data row4 col0" >0.7391</td>
#       <td id="T_35af4_row4_col1" class="data row4 col1" >0.7482</td>
#       <td id="T_35af4_row4_col2" class="data row4 col2" >0.7679</td>
#       <td id="T_35af4_row4_col3" class="data row4 col3" >0.7167</td>
#       <td id="T_35af4_row4_col4" class="data row4 col4" >0.7414</td>
#       <td id="T_35af4_row4_col5" class="data row4 col5" >0.4789</td>
#       <td id="T_35af4_row4_col6" class="data row4 col6" >0.4800</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_35af4_row5_col0" class="data row5 col0" >0.6000</td>
#       <td id="T_35af4_row5_col1" class="data row5 col1" >0.6221</td>
#       <td id="T_35af4_row5_col2" class="data row5 col2" >0.6429</td>
#       <td id="T_35af4_row5_col3" class="data row5 col3" >0.5806</td>
#       <td id="T_35af4_row5_col4" class="data row5 col4" >0.6102</td>
#       <td id="T_35af4_row5_col5" class="data row5 col5" >0.2016</td>
#       <td id="T_35af4_row5_col6" class="data row5 col6" >0.2027</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_35af4_row6_col0" class="data row6 col0" >0.6522</td>
#       <td id="T_35af4_row6_col1" class="data row6 col1" >0.6760</td>
#       <td id="T_35af4_row6_col2" class="data row6 col2" >0.6964</td>
#       <td id="T_35af4_row6_col3" class="data row6 col3" >0.6290</td>
#       <td id="T_35af4_row6_col4" class="data row6 col4" >0.6610</td>
#       <td id="T_35af4_row6_col5" class="data row6 col5" >0.3058</td>
#       <td id="T_35af4_row6_col6" class="data row6 col6" >0.3074</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_35af4_row7_col0" class="data row7 col0" >0.7043</td>
#       <td id="T_35af4_row7_col1" class="data row7 col1" >0.7365</td>
#       <td id="T_35af4_row7_col2" class="data row7 col2" >0.7321</td>
#       <td id="T_35af4_row7_col3" class="data row7 col3" >0.6833</td>
#       <td id="T_35af4_row7_col4" class="data row7 col4" >0.7069</td>
#       <td id="T_35af4_row7_col5" class="data row7 col5" >0.4094</td>
#       <td id="T_35af4_row7_col6" class="data row7 col6" >0.4104</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_35af4_row8_col0" class="data row8 col0" >0.6696</td>
#       <td id="T_35af4_row8_col1" class="data row8 col1" >0.7424</td>
#       <td id="T_35af4_row8_col2" class="data row8 col2" >0.6786</td>
#       <td id="T_35af4_row8_col3" class="data row8 col3" >0.6552</td>
#       <td id="T_35af4_row8_col4" class="data row8 col4" >0.6667</td>
#       <td id="T_35af4_row8_col5" class="data row8 col5" >0.3393</td>
#       <td id="T_35af4_row8_col6" class="data row8 col6" >0.3395</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_35af4_row9_col0" class="data row9 col0" >0.6174</td>
#       <td id="T_35af4_row9_col1" class="data row9 col1" >0.7048</td>
#       <td id="T_35af4_row9_col2" class="data row9 col2" >0.6607</td>
#       <td id="T_35af4_row9_col3" class="data row9 col3" >0.5968</td>
#       <td id="T_35af4_row9_col4" class="data row9 col4" >0.6271</td>
#       <td id="T_35af4_row9_col5" class="data row9 col5" >0.2363</td>
#       <td id="T_35af4_row9_col6" class="data row9 col6" >0.2376</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_35af4_row10_col0" class="data row10 col0" >0.6510</td>
#       <td id="T_35af4_row10_col1" class="data row10 col1" >0.6960</td>
#       <td id="T_35af4_row10_col2" class="data row10 col2" >0.6652</td>
#       <td id="T_35af4_row10_col3" class="data row10 col3" >0.6393</td>
#       <td id="T_35af4_row10_col4" class="data row10 col4" >0.6513</td>
#       <td id="T_35af4_row10_col5" class="data row10 col5" >0.3026</td>
#       <td id="T_35af4_row10_col6" class="data row10 col6" >0.3035</td>
#     </tr>
#     <tr>
#       <th id="T_35af4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_35af4_row11_col0" class="data row11 col0" >0.0529</td>
#       <td id="T_35af4_row11_col1" class="data row11 col1" >0.0480</td>
#       <td id="T_35af4_row11_col2" class="data row11 col2" >0.0548</td>
#       <td id="T_35af4_row11_col3" class="data row11 col3" >0.0537</td>
#       <td id="T_35af4_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='entropy', max_depth=3, max_features=1.0,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.02, min_samples_leaf=4,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=120, n_jobs=-1,
#                        oob_score=False, random_state=5049, verbose=0,
#                        warm_start=False)

# %%
evaluate_model(tuned_model_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
avaliacao = predict_model(tuned_model_rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_db088">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db088_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_db088_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_db088_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_db088_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_db088_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_db088_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_db088_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_db088_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db088_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db088_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_db088_row0_col1" class="data row0 col1" >0.6586</td>
#       <td id="T_db088_row0_col2" class="data row0 col2" >0.6848</td>
#       <td id="T_db088_row0_col3" class="data row0 col3" >0.6240</td>
#       <td id="T_db088_row0_col4" class="data row0 col4" >0.6594</td>
#       <td id="T_db088_row0_col5" class="data row0 col5" >0.6412</td>
#       <td id="T_db088_row0_col6" class="data row0 col6" >0.3160</td>
#       <td id="T_db088_row0_col7" class="data row0 col7" >0.3165</td>
#     </tr>
#   </tbody>
# </table>

# %%
testar = avaliacao.loc[:,('churn',
             'prediction_label',
             'prediction_score')]

testar
# Out:
#       churn  prediction_label  prediction_score
# 189       0                 1            0.6440
# 2         1                 1            0.7078
# 8         1                 1            0.6520
# 1484      0                 0            0.6767
# 38        1                 1            0.6858
# ...     ...               ...               ...
# 757       0                 0            0.5866
# 414       0                 0            0.5317
# 608       0                 0            0.5836
# 812       1                 0            0.6399
# 1191      0                 0            0.5717
#
# [495 rows x 3 columns]

# %%
final_model = finalize_model(tuned_model_rf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pycaret\internal\preprocess\transformers.py in _reorder_cols(self, df, original_df)
#     134         try:
# --> 135             original_df.index = df.index
#     136         except ValueError:  # Length mismatch
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
#     770         self._clear_item_cache()
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     213         # Caller is responsible for ensuring we have an Index object.
# --> 214         self._validate_set_axis(axis, new_labels)
#     215         self.axes[axis] = new_labels
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\base.py in _validate_set_axis(self, axis, new_labels)
#      68         elif new_len != old_len:
# ---> 69             raise ValueError(
#      70                 f"Length mismatch: Expected axis has {old_len} elements, new "
#
# ValueError: Length mismatch: Expected axis has 1647 elements, new values have 1564 elements
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5484\1587750683.py in <module>
# ----> 1 final_model = finalize_model(tuned_model_rf)
#
# ~\anaconda3\lib\site-packages\pycaret\utils\generic.py in wrapper(*args, **kwargs)
#     962                 if globals_d[name] is None:
#     963                     raise ValueError(message)
# --> 964             return func(*args, **kwargs)
#     965
#     966         return wrapper
#
# ~\anaconda3\lib\site-packages\pycaret\classification\functional.py in finalize_model(estimator, fit_kwargs, groups, model_only, experiment_custom_tags)
#    2233     """
#    2234
# -> 2235     return _CURRENT_EXPERIMENT.finalize_model(
#    2236         estimator=estimator,
#    2237         fit_kwargs=fit_kwargs,
#
# ~\anaconda3\lib\site-packages\pycaret\classification\oop.py in finalize_model(self, estimator, fit_kwargs, groups, model_only, experiment_custom_tags)
#    2884         """
#    2885
# -> 2886         return super().finalize_model(
#    2887             estimator=estimator,
#    2888             fit_kwargs=fit_kwargs,
#
# ~\anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in finalize_model(self, estimator, fit_kwargs, groups, model_only, experiment_custom_tags)
#    4736
#    4737         self.logger.info(f"Finalizing {estimator}")
# -> 4738         pipeline_final, model_fit_time = self._create_model(
#    4739             estimator=estimator,
#    4740             cross_validation=False,
#
# ~\anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in _create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1505
#    1506         if not cross_validation:
# -> 1507             model, model_fit_time = self._create_model_without_cv(
#    1508                 model=model,
#    1509                 data_X=data_X,
#
# ~\anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in _create_model_without_cv(self, model, data_X, data_y, fit_kwargs, round, predict, system, display, model_only, return_train_score)
#    1030             model_fit_start = time.time()
#    1031             with redirect_output(self.logger):
# -> 1032                 pipeline_with_model.fit(data_X, data_y, **fit_kwargs)
#    1033             model_fit_end = time.time()
#    1034
#
# ~\anaconda3\lib\site-packages\pycaret\internal\pipeline.py in fit(self, X, y, **params)
#     271     def fit(self, X=None, y=None, **params):
#     272         routed_params = self._check_method_params(method="fit", props=params)
# --> 273         X, y, _ = self._fit(X, y, routed_params)
#     274
#     275         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# ~\anaconda3\lib\site-packages\pycaret\internal\pipeline.py in _fit(self, X, y, routed_params)
#     254                     params=routed_params.get(name, {}),
#     255                 )
# --> 256                 X, y = self._memory_transform(
#     257                     transformer=fitted_transformer,
#     258                     X=X,
#
# ~\anaconda3\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     351
#     352     def __call__(self, *args, **kwargs):
# --> 353         return self.func(*args, **kwargs)
#     354
#     355     def call_and_shelve(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\pycaret\internal\pipeline.py in _transform_one(transformer, X, y)
#      78     if "y" in signature(transformer.transform).parameters:
#      79         args.append(y)
# ---> 80     output = transformer.transform(*args)
#      81
#      82     if isinstance(output, tuple):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py in wrapped(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#
# ~\anaconda3\lib\site-packages\pycaret\internal\preprocess\transformers.py in transform(self, X, y)
#     257         # Transform can return X, y or both
#     258         if isinstance(output, tuple):
# --> 259             new_X = self._prepare_df(X, output[0])
#     260             new_y = to_series(output[1], index=new_X.index, name=y.name)
#     261         else:
#
# ~\anaconda3\lib\site-packages\pycaret\internal\preprocess\transformers.py in _prepare_df(self, X, out)
#     194         # Reorder columns if only a subset was used
#     195         if len(self._include) != X.shape[1]:
# --> 196             return self._reorder_cols(out, X)
#     197         else:
#     198             return out
#
# ~\anaconda3\lib\site-packages\pycaret\internal\preprocess\transformers.py in _reorder_cols(self, df, original_df)
#     135             original_df.index = df.index
#     136         except ValueError:  # Length mismatch
# --> 137             raise IndexError(
#     138                 f"Length of values ({len(df)}) does not match length of "
#     139                 f"index ({len(original_df)}). This usually happens when "
#
# IndexError: Length of values (1564) does not match length of index (1647). This usually happens when transformations that drop rows aren't applied on all the columns.

# %% [markdown]
# # Fazendo teste de usando regressão

# %%
df_original = pd.read_excel("database_mm_0312.xlsx")
df_original.head()
# Out:
#     ano   competen  codufmun  ibge_aloc municipio_destino uf_destino     cnes  \
# 0  2019 2019-06-01    240580     240580       JOAO CAMARA         RN  2474689
# 1  2019 2019-06-01    220020     220020       AGUA BRANCA         PI  2368455
# 2  2019 2019-10-01    520310     520310            BALIZA         GO  2500132
# 3  2019 2019-09-01    290195     290195          APUAREMA         BA  7050062
# 4  2019 2019-09-01    130340     130340         PARINTINS         AM  9640347
#
#    tp_unid                                     fantasia  \
# 0        2                          PSF 2 SAO FRANCISCO
# 1        2  POSTO DE SAUDE OTACIANA MARIA DO NASCIMENTO
# 2        2                     ESF MARLENE NERY RIBEIRO
# 3        2                                 USF OTACIANO
# 4        2   UNIDADE BASICA DE SAUDE DO BAIRRO DA UNIAO
#
#                          nomeprof  ...  orcamento_saude esgotamento_sanitario  \
# 0  MARLIO EVERTON MACEDO DE PAIVA  ...           617.07                 35.43
# 1            ANA MARIA REGO COSTA  ...           997.20                 35.77
# 2            RUBENS NOVAIS XAVIER  ...           785.85                  0.00
# 3          HERALDO ROCHA DE JESUS  ...           578.33                  0.00
# 4              KEDMA TAVARES BUAS  ...           469.07                  0.00
#
#   taxa_homicidio mortes_armasdefogo feminicidio ideb_anosiniciais  \
# 0         51.495                0.0      28.412               4.2
# 1         11.487                0.0      21.671               6.0
# 2         38.926                0.0       0.000               6.2
# 3         40.928                0.0      26.688               4.2
# 4         21.002                0.0       7.180               5.0
#
#    ideb_anosfinais investimento_infraestrutura  equipamentos_esportivos  \
# 0              3.0                    1076.540                    2.878
# 1              4.9                    3447.022                   46.112
# 2              4.9                    2781.115                   20.032
# 3              3.4                    4027.146                   13.587
# 4              4.4                    3341.453                    1.767
#
#    equpamentos_culturais
# 0                  5.756
# 1                 34.584
# 2                 20.032
# 3                 27.174
# 4                  1.767
#
# [5 rows x 51 columns]

# %%
df_media = df_original.loc[:,('uf_destino', 
                        'participou_pmmb',
                        'sexo',
                         'atuacao_previa_no_municipio',
                         'anos_atuacao_mesmo_municipio', 
                         'media_vinculos', 
                         'idade_em_anos',
                         'Prorrogado', 
                         'anos_formacao',
                         'leitos_hospitalares_cirurgico_clinico_complementar',
                         'leitos_instalacao_fisica_urgencia',
                        'leitos_instalacao_fisica_obstetrico', 
                        'agente_saude', 
                        'dentista',
                        'enfermeiro', 
                        'tec_aux_enf', 
                        'populacao', 
                        'porte', 
                        'pib_percapita',
                        'tx_pop_ocupada', 
                        'cobertura_saude', 
                        'vagas_medicina_milhab',
                        'orcamento_saude', 
                        'esgotamento_sanitario', 
                        'taxa_homicidio',
                        'ideb_anosiniciais',
                        'ideb_anosfinais', 
                        'investimento_infraestrutura',
                        'equipamentos_esportivos', 
                        'equpamentos_culturais',
                        'meses_no_local_alocado')]

# %%
from pycaret.regression import *

# %%
reg_mm = setup(data = df_media, 
                target = 'meses_no_local_alocado',
                train_size=0.7,
                normalize=True,
                normalize_method='minmax',
                remove_multicollinearity=True,
                remove_outliers=True,
                fold=10)

reg_mm
# Out:
# <style type="text/css">
# #T_80d0c_row10_col1, #T_80d0c_row16_col1, #T_80d0c_row18_col1, #T_80d0c_row20_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_80d0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80d0c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_80d0c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80d0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80d0c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_80d0c_row0_col1" class="data row0 col1" >8664</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80d0c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_80d0c_row1_col1" class="data row1 col1" >meses_no_local_alocado</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80d0c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_80d0c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80d0c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_80d0c_row3_col1" class="data row3 col1" >(1647, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80d0c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_80d0c_row4_col1" class="data row4 col1" >(1589, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80d0c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_80d0c_row5_col1" class="data row5 col1" >(1094, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80d0c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_80d0c_row6_col1" class="data row6 col1" >(495, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80d0c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_80d0c_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80d0c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_80d0c_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_80d0c_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_80d0c_row9_col1" class="data row9 col1" >33.2%</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_80d0c_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_80d0c_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_80d0c_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_80d0c_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_80d0c_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_80d0c_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_80d0c_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_80d0c_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_80d0c_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_80d0c_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_80d0c_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_80d0c_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_80d0c_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_80d0c_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_80d0c_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_80d0c_row17_col1" class="data row17 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_80d0c_row18_col0" class="data row18 col0" >Remove outliers</td>
#       <td id="T_80d0c_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_80d0c_row19_col0" class="data row19 col0" >Outliers threshold</td>
#       <td id="T_80d0c_row19_col1" class="data row19 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_80d0c_row20_col0" class="data row20 col0" >Normalize</td>
#       <td id="T_80d0c_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_80d0c_row21_col0" class="data row21 col0" >Normalize method</td>
#       <td id="T_80d0c_row21_col1" class="data row21 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_80d0c_row22_col0" class="data row22 col0" >Fold Generator</td>
#       <td id="T_80d0c_row22_col1" class="data row22 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_80d0c_row23_col0" class="data row23 col0" >Fold Number</td>
#       <td id="T_80d0c_row23_col1" class="data row23 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_80d0c_row24_col0" class="data row24 col0" >CPU Jobs</td>
#       <td id="T_80d0c_row24_col1" class="data row24 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_80d0c_row25_col0" class="data row25 col0" >Use GPU</td>
#       <td id="T_80d0c_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_80d0c_row26_col0" class="data row26 col0" >Log Experiment</td>
#       <td id="T_80d0c_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_80d0c_row27_col0" class="data row27 col0" >Experiment Name</td>
#       <td id="T_80d0c_row27_col1" class="data row27 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_80d0c_row28_col0" class="data row28 col0" >USI</td>
#       <td id="T_80d0c_row28_col1" class="data row28 col1" >8a95</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_reg = compare_models()
# Out:
# <style type="text/css">
# #T_9cc5e th {
#   text-align: left;
# }
# #T_9cc5e_row0_col0, #T_9cc5e_row0_col6, #T_9cc5e_row1_col0, #T_9cc5e_row1_col1, #T_9cc5e_row1_col2, #T_9cc5e_row1_col3, #T_9cc5e_row1_col4, #T_9cc5e_row1_col5, #T_9cc5e_row1_col6, #T_9cc5e_row2_col0, #T_9cc5e_row2_col1, #T_9cc5e_row2_col2, #T_9cc5e_row2_col3, #T_9cc5e_row2_col4, #T_9cc5e_row2_col5, #T_9cc5e_row3_col0, #T_9cc5e_row3_col1, #T_9cc5e_row3_col2, #T_9cc5e_row3_col3, #T_9cc5e_row3_col4, #T_9cc5e_row3_col5, #T_9cc5e_row3_col6, #T_9cc5e_row4_col0, #T_9cc5e_row4_col1, #T_9cc5e_row4_col2, #T_9cc5e_row4_col3, #T_9cc5e_row4_col4, #T_9cc5e_row4_col5, #T_9cc5e_row4_col6, #T_9cc5e_row5_col0, #T_9cc5e_row5_col1, #T_9cc5e_row5_col2, #T_9cc5e_row5_col3, #T_9cc5e_row5_col4, #T_9cc5e_row5_col5, #T_9cc5e_row5_col6, #T_9cc5e_row6_col0, #T_9cc5e_row6_col1, #T_9cc5e_row6_col2, #T_9cc5e_row6_col3, #T_9cc5e_row6_col4, #T_9cc5e_row6_col5, #T_9cc5e_row6_col6, #T_9cc5e_row7_col0, #T_9cc5e_row7_col1, #T_9cc5e_row7_col2, #T_9cc5e_row7_col3, #T_9cc5e_row7_col4, #T_9cc5e_row7_col5, #T_9cc5e_row7_col6, #T_9cc5e_row8_col0, #T_9cc5e_row8_col1, #T_9cc5e_row8_col2, #T_9cc5e_row8_col3, #T_9cc5e_row8_col4, #T_9cc5e_row8_col5, #T_9cc5e_row8_col6, #T_9cc5e_row9_col0, #T_9cc5e_row9_col1, #T_9cc5e_row9_col2, #T_9cc5e_row9_col3, #T_9cc5e_row9_col4, #T_9cc5e_row9_col5, #T_9cc5e_row9_col6, #T_9cc5e_row10_col0, #T_9cc5e_row10_col1, #T_9cc5e_row10_col2, #T_9cc5e_row10_col3, #T_9cc5e_row10_col4, #T_9cc5e_row10_col5, #T_9cc5e_row10_col6, #T_9cc5e_row11_col0, #T_9cc5e_row11_col1, #T_9cc5e_row11_col2, #T_9cc5e_row11_col3, #T_9cc5e_row11_col4, #T_9cc5e_row11_col5, #T_9cc5e_row11_col6, #T_9cc5e_row12_col0, #T_9cc5e_row12_col1, #T_9cc5e_row12_col2, #T_9cc5e_row12_col3, #T_9cc5e_row12_col4, #T_9cc5e_row12_col5, #T_9cc5e_row12_col6, #T_9cc5e_row13_col0, #T_9cc5e_row13_col1, #T_9cc5e_row13_col2, #T_9cc5e_row13_col3, #T_9cc5e_row13_col4, #T_9cc5e_row13_col5, #T_9cc5e_row13_col6, #T_9cc5e_row14_col0, #T_9cc5e_row14_col1, #T_9cc5e_row14_col2, #T_9cc5e_row14_col3, #T_9cc5e_row14_col4, #T_9cc5e_row14_col5, #T_9cc5e_row14_col6, #T_9cc5e_row15_col0, #T_9cc5e_row15_col1, #T_9cc5e_row15_col2, #T_9cc5e_row15_col3, #T_9cc5e_row15_col4, #T_9cc5e_row15_col5, #T_9cc5e_row15_col6, #T_9cc5e_row16_col0, #T_9cc5e_row16_col1, #T_9cc5e_row16_col2, #T_9cc5e_row16_col3, #T_9cc5e_row16_col4, #T_9cc5e_row16_col5, #T_9cc5e_row16_col6, #T_9cc5e_row17_col0, #T_9cc5e_row17_col1, #T_9cc5e_row17_col2, #T_9cc5e_row17_col3, #T_9cc5e_row17_col4, #T_9cc5e_row17_col5, #T_9cc5e_row17_col6 {
#   text-align: left;
# }
# #T_9cc5e_row0_col1, #T_9cc5e_row0_col2, #T_9cc5e_row0_col3, #T_9cc5e_row0_col4, #T_9cc5e_row0_col5, #T_9cc5e_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9cc5e_row0_col7, #T_9cc5e_row1_col7, #T_9cc5e_row2_col7, #T_9cc5e_row3_col7, #T_9cc5e_row4_col7, #T_9cc5e_row5_col7, #T_9cc5e_row6_col7, #T_9cc5e_row7_col7, #T_9cc5e_row9_col7, #T_9cc5e_row10_col7, #T_9cc5e_row11_col7, #T_9cc5e_row12_col7, #T_9cc5e_row13_col7, #T_9cc5e_row14_col7, #T_9cc5e_row15_col7, #T_9cc5e_row16_col7, #T_9cc5e_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9cc5e_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9cc5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cc5e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9cc5e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9cc5e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9cc5e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9cc5e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9cc5e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9cc5e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9cc5e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cc5e_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_9cc5e_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_9cc5e_row0_col1" class="data row0 col1" >11.3476</td>
#       <td id="T_9cc5e_row0_col2" class="data row0 col2" >212.7985</td>
#       <td id="T_9cc5e_row0_col3" class="data row0 col3" >14.5522</td>
#       <td id="T_9cc5e_row0_col4" class="data row0 col4" >0.5014</td>
#       <td id="T_9cc5e_row0_col5" class="data row0 col5" >0.6086</td>
#       <td id="T_9cc5e_row0_col6" class="data row0 col6" >0.7652</td>
#       <td id="T_9cc5e_row0_col7" class="data row0 col7" >0.2460</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_9cc5e_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_9cc5e_row1_col1" class="data row1 col1" >11.4977</td>
#       <td id="T_9cc5e_row1_col2" class="data row1 col2" >217.6128</td>
#       <td id="T_9cc5e_row1_col3" class="data row1 col3" >14.7153</td>
#       <td id="T_9cc5e_row1_col4" class="data row1 col4" >0.4904</td>
#       <td id="T_9cc5e_row1_col5" class="data row1 col5" >0.6100</td>
#       <td id="T_9cc5e_row1_col6" class="data row1 col6" >0.7724</td>
#       <td id="T_9cc5e_row1_col7" class="data row1 col7" >0.3610</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_9cc5e_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9cc5e_row2_col1" class="data row2 col1" >11.7192</td>
#       <td id="T_9cc5e_row2_col2" class="data row2 col2" >227.8801</td>
#       <td id="T_9cc5e_row2_col3" class="data row2 col3" >15.0650</td>
#       <td id="T_9cc5e_row2_col4" class="data row2 col4" >0.4654</td>
#       <td id="T_9cc5e_row2_col5" class="data row2 col5" >0.6222</td>
#       <td id="T_9cc5e_row2_col6" class="data row2 col6" >0.7602</td>
#       <td id="T_9cc5e_row2_col7" class="data row2 col7" >0.2560</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_9cc5e_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_9cc5e_row3_col1" class="data row3 col1" >11.8589</td>
#       <td id="T_9cc5e_row3_col2" class="data row3 col2" >229.3569</td>
#       <td id="T_9cc5e_row3_col3" class="data row3 col3" >15.1155</td>
#       <td id="T_9cc5e_row3_col4" class="data row3 col4" >0.4639</td>
#       <td id="T_9cc5e_row3_col5" class="data row3 col5" >0.6292</td>
#       <td id="T_9cc5e_row3_col6" class="data row3 col6" >0.8400</td>
#       <td id="T_9cc5e_row3_col7" class="data row3 col7" >0.0810</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_9cc5e_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_9cc5e_row4_col1" class="data row4 col1" >11.9133</td>
#       <td id="T_9cc5e_row4_col2" class="data row4 col2" >230.9964</td>
#       <td id="T_9cc5e_row4_col3" class="data row4 col3" >15.1679</td>
#       <td id="T_9cc5e_row4_col4" class="data row4 col4" >0.4597</td>
#       <td id="T_9cc5e_row4_col5" class="data row4 col5" >0.6323</td>
#       <td id="T_9cc5e_row4_col6" class="data row4 col6" >0.8328</td>
#       <td id="T_9cc5e_row4_col7" class="data row4 col7" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_9cc5e_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_9cc5e_row5_col1" class="data row5 col1" >11.8510</td>
#       <td id="T_9cc5e_row5_col2" class="data row5 col2" >232.2269</td>
#       <td id="T_9cc5e_row5_col3" class="data row5 col3" >15.1930</td>
#       <td id="T_9cc5e_row5_col4" class="data row5 col4" >0.4585</td>
#       <td id="T_9cc5e_row5_col5" class="data row5 col5" >0.6309</td>
#       <td id="T_9cc5e_row5_col6" class="data row5 col6" >0.8436</td>
#       <td id="T_9cc5e_row5_col7" class="data row5 col7" >0.0820</td>
#     </tr>
#     <tr>
#       <t

# %%
tuned_model_reg = tune_model(best_model_reg)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
