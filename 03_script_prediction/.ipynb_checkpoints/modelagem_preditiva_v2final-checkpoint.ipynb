# %% [markdown]
# # Análise preditiva do Programa Mais Médicos

# %% [markdown]
# ## 1. Análise preditiva para desfecho categórico (churn)

# %%
import pandas as pd
import numpy as np
import shap
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve
import xgboost as xgb
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
import optuna

# %% [markdown]
# ### Carregamento dos dados

# %%
df_completo = pd.read_csv(r"C:\Users\HP I3\OneDrive\Documentos\LAPEI-CIGETS\sa_maismedicos\01_dados\dados resultantes\df_modelagem0303.csv")

list(df_completo.columns)
# Out:
# ['Unnamed: 0',
#  'meses_no_local_alocado',
#  'churn',
#  'idade',
#  'anos_formacao',
#  'atuacao_previa_no_municipio',
#  'anos_atuacao_previa_no_municipio',
#  'media_vinculos_mes',
#  'Prorrogado',
#  'm_agente_saude',
#  'm_tec_aux_enf',
#  'm_enfermeiro',
#  'm_dentista',
#  'regiao_destino',
#  'populacao',
#  'porte',
#  'pib_percapita',
#  'variacao_pib',
#  'tx_pop_ocupada_2019',
#  'orcamento_saude',
#  'esgotamento_sanitario',
#  'taxa_homicidio',
#  'ideb_anosfinais',
#  'investimento_infraestrutura',
#  'equipamentos_esportivos',
#  'equipamentos_culturais',
#  'distancia_capital']

# %%
df_completo = df_completo.drop(["Unnamed: 0",
              "meses_no_local_alocado",
              "variacao_pib",
              'm_dentista', 'anos_formacao'], 
             axis='columns')

df_completo[['m_agente_saude', 'm_tec_aux_enf', 'm_enfermeiro']] = df_completo[['m_agente_saude', 'm_tec_aux_enf', 
                                                                                     'm_enfermeiro']].fillna(0)
df_completo['churn'] = df_completo['churn'].map({'permanece': 0, 'migrou': 1})

df_m1 = df_completo[['churn', 'idade', 'atuacao_previa_no_municipio' ,'anos_atuacao_previa_no_municipio',
                   'regiao_destino']]

df_m2 = df_completo[['churn', 'idade', 'atuacao_previa_no_municipio' ,'anos_atuacao_previa_no_municipio',
                   'media_vinculos_mes', 'm_agente_saude', 'm_tec_aux_enf', 'm_enfermeiro', 'regiao_destino']]

df_m3 = df_completo.drop(['Prorrogado'], axis='columns')

df_m4 = df_completo

# %%
df_m2.columns
# Out:
# Index(['churn', 'idade', 'anos_formacao', 'atuacao_previa_no_municipio',
#        'anos_atuacao_previa_no_municipio', 'media_vinculos_mes',
#        'm_agente_saude', 'm_tec_aux_enf', 'm_enfermeiro'],
#       dtype='object')

# %% [markdown]
# ### Análise exploratória de dados - matriz de correlação

# %%
df_numerico = df_m4.select_dtypes(include=['number'])

# Criando a matriz de correlação
corr = df_numerico.corr()

# Criando o heatmap com seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, square=False)
plt.title("Matriz de Correlação")
plt.show()

# %% [markdown]
# ### Pré-processamento e divisão em treino e teste

# %%
def dividir_e_balancear(df):
    y = df['churn']  
    X = df.drop(columns=['churn']) 

    num_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
    cat_features = X.select_dtypes(include=['object', 'category']).columns.tolist()

    num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ])

    cat_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
    ])

    preprocessor = ColumnTransformer([
        ('num', num_pipeline, num_features),
        ('cat', cat_pipeline, cat_features)
    ])
    
    # Divisão dos dados em treino e teste
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

    # Aplicar o pré-processamento
    X_train_processed = preprocessor.fit_transform(X_train)
    X_test_processed = preprocessor.transform(X_test)

    # Aplicação do SMOTE para balanceamento
    smote = SMOTE(sampling_strategy='auto', random_state=42)
    y_train = y_train.astype(int)  # Garantir que y_train seja numérico
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train_processed, y_train)
    
    return X_train_resampled, X_test_processed, y_train_resampled, y_test, preprocessor, X_train

# %%
X_train_m1, X_test_m1, y_train_m1, y_test_m1, preprocessor_m1, X_train_raw1 = dividir_e_balancear(df_m1)
X_train_m2, X_test_m2, y_train_m2, y_test_m2, preprocessor_m2, X_train_raw2 = dividir_e_balancear(df_m2)
X_train_m3, X_test_m3, y_train_m3, y_test_m3, preprocessor_m3, X_train_raw3 = dividir_e_balancear(df_m3)
X_train_m4, X_test_m4, y_train_m4, y_test_m4, preprocessor_m4, X_train_raw4 = dividir_e_balancear(df_m4)

# %%
X_train_raw1
# Out:
#       idade  anos_formacao atuacao_previa_no_municipio  \
# 1199     36       7.085558                         Não
# 290      35       4.999316                         Não
# 727      32       0.249144                         Não
# 1402     54       0.999316                         Não
# 1134     34       3.085558                         Não
# ...     ...            ...                         ...
# 882      69      39.085558                         Não
# 741      40       1.503080                         Não
# 228      37       6.083504                         Não
# 469      36       0.167009                         Não
# 201      31       0.167009                         Não
#
#       anos_atuacao_previa_no_municipio regiao_destino
# 1199                               0.0        Sudeste
# 290                                0.0       Nordeste
# 727                                0.0          Norte
# 1402                               0.0       Nordeste
# 1134                               0.0            Sul
# ...                                ...            ...
# 882                                0.0       Nordeste
# 741                                0.0       Nordeste
# 228                                0.0       Nordeste
# 469                                0.0   Centro-oeste
# 201                                0.0       Nordeste
#
# [1251 rows x 5 columns]

# %% [markdown]
# ## Instanciando modelos e rodando modelos

# %% [markdown]
# No bloco de código abaixo é definida a função para treinar e avaliar os modelos sem Optuna.

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    'LightGBM': lgb.LGBMClassifier()
}

param_grids = {
    'Logistic Regression': {'classifier__C': [0.01, 0.1, 1, 10]},
    'Decision Tree': {'classifier__max_depth': [3, 5, 10]},
    'Random Forest': {
        'classifier__n_estimators': [100, 300, 500],
        'classifier__max_depth': [3, 5, 10],
        'classifier__min_samples_split': [2, 5, 10]
    },
    'XGBoost': {
        'classifier__n_estimators': [100, 300, 500],
        'classifier__max_depth': [3, 6, 9],
        'classifier__learning_rate': [0.01, 0.05, 0.1],
        'classifier__subsample': [0.7, 0.85, 1.0],
        'classifier__colsample_bytree': [0.7, 0.85, 1.0],
        'classifier__gamma': [0, 0.1, 0.5]
    },
    'LightGBM': {
        'classifier__n_estimators': [100, 300, 500],
        'classifier__learning_rate': [0.01, 0.05, 0.1],
        'classifier__num_leaves': [20, 31, 40],
        'classifier__min_child_samples': [10, 20, 30]
    }
}


def treinando_avaliando(x_train, y_train, x_test, y_test):
    # Validação cruzada e otimização de hiperparâmetros
    best_models = {}

    for name, model in models.items():
        print(f"Treinando modelo: {name}")
        pipeline = Pipeline([('classifier', model)])

        param_grid = param_grids.get(name, {})
        cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        grid_search = GridSearchCV(pipeline, param_grid, cv=cv, scoring='roc_auc', n_jobs=-1)
        grid_search.fit(x_train, y_train)

        best_models[name] = grid_search.best_estimator_
        print(f"Melhores parâmetros para {name}: {grid_search.best_params_}\n")

    # Avaliação final no conjunto de teste
    results = []
    for name, model in best_models.items():
        y_pred = model.predict(x_test)
        y_prob = model.predict_proba(x_test)[:, 1]
        results.append({
            'Model': name,
            'Accuracy': accuracy_score(y_test, y_pred),
            'Precision': precision_score(y_test, y_pred),
            'Recall': recall_score(y_test, y_pred),
            'F1 Score': f1_score(y_test, y_pred),
            'ROC AUC': roc_auc_score(y_test, y_prob)
        })
    
    return results, models

# %% [markdown]
# No bloco de código abaixo é definida a função para treinar e avaliar os modelos com Optuna.

# %%
# Definir uma função objetivo para o Optuna
def objective(trial, model_name, x_train, y_train):
    # Definir os hiperparâmetros a serem otimizados para cada modelo
    if model_name == 'Logistic Regression':
        C = trial.suggest_loguniform('C', 0.01, 10)
        model = LogisticRegression(C=C)
    
    elif model_name == 'Decision Tree':
        max_depth = trial.suggest_int('max_depth', 3, 10)
        model = DecisionTreeClassifier(max_depth=max_depth)
    
    elif model_name == 'Random Forest':
        n_estimators = trial.suggest_int('n_estimators', 100, 500, step=100)
        max_depth = trial.suggest_int('max_depth', 3, 10)
        min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split)
    
    elif model_name == 'XGBoost':
        n_estimators = trial.suggest_int('n_estimators', 100, 500, step=100)
        max_depth = trial.suggest_int('max_depth', 3, 9)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.1)
        subsample = trial.suggest_float('subsample', 0.7, 1.0)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.7, 1.0)
        gamma = trial.suggest_float('gamma', 0, 0.5)
        model = xgb.XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate, subsample=subsample, colsample_bytree=colsample_bytree, gamma=gamma, use_label_encoder=False, eval_metric='logloss')
    
    elif model_name == 'LightGBM':
        n_estimators = trial.suggest_int('n_estimators', 100, 500, step=100)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.1)
        num_leaves = trial.suggest_int('num_leaves', 20, 40)
        min_child_samples = trial.suggest_int('min_child_samples', 10, 30)
        model = lgb.LGBMClassifier(n_estimators=n_estimators, learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples)
    
    # Treinamento do modelo
    model.fit(x_train, y_train)
    
    # Obter a probabilidade da classe positiva (para calcular o ROC AUC)
    y_prob = model.predict_proba(x_train)[:, 1]
    
    # Calcular o ROC AUC para esta combinação de hiperparâmetros
    roc_auc = roc_auc_score(y_train, y_prob)
    
    # Retornar tanto o modelo quanto o ROC AUC
    return model, roc_auc

def treinando_avaliando_optuna(x_train, y_train, x_test, y_test):
    best_models = {}
    best_roc_auc = {}

    for name in models.keys():
        print(f"Treinando modelo com Optuna: {name}")

        # Otimização de hiperparâmetros com Optuna
        study = optuna.create_study(direction="maximize")  # Maximizar o ROC AUC
        study.optimize(lambda trial: objective(trial, name, x_train, y_train)[1], n_trials=10)  # Aqui estamos otimizar apenas o ROC AUC

        # Obter o melhor modelo do estudo
        best_model, best_roc = objective(study.best_trial, name, x_train, y_train)
        best_models[name] = best_model
        best_roc_auc[name] = best_roc
        
        print(f"Melhores parâmetros para {name}: {study.best_params}\n")

    # Avaliação final no conjunto de teste
    results = []
    for name, model in best_models.items():
        y_pred = model.predict(x_test)
        y_prob = model.predict_proba(x_test)[:, 1]
        results.append({
            'Model': name,
            'Accuracy': accuracy_score(y_test, y_pred),
            'Precision': precision_score(y_test, y_pred),
            'Recall': recall_score(y_test, y_pred),
            'F1 Score': f1_score(y_test, y_pred),
            'ROC AUC': roc_auc_score(y_test, y_prob)
        })
    
    return results, models

# %% [markdown]
# ### Modelo 1

# %%
results_m1, models_m1 = treinando_avaliando_optuna(X_train_m1, y_train_m1, X_test_m1, y_test_m1)
results_m1_df = pd.DataFrame(results_m1)
print(results_m1_df.sort_values(by='ROC AUC', ascending=False))
# Out:
# [I 2025-03-05 14:36:29,738] A new study created in memory with name: no-name-ef3421db-6fbc-4c1e-8429-fda07d543aef
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:29,774] Trial 0 finished with value: 0.7068672091412742 and parameters: {'C': 0.18527965831729878}. Best is trial 0 with value: 0.7068672091412742.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:29,816] Trial 1 finished with value: 0.7078021121883656 and parameters: {'C': 0.7378518824757898}. Best is trial 1 with value: 0.7078021121883656.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:29,918] Trial 2 finished with value: 0.7078471260387811 and parameters: {'C': 0.5904193056818821}. Best is trial 2 with value: 0.7078471260387811.
# Treinando modelo com Optuna: Logistic Regression
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:29,946] Trial 3 finished with value: 0.7078073060941829 and parameters: {'C': 1.5408788746017057}. Best is trial 2 with value: 0.7078471260387811.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:29,993] Trial 4 finished with value: 0.7078384695290858 and parameters: {'C': 2.9284340320406517}. Best is trial 2 with value: 0.7078471260387811.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:30,044] Trial 5 finished with value: 0.7081604916897508 and parameters: {'C': 0.3046158021597568}. Best is trial 5 with value: 0.7081604916897508.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:30,082] Trial 6 finished with value: 0.7073104224376732 and parameters: {'C': 0.14593624723979626}. Best is trial 5 with value: 0.7081604916897508.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:30,130] Trial 7 finished with value: 0.7062837603878116 and parameters: {'C': 0.03456517341725918}. Best is trial 5 with value: 0.7081604916897508.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:30,167] Trial 8 finished with value: 0.7055427631578948 and parameters: {'C': 0.023814706626911614}. Best is trial 5 with value: 0.7081604916897508.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:30,202] Trial 9 finished with value: 0.7060898545706371 and parameters: {'C': 0.03084332041918865}. Best is trial 5 with value: 0.7081604916897508.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8876\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:36:30,226] A new study created in memory with name: no-name-ff5be899-1cc2-4f4d-a06c-336db80673b3
# [I 2025-03-05 14:36:30,245] Trial 0 finished with value: 0.7647654085872577 and parameters: {'max_depth': 7}. Best is trial 0 with value: 0.7647654085872577.
# [I 2025-03-05 14:36:30,264] Trial 1 finished with value: 0.8027319944598338 and parameters: {'max_depth': 9}. Best is trial 1 with value: 0.8027319944598338.
# [I 2025-03-05 14:36:30,282] Trial 2 finished with value: 0.7669546398891968 and parameters: {'max_depth': 7}. Best is trial 1 with value: 0.8027319944598338.
# [I 2025-03-05 14:36:30,301] Trial 3 finished with value: 0.8027319944598338 and parameters: {'max_depth': 9}. Best is trial 1 with value: 0.8027319944598338.
# [I 2025-03-05 14:36:30,319] Trial 4 finished with value: 0.7494494459833796 and parameters: {'max_depth': 6}. Best is trial 1 with value: 0.8027319944598338.
# [I 2025-03-05 14:36:30,328] Trial 5 finished with value: 0.7667737188365652 and parameters: {'max_depth': 7}. Best is trial 1 with value: 0.8027319944598338.
# [I 2025-03-05 14:36:30,354] Trial 6 finished with value: 0.8026688019390581 and parameters: {'max_depth': 9}. Best is trial 1 with value: 0.8027319944598338.
# [I 2025-03-05 14:36:30,368] Trial 7 finished with value: 0.8015174861495845 and parameters: {'max_depth': 9}. Best is trial 1 with value: 0.8027319944598338.
# [I 2025-03-05 14:36:30,388] Trial 8 finished with value: 0.7494494459833796 and parameters: {'max_depth': 6}. Best is trial 1 with value: 0.8027319944598338.
# [I 2025-03-05 14:36:30,405] Trial 9 finished with value: 0.7365157548476453 and parameters: {'max_depth': 5}. Best is trial 1 with value: 0.8027319944598338.
# Melhores parâmetros para Logistic Regression: {'C': 0.3046158021597568}
#
# Treinando modelo com Optuna: Decision Tree
# [I 2025-03-05 14:36:30,419] A new study created in memory with name: no-name-47d1a475-29e1-4e02-a925-84cb4ac129bd
# Melhores parâmetros para Decision Tree: {'max_depth': 9}
#
# Treinando modelo com Optuna: Random Forest
# [I 2025-03-05 14:36:32,174] Trial 0 finished with value: 0.8113356994459835 and parameters: {'n_estimators': 400, 'max_depth': 10, 'min_samples_split': 7}. Best is trial 0 with value: 0.8113356994459835.
# [I 2025-03-05 14:36:33,811] Trial 1 finished with value: 0.7974333448753462 and parameters: {'n_estimators': 400, 'max_depth': 9, 'min_samples_split': 10}. Best is trial 0 with value: 0.8113356994459835.
# [I 2025-03-05 14:36:34,645] Trial 2 finished with value: 0.8167962257617729 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 2 with value: 0.8167962257617729.
# [I 2025-03-05 14:36:36,426] Trial 3 finished with value: 0.7415555747922438 and parameters: {'n_estimators': 500, 'max_depth': 5, 'min_samples_split': 10}. Best is trial 2 with value: 0.8167962257617729.
# [I 2025-03-05 14:36:37,311] Trial 4 finished with value: 0.8072117382271469 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 8}. Best is trial 2 with value: 0.8167962257617729.
# [I 2025-03-05 14:36:38,332] Trial 5 finished with value: 0.7966975415512465 and parameters: {'n_estimators': 300, 'max_depth': 8, 'min_samples_split': 5}. Best is trial 2 with value: 0.8167962257617729.
# [I 2025-03-05 14:36:39,344] Trial 6 finished with value: 0.7287508656509696 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 8}. Best is trial 2 with value: 0.8167962257617729.
# [I 2025-03-05 14:36:41,139] Trial 7 finished with value: 0.7583994113573407 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 8}. Best is trial 2 with value: 0.8167962257617729.
# [I 2025-03-05 14:36:41,977] Trial 8 finished with value: 0.7188339681440443 and parameters: {'n_estimators': 300, 'max_depth': 3, 'min_samples_split': 7}. Best is trial 2 with value: 0.8167962257617729.
# [I 2025-03-05 14:36:42,865] Trial 9 finished with value: 0.7567122576177285 and parameters: {'n_estimators': 300, 'max_depth': 6, 'min_samples_split': 9}. Best is trial 2 with value: 0.8167962257617729.
# [I 2025-03-05 14:36:43,584] A new study created in memory with name: no-name-3a7c2d1f-1b26-4e77-b4f0-74dc41d46d67
# Melhores parâmetros para Random Forest: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 5}
#
# Treinando modelo com Optuna: XGBoost
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:44,091] Trial 0 finished with value: 0.8049584487534627 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.05782055703408072, 'subsample': 0.896609069455401, 'colsample_bytree': 0.8788307794677079, 'gamma': 0.3552998174638711}. Best is trial 0 with value: 0.8049584487534627.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:44,657] Trial 1 finished with value: 0.8218836565096953 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.06149508896712058, 'subsample': 0.8326056324671673, 'colsample_bytree': 0.9169543759693903, 'gamma': 0.3127047954305586}. Best is trial 1 with value: 0.8218836565096953.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:44,924] Trial 2 finished with value: 0.7805574792243767 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.08882501547665489, 'subsample': 0.7907552335759945, 'colsample_bytree': 0.9708990482240102, 'gamma': 0.49289786831393095}. Best is trial 1 with value: 0.8218836565096953.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:45,678] Trial 3 finished with value: 0.8301843836565097 and parameters: {'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.05057844243391746, 'subsample': 0.9419722482707371, 'colsample_bytree': 0.8371308056264056, 'gamma': 0.05592188669459763}. Best is trial 3 with value: 0.8301843836565097.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:45,832] Trial 4 finished with value: 0.771565962603878 and parameters: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.09631806736945868, 'subsample': 0.7811027188819943, 'colsample_bytree': 0.7239929558970625, 'gamma': 0.25376553268853924}. Best is trial 3 with value: 0.8301843836565097.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:46,057] Trial 5 finished with value: 0.7915157548476455 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.036817203653159894, 'subsample': 0.9531114522015884, 'colsample_bytree': 0.9867643725698152, 'gamma': 0.2326656699908632}. Best is trial 3 with value: 0.8301843836565097.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:46,624] Trial 6 finished with value: 0.8288227146814404 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.056772148466220335, 'subsample': 0.804203298039369, 'colsample_bytree': 0.9970707779137604, 'gamma': 0.15540773560958177}. Best is trial 3 with value: 0.8301843836565097.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:46,910] Trial 7 finished with value: 0.7662898199445983 and parameters: {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.04149792205934688, 'subsample': 0.9651736324530527, 'colsample_bytree': 0.7806194895366834, 'gamma': 0.38929605089392016}. Best is trial 3 with value: 0.8301843836565097.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:47,599] Trial 8 finished with value: 0.8171892313019391 and parameters: {'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.06367479450530741, 'subsample': 0.8010789804214262, 'colsample_bytree': 0.8581176784260026, 'gamma': 0.4718443068579526}. Best is trial 3 with value: 0.8301843836565097.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:48,189] Trial 9 finished with value: 0.8305211218836566 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.08260761120467468, 'subsample': 0.9438409094267968, 'colsample_bytree': 0.8728756022307375, 'gamma': 0.10106557922601878}. Best is trial 9 with value: 0.8305211218836566.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:36:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:36:48,742] A new study created in memory with name: no-name-e72bde59-42fc-4d58-8e5e-a576bd880f8a
# Melhores parâmetros para XGBoost: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.08260761120467468, 'subsample': 0.9438409094267968, 'colsample_bytree': 0.8728756022307375, 'gamma': 0.10106557922601878}
#
# Treinando modelo com Optuna: LightGBM
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000259 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:36:49,041] Trial 0 finished with value: 0.7909565443213297 and parameters: {'n_estimators': 300, 'learning_rate': 0.048099840048025665, 'num_leaves': 21, 'min_child_samples': 26}. Best is trial 0 with value: 0.7909565443213297.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000848 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-03-05 14:36:49,622] Trial 1 finished with value: 0.7810353185595568 and parameters: {'n_estimators': 300, 'learning_rate': 0.022749427723117225, 'num_leaves': 40, 'min_child_samples': 25}. Best is trial 0 with value: 0.7909565443213297.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000288 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:36:50,947] Trial 2 finished with value: 0.8197039473684209 and parameters: {'n_estimators': 500, 'learning_rate': 0.04170011080027563, 'num_leaves': 35, 'min_child_samples': 18}. Best is trial 2 with value: 0.8197039473684209.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000908 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:36:51,790] Trial 3 finished with value: 0.8197342451523546 and parameters: {'n_estimators': 300, 'learning_rate': 0.09443087722587332, 'num_leaves': 20, 'min_child_samples': 13}. Best is trial 3 with value: 0.8197342451523546.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.089614 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:36:52,776] Trial 4 finished with value: 0.7997195290858725 and parameters: {'n_estimators': 200, 'learning_rate': 0.06572785345614823, 'num_leaves': 31, 'min_child_samples': 24}. Best is trial 3 with value: 0.8197342451523546.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000377 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:36:53,027] Trial 5 finished with value: 0.7888201177285318 and parameters: {'n_estimators': 200, 'learning_rate': 0.06916303330752223, 'num_leaves': 21, 'min_child_samples': 28}. Best is trial 3 with value: 0.8197342451523546.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000367 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:36:53,395] Trial 6 finished with value: 0.7993784626038782 and parameters: {'n_estimators': 300, 'learning_rate': 0.056158651186731724, 'num_leaves': 22, 'min_child_samples': 22}. Best is trial 3 with value: 0.8197342451523546.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000472 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:36:53,722] Trial 7 finished with value: 0.8104622576177285 and parameters: {'n_estimators': 300, 'learning_rate': 0.07824801374237737, 'num_leaves': 29, 'min_child_samples': 25}. Best is trial 3 with value: 0.8197342451523546.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000313 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:36:54,206] Trial 8 finished with value: 0.8124783587257618 and parameters: {'n_estimators': 400, 'learning_rate': 0.032108116279640976, 'num_leaves': 26, 'min_child_samples': 11}. Best is trial 3 with value: 0.8197342451523546.
# [I 2025-03-05 14:36:54,378] Trial 9 finished with value: 0.8098563019390581 and parameters: {'n_estimators': 100, 'learning_rate': 0.0996546461027519, 'num_leaves': 38, 'min_child_samples': 16}. Best is trial 3 with value: 0.8197342451523546.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000403 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 153
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Melhores parâmetros para LightGBM: {'n_estimators': 300, 'learning_rate': 0.09443087722587332, 'num_leaves': 20, 'min_child_samples': 13}
#
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 0  Logistic Regression  0.664537   0.715736  0.742105  0.728682  0.694651
# 3              XGBoost  0.626198   0.678049  0.731579  0.703797  0.647283
# 2        Random Forest  0.591054   0.666667  0.652632  0.659574  0.644801
# 4             LightGBM  0.607029   0.670051  0.694737  0.682171  0.639966
# 1        Decision Tree  0.555911   0.658385  0.557895  0.603989  0.586222

# %%
best_model_name = results_m1_df.sort_values(by='ROC AUC', ascending=False).iloc[0]['Model']
best_model_m1 = models_m1[best_model_name]

# %%
# Treinando o modelo
best_model_m1.fit(X_train_m1, y_train_m1)

# Fazendo previsões no conjunto de teste
y_pred = best_model_m1.predict(X_test_m1)

# Imprimindo o relatório de classificação
print(classification_report(y_test_m1, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.54      0.56       123
#            1       0.72      0.74      0.73       190
#
#     accuracy                           0.66       313
#    macro avg       0.65      0.64      0.64       313
# weighted avg       0.66      0.66      0.66       313

# %%
import shap

shap.initjs() #habilitando a visualização dos gráficos
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
explainer = shap.KernelExplainer(best_model_m1.predict, 
                           X_test_m1)

shap_values = explainer(X_test_m1)
# Out:
# Using 313 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/313 [00:00<?, ?it/s]

# %%
#Definido dicionário com nome das variáveis
nome_variaveis = {
    'num__anos_formacao': 'Anos de Formação',
    'num__idade': 'Idade',
    'num__m_enfermeiro': 'Média de Enfermeiros',
    'num__media_vinculos_mes': 'Média de vínculos por mês',
    'num__m_dentista': 'Média de Cirurgiões-Dentistas',
    'num__m_tec_aux_enf': 'Média de Técnicos/Auxiliares de Enfermagem',
    'num__m_agente_saude': 'Média de Agentes de Saúde',
    'cat__atuacao_previa_no_municipio_Sim': 'Atuação Prévia no Município',
    'num__anos_atuacao_previa_no_municipio': 'Anos de atuação prévia no município',
    'num__populacao': 'População',
    'num__taxa_homicidio': 'Taxa de homicídios',
    'num__orcamento_saude': 'Orçamento em saúde',
    'num__variacao_pib': 'Variação do PIB',
    'num__equipamentos_esportivos': 'Equipamentos esportivos',
    'num__investimento_infraestrutura': 'Investimento em infraestrutura',
    'num__esgotamento_sanitario': 'Esgotamento sanitário',
    'num__distancia_capital': 'Distância até a capital',
    'cat__porte_MP': 'Município de Médio Porte',
    'num__pib_percapita': 'PIB per capita',
    'num__equipamentos_culturais': 'Equipamentos culturais',
    'num__ideb_anosfinais': 'IDEB Anos Finais',
    'cat__porte_PP-II': 'Municícipio de Pequeno Porte II',
    'cat__Prorrogado_SIM': 'Prorrogação',
    'num__tx_pop_ocupada_2019': 'Taxa de população ocupada',
    'cat__regiao_destino_Norte': 'Região Norte',
    'cat__regiao_destino_Nordeste': 'Região Nordeste',
    'cat__regiao_destino_Sul': 'Região Sul',
    'cat__regiao_destino_Sudeste': 'Região Sudeste'
}

feature_nomes_ajust = [nome_variaveis.get(nome, nome) for nome in feature_names]

# %%
#Recuperando o nome das variáveis
feature_names = preprocessor_m1.get_feature_names_out()

shap.summary_plot(shap_values, features= X_train_m1, 
                  feature_names= feature_nomes_ajust, 
                  plot_type="bar")

# %% [markdown]
# ### Modelo 2

# %%
results_m2, models_m2 = treinando_avaliando_optuna(X_train_m2, y_train_m2, X_test_m2, y_test_m2)
results_m2_df = pd.DataFrame(results_m2)
print(results_m2_df.sort_values(by='ROC AUC', ascending=False))
# Out:
# [I 2025-03-05 14:55:19,367] A new study created in memory with name: no-name-e289fc35-9059-4096-925e-5d4f2df3c0f0
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,396] Trial 0 finished with value: 0.7242711218836565 and parameters: {'C': 0.030791733337389517}. Best is trial 0 with value: 0.7242711218836565.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,412] Trial 1 finished with value: 0.7252060249307479 and parameters: {'C': 6.248375514803472}. Best is trial 1 with value: 0.7252060249307479.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,443] Trial 2 finished with value: 0.7249722991689751 and parameters: {'C': 0.11763213099157546}. Best is trial 1 with value: 0.7252060249307479.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,467] Trial 3 finished with value: 0.7249826869806094 and parameters: {'C': 0.12246794662925722}. Best is trial 1 with value: 0.7252060249307479.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,497] Trial 4 finished with value: 0.724406163434903 and parameters: {'C': 0.035250458688707194}. Best is trial 1 with value: 0.7252060249307479.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,531] Trial 5 finished with value: 0.7246762465373962 and parameters: {'C': 0.04551222986863983}. Best is trial 1 with value: 0.7252060249307479.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,559] Trial 6 finished with value: 0.7251696675900278 and parameters: {'C': 3.1537104709037687}. Best is trial 1 with value: 0.7252060249307479.
# Treinando modelo com Optuna: Logistic Regression
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,590] Trial 7 finished with value: 0.7251627423822715 and parameters: {'C': 0.3140378647556174}. Best is trial 1 with value: 0.7252060249307479.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,623] Trial 8 finished with value: 0.7251644736842107 and parameters: {'C': 1.0413314437544077}. Best is trial 1 with value: 0.7252060249307479.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,654] Trial 9 finished with value: 0.7246173822714681 and parameters: {'C': 0.04221169739901762}. Best is trial 1 with value: 0.7252060249307479.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 14:55:19,681] A new study created in memory with name: no-name-0023eb9e-fe84-4eae-86e3-06ee4e6d23a3
# [I 2025-03-05 14:55:19,709] Trial 0 finished with value: 0.8240581717451523 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.8240581717451523.
# [I 2025-03-05 14:55:19,739] Trial 1 finished with value: 0.8240581717451523 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.8240581717451523.
# [I 2025-03-05 14:55:19,763] Trial 2 finished with value: 0.7942520775623269 and parameters: {'max_depth': 4}. Best is trial 0 with value: 0.8240581717451523.
# [I 2025-03-05 14:55:19,787] Trial 3 finished with value: 0.8240581717451523 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.8240581717451523.
# [I 2025-03-05 14:55:19,814] Trial 4 finished with value: 0.8585534972299169 and parameters: {'max_depth': 6}. Best is trial 4 with value: 0.8585534972299169.
# [I 2025-03-05 14:55:19,840] Trial 5 finished with value: 0.8905306440443214 and parameters: {'max_depth': 7}. Best is trial 5 with value: 0.8905306440443214.
# [I 2025-03-05 14:55:19,868] Trial 6 finished with value: 0.8905306440443214 and parameters: {'max_depth': 7}. Best is trial 5 with value: 0.8905306440443214.
# Melhores parâmetros para Logistic Regression: {'C': 6.248375514803472}
#
# Treinando modelo com Optuna: Decision Tree
# [I 2025-03-05 14:55:19,887] Trial 7 finished with value: 0.7666317520775623 and parameters: {'max_depth': 3}. Best is trial 5 with value: 0.8905306440443214.
# [I 2025-03-05 14:55:19,907] Trial 8 finished with value: 0.7666317520775623 and parameters: {'max_depth': 3}. Best is trial 5 with value: 0.8905306440443214.
# [I 2025-03-05 14:55:19,932] Trial 9 finished with value: 0.9461279432132964 and parameters: {'max_depth': 9}. Best is trial 9 with value: 0.9461279432132964.
# [I 2025-03-05 14:55:19,955] A new study created in memory with name: no-name-b646107a-d654-424b-9bcf-1085e3529b31
# Melhores parâmetros para Decision Tree: {'max_depth': 9}
#
# Treinando modelo com Optuna: Random Forest
# [I 2025-03-05 14:55:20,439] Trial 0 finished with value: 0.9049679709141274 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 3}. Best is trial 0 with value: 0.9049679709141274.
# [I 2025-03-05 14:55:21,532] Trial 1 finished with value: 0.8207712950138504 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 6}. Best is trial 0 with value: 0.9049679709141274.
# [I 2025-03-05 14:55:24,347] Trial 2 finished with value: 0.9054934210526315 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 2 with value: 0.9054934210526315.
# [I 2025-03-05 14:55:25,732] Trial 3 finished with value: 0.8027051592797784 and parameters: {'n_estimators': 400, 'max_depth': 3, 'min_samples_split': 2}. Best is trial 2 with value: 0.9054934210526315.
# [I 2025-03-05 14:55:26,537] Trial 4 finished with value: 0.8441282894736842 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 6}. Best is trial 2 with value: 0.9054934210526315.
# [I 2025-03-05 14:55:27,679] Trial 5 finished with value: 0.9576835180055401 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 9}. Best is trial 5 with value: 0.9576835180055401.
# [I 2025-03-05 14:55:28,747] Trial 6 finished with value: 0.8430375692520775 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 7}. Best is trial 5 with value: 0.9576835180055401.
# [I 2025-03-05 14:55:31,524] Trial 7 finished with value: 0.8659522160664821 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 10}. Best is trial 5 with value: 0.9576835180055401.
# [I 2025-03-05 14:55:33,383] Trial 8 finished with value: 0.8436037049861494 and parameters: {'n_estimators': 400, 'max_depth': 5, 'min_samples_split': 6}. Best is trial 5 with value: 0.9576835180055401.
# [I 2025-03-05 14:55:34,931] Trial 9 finished with value: 0.9765114265927979 and parameters: {'n_estimators': 300, 'max_depth': 10, 'min_samples_split': 3}. Best is trial 9 with value: 0.9765114265927979.
# [I 2025-03-05 14:55:36,463] A new study created in memory with name: no-name-2f0731ec-8b9a-4878-8f1b-eac8a1e99e79
# Melhores parâmetros para Random Forest: {'n_estimators': 300, 'max_depth': 10, 'min_samples_split': 3}
#
# Treinando modelo com Optuna: XGBoost
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:37,297] Trial 0 finished with value: 0.9964014889196676 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.029742311374352105, 'subsample': 0.8739059386496026, 'colsample_bytree': 0.7112774744090378, 'gamma': 0.03848942626672147}. Best is trial 0 with value: 0.9964014889196676.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:37,599] Trial 1 finished with value: 0.9891629155124654 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.08119558669419016, 'subsample': 0.9854858061484285, 'colsample_bytree': 0.932425399576308, 'gamma': 0.4041572317138483}. Best is trial 0 with value: 0.9964014889196676.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:38,514] Trial 2 finished with value: 0.9997913781163434 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.062121443527447806, 'subsample': 0.9113241088627378, 'colsample_bytree': 0.7888376350236618, 'gamma': 0.044766957819775244}. Best is trial 2 with value: 0.9997913781163434.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:39,222] Trial 3 finished with value: 0.9738131925207756 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.019012606160091566, 'subsample': 0.7828309173171386, 'colsample_bytree': 0.7025821115080888, 'gamma': 0.0216212616846862}. Best is trial 2 with value: 0.9997913781163434.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:39,533] Trial 4 finished with value: 0.9230730609418282 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.058478374033885276, 'subsample': 0.819667857567035, 'colsample_bytree': 0.9755610118353591, 'gamma': 0.3160333134618213}. Best is trial 2 with value: 0.9997913781163434.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:39,833] Trial 5 finished with value: 0.9829994806094182 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.04386822221857193, 'subsample': 0.7728397421235268, 'colsample_bytree': 0.7383722488923755, 'gamma': 0.07434532000687816}. Best is trial 2 with value: 0.9997913781163434.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:40,356] Trial 6 finished with value: 0.99920966066482 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.06580613591809954, 'subsample': 0.7840398528839345, 'colsample_bytree': 0.8374071786031528, 'gamma': 0.0749146632530529}. Best is trial 2 with value: 0.9997913781163434.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:41,133] Trial 7 finished with value: 0.9992667936288089 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.056149263281725814, 'subsample': 0.8089244660877681, 'colsample_bytree': 0.7252744631644922, 'gamma': 0.3105443513754539}. Best is trial 2 with value: 0.9997913781163434.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:41,726] Trial 8 finished with value: 0.9820524584487536 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.017098122849519826, 'subsample': 0.860304967430296, 'colsample_bytree': 0.8061051639704544, 'gamma': 0.1109085516689361}. Best is trial 2 with value: 0.9997913781163434.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:42,017] Trial 9 finished with value: 0.9961885387811634 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.0805104715842001, 'subsample': 0.8616214892389803, 'colsample_bytree': 0.8384319827413624, 'gamma': 0.48529794120494163}. Best is trial 2 with value: 0.9997913781163434.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:55:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 14:55:42,956] A new study created in memory with name: no-name-bccde79f-91b6-41f0-ba86-357797e7c9fe
# Melhores parâmetros para XGBoost: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.062121443527447806, 'subsample': 0.9113241088627378, 'colsample_bytree': 0.7888376350236618, 'gamma': 0.044766957819775244}
#
# Treinando modelo com Optuna: LightGBM
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000255 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:43,749] Trial 0 finished with value: 0.9800969529085873 and parameters: {'n_estimators': 500, 'learning_rate': 0.01548980278603141, 'num_leaves': 26, 'min_child_samples': 24}. Best is trial 0 with value: 0.9800969529085873.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001421 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:44,406] Trial 1 finished with value: 0.9998840027700832 and parameters: {'n_estimators': 300, 'learning_rate': 0.06532925190869107, 'num_leaves': 31, 'min_child_samples': 10}. Best is trial 1 with value: 0.9998840027700832.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002280 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:45,466] Trial 2 finished with value: 0.9999515235457064 and parameters: {'n_estimators': 400, 'learning_rate': 0.05862831894342634, 'num_leaves': 37, 'min_child_samples': 26}. Best is trial 2 with value: 0.9999515235457064.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000900 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:45,970] Trial 3 finished with value: 0.9969641620498614 and parameters: {'n_estimators': 200, 'learning_rate': 0.040379554971791694, 'num_leaves': 35, 'min_child_samples': 13}. Best is trial 2 with value: 0.9999515235457064.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001386 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:46,908] Trial 4 finished with value: 0.9845654432132963 and parameters: {'n_estimators': 400, 'learning_rate': 0.020521847724501517, 'num_leaves': 29, 'min_child_samples': 30}. Best is trial 2 with value: 0.9999515235457064.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000923 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:47,842] Trial 5 finished with value: 0.999970567867036 and parameters: {'n_estimators': 500, 'learning_rate': 0.08597094513208858, 'num_leaves': 24, 'min_child_samples': 24}. Best is trial 5 with value: 0.999970567867036.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002310 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:48,330] Trial 6 finished with value: 0.9566940789473686 and parameters: {'n_estimators': 200, 'learning_rate': 0.018827875465741488, 'num_leaves': 29, 'min_child_samples': 17}. Best is trial 5 with value: 0.999970567867036.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000777 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:48,601] Trial 7 finished with value: 0.9707686980609418 and parameters: {'n_estimators': 100, 'learning_rate': 0.045498955572759466, 'num_leaves': 38, 'min_child_samples': 27}. Best is trial 5 with value: 0.999970567867036.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006850 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:49,432] Trial 8 finished with value: 0.9999774930747922 and parameters: {'n_estimators': 400, 'learning_rate': 0.07887304220576302, 'num_leaves': 28, 'min_child_samples': 16}. Best is trial 8 with value: 0.9999774930747922.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002381 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 14:55:50,061] Trial 9 finished with value: 0.9987586565096953 and parameters: {'n_estimators': 300, 'learning_rate': 0.05027639172535031, 'num_leaves': 29, 'min_child_samples': 23}. Best is trial 8 with value: 0.9999774930747922.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000990 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1140
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Melhores parâmetros para LightGBM: {'n_estimators': 400, 'learning_rate': 0.07887304220576302, 'num_leaves': 28, 'min_child_samples': 16}
#
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 2        Random Forest  0.696486   0.751323  0.747368  0.749340  0.757980
# 3              XGBoost  0.683706   0.735751  0.747368  0.741514  0.753744
# 4             LightGBM  0.670927   0.723077  0.742105  0.732468  0.740180
# 0  Logistic Regression  0.690096   0.746032  0.742105  0.744063  0.715747
# 1        Decision Tree  0.686901   0.787500  0.663158  0.720000  0.698652

# %%
#Escolhendo o modelo
best_model_name = results_m2_df.sort_values(by='ROC AUC', ascending=False).iloc[0]['Model']
best_model_m2 = models_m2[best_model_name]

# %%
# Treinando o modelo
best_model_m2.fit(X_train_m2, y_train_m2)

# Fazendo previsões no conjunto de teste
y_pred = best_model_m2.predict(X_test_m2)

# Imprimindo o relatório de classificação
print(classification_report(y_test_m2, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.59      0.60       123
#            1       0.74      0.76      0.75       190
#
#     accuracy                           0.69       313
#    macro avg       0.68      0.67      0.68       313
# weighted avg       0.69      0.69      0.69       313

# %%
explainer = shap.Explainer(best_model_m2.predict, 
                           X_test_m2)

shap_values = explainer(X_test_m2)
# Out:
# PermutationExplainer explainer: 314it [03:04,  1.67it/s]

# %%
#Recuperando o nome das variáveis
feature_names = preprocessor_m2.get_feature_names_out()

shap.summary_plot(shap_values, features= X_train_m2, 
                  feature_names= feature_nomes_ajust, 
                  plot_type="bar",
                 max_display = 10)

# %% [markdown]
# ### Modelo 3

# %%
results_m3, models_m3 = treinando_avaliando_optuna(X_train_m3, y_train_m3, X_test_m3, y_test_m3)
results_m3_df = pd.DataFrame(results_m3)
print(results_m3_df.sort_values(by='ROC AUC', ascending=False))
# Out:
# [I 2025-03-05 15:05:52,314] A new study created in memory with name: no-name-1662e1c5-3cf1-42fa-9bf1-6d83fcf1047c
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:52,343] Trial 0 finished with value: 0.7275761772853185 and parameters: {'C': 0.01050507850122971}. Best is trial 0 with value: 0.7275761772853185.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:52,380] Trial 1 finished with value: 0.7343265235457063 and parameters: {'C': 5.171432331860726}. Best is trial 1 with value: 0.7343265235457063.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:52,420] Trial 2 finished with value: 0.7337292243767313 and parameters: {'C': 0.14226362086611247}. Best is trial 1 with value: 0.7343265235457063.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:52,467] Trial 3 finished with value: 0.7344113573407202 and parameters: {'C': 0.2622142300915825}. Best is trial 3 with value: 0.7344113573407202.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:52,509] Trial 4 finished with value: 0.7335786011080332 and parameters: {'C': 0.12595867893637355}. Best is trial 3 with value: 0.7344113573407202.
# Treinando modelo com Optuna: Logistic Regression
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:52,969] Trial 5 finished with value: 0.7345394736842106 and parameters: {'C': 0.2936431088132354}. Best is trial 5 with value: 0.7345394736842106.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:53,106] Trial 6 finished with value: 0.7345100415512464 and parameters: {'C': 0.30970638546491397}. Best is trial 5 with value: 0.7345394736842106.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:53,137] Trial 7 finished with value: 0.7343784626038782 and parameters: {'C': 3.953087568361065}. Best is trial 5 with value: 0.7345394736842106.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:53,180] Trial 8 finished with value: 0.7327614265927977 and parameters: {'C': 0.08223580114120327}. Best is trial 5 with value: 0.7345394736842106.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:53,217] Trial 9 finished with value: 0.7299497922437672 and parameters: {'C': 0.020887452406197965}. Best is trial 5 with value: 0.7345394736842106.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:05:53,260] A new study created in memory with name: no-name-66044f2b-9082-452b-8501-e2c53f260e81
# [I 2025-03-05 15:05:53,306] Trial 0 finished with value: 0.7720515927977839 and parameters: {'max_depth': 3}. Best is trial 0 with value: 0.7720515927977839.
# [I 2025-03-05 15:05:53,353] Trial 1 finished with value: 0.8385915858725761 and parameters: {'max_depth': 5}. Best is trial 1 with value: 0.8385915858725761.
# [I 2025-03-05 15:05:53,402] Trial 2 finished with value: 0.8016542590027701 and parameters: {'max_depth': 4}. Best is trial 1 with value: 0.8385915858725761.
# [I 2025-03-05 15:05:53,442] Trial 3 finished with value: 0.8016542590027701 and parameters: {'max_depth': 4}. Best is trial 1 with value: 0.8385915858725761.
# Melhores parâmetros para Logistic Regression: {'C': 0.2936431088132354}
#
# Treinando modelo com Optuna: Decision Tree
# [I 2025-03-05 15:05:53,503] Trial 4 finished with value: 0.9763331024930748 and parameters: {'max_depth': 9}. Best is trial 4 with value: 0.9763331024930748.
# [I 2025-03-05 15:05:53,542] Trial 5 finished with value: 0.8016542590027701 and parameters: {'max_depth': 4}. Best is trial 4 with value: 0.9763331024930748.
# [I 2025-03-05 15:05:53,586] Trial 6 finished with value: 0.9236989265927978 and parameters: {'max_depth': 7}. Best is trial 4 with value: 0.9763331024930748.
# [I 2025-03-05 15:05:53,651] Trial 7 finished with value: 0.9236989265927978 and parameters: {'max_depth': 7}. Best is trial 4 with value: 0.9763331024930748.
# [I 2025-03-05 15:05:53,703] Trial 8 finished with value: 0.9236989265927978 and parameters: {'max_depth': 7}. Best is trial 4 with value: 0.9763331024930748.
# [I 2025-03-05 15:05:53,759] Trial 9 finished with value: 0.9236989265927978 and parameters: {'max_depth': 7}. Best is trial 4 with value: 0.9763331024930748.
# [I 2025-03-05 15:05:53,802] A new study created in memory with name: no-name-b672273a-62ce-4238-adbc-6bd5c4403695
# Melhores parâmetros para Decision Tree: {'max_depth': 9}
#
# Treinando modelo com Optuna: Random Forest
# [I 2025-03-05 15:05:55,759] Trial 0 finished with value: 0.8852709487534626 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 6}. Best is trial 0 with value: 0.8852709487534626.
# [I 2025-03-05 15:05:56,863] Trial 1 finished with value: 0.877082756232687 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 0 with value: 0.8852709487534626.
# [I 2025-03-05 15:06:00,229] Trial 2 finished with value: 0.9716932132963989 and parameters: {'n_estimators': 300, 'max_depth': 8, 'min_samples_split': 5}. Best is trial 2 with value: 0.9716932132963989.
# [I 2025-03-05 15:06:01,100] Trial 3 finished with value: 0.9665053670360111 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 8}. Best is trial 2 with value: 0.9716932132963989.
# [I 2025-03-05 15:06:02,168] Trial 4 finished with value: 0.8205791204986149 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 2}. Best is trial 2 with value: 0.9716932132963989.
# [I 2025-03-05 15:06:02,955] Trial 5 finished with value: 0.9859002770083103 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 5 with value: 0.9859002770083103.
# [I 2025-03-05 15:06:04,387] Trial 6 finished with value: 0.9639768005540166 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 8}. Best is trial 5 with value: 0.9859002770083103.
# [I 2025-03-05 15:06:04,968] Trial 7 finished with value: 0.8766404085872576 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 10}. Best is trial 5 with value: 0.9859002770083103.
# [I 2025-03-05 15:06:05,972] Trial 8 finished with value: 0.8466378116343491 and parameters: {'n_estimators': 200, 'max_depth': 4, 'min_samples_split': 5}. Best is trial 5 with value: 0.9859002770083103.
# [I 2025-03-05 15:06:09,437] Trial 9 finished with value: 0.9174809556786704 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 5 with value: 0.9859002770083103.
# [I 2025-03-05 15:06:10,282] A new study created in memory with name: no-name-f892dc97-2521-4755-97a3-da8b18d80b18
# Melhores parâmetros para Random Forest: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 4}
#
# Treinando modelo com Optuna: XGBoost
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:11,178] Trial 0 finished with value: 0.9864716066481994 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.03210385335437105, 'subsample': 0.7002637470436673, 'colsample_bytree': 0.706317653797144, 'gamma': 0.05340358421739266}. Best is trial 0 with value: 0.9864716066481994.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:12,218] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.09310466245693477, 'subsample': 0.8463969684403001, 'colsample_bytree': 0.9259139942790762, 'gamma': 0.4808424029623089}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:14,158] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 500, 'max_depth': 9, 'learning_rate': 0.0722714052168592, 'subsample': 0.7198609749191525, 'colsample_bytree': 0.9703154254322561, 'gamma': 0.21807707072291183}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:15,652] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.06586342133046268, 'subsample': 0.8007177267042802, 'colsample_bytree': 0.8796340512905317, 'gamma': 0.250705304439077}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:16,442] Trial 4 finished with value: 0.9995135041551246 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.03853467921713437, 'subsample': 0.803720585412183, 'colsample_bytree': 0.7519214377973191, 'gamma': 0.3848059263711069}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:17,280] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.09403890395501874, 'subsample': 0.8208438593943171, 'colsample_bytree': 0.8730166751947445, 'gamma': 0.4072288237175484}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:18,193] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.06535946039486347, 'subsample': 0.8021902073675524, 'colsample_bytree': 0.7888176397487878, 'gamma': 0.2774271643497563}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:18,766] Trial 7 finished with value: 0.9425112534626039 and parameters: {'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.02871184304875199, 'subsample': 0.8499747772704539, 'colsample_bytree': 0.8344060774556898, 'gamma': 0.025401586963302136}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:19,896] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.05491308829471453, 'subsample': 0.9370077454116981, 'colsample_bytree': 0.7738721957808682, 'gamma': 0.17420582367652576}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:21,195] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.07214510015304089, 'subsample': 0.9577792857803313, 'colsample_bytree': 0.8124965979811603, 'gamma': 0.06370589607797073}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:06:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:06:22,109] A new study created in memory with name: no-name-a7bd0a81-eb1f-4cd5-905d-8193764048ac
# Melhores parâmetros para XGBoost: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.09310466245693477, 'subsample': 0.8463969684403001, 'colsample_bytree': 0.9259139942790762, 'gamma': 0.4808424029623089}
#
# Treinando modelo com Optuna: LightGBM
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000923 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:23,291] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.02960080933112319, 'num_leaves': 27, 'min_child_samples': 28}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000624 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:24,478] Trial 1 finished with value: 0.9999722991689751 and parameters: {'n_estimators': 300, 'learning_rate': 0.024598307617560388, 'num_leaves': 32, 'min_child_samples': 12}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000807 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:25,830] Trial 2 finished with value: 0.9999861495844875 and parameters: {'n_estimators': 400, 'learning_rate': 0.02616341959048671, 'num_leaves': 28, 'min_child_samples': 19}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000794 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:26,449] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 200, 'learning_rate': 0.08438954027461884, 'num_leaves': 26, 'min_child_samples': 25}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000757 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:26,796] Trial 4 finished with value: 0.9993100761772854 and parameters: {'n_estimators': 100, 'learning_rate': 0.060974234038850016, 'num_leaves': 28, 'min_child_samples': 15}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000901 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:27,241] Trial 5 finished with value: 0.9999982686980609 and parameters: {'n_estimators': 100, 'learning_rate': 0.07463513000243217, 'num_leaves': 38, 'min_child_samples': 11}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000837 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:27,660] Trial 6 finished with value: 0.9999948060941828 and parameters: {'n_estimators': 100, 'learning_rate': 0.08189789234158276, 'num_leaves': 36, 'min_child_samples': 20}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000791 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-03-05 15:06:29,587] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.02020056342552745, 'num_leaves': 39, 'min_child_samples': 30}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000899 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:30,088] Trial 8 finished with value: 0.999942867036011 and parameters: {'n_estimators': 200, 'learning_rate': 0.061495192594370356, 'num_leaves': 21, 'min_child_samples': 28}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000773 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:06:30,938] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 300, 'learning_rate': 0.09288979164924271, 'num_leaves': 29, 'min_child_samples': 27}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3881
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Melhores parâmetros para LightGBM: {'n_estimators': 500, 'learning_rate': 0.02960080933112319, 'num_leaves': 27, 'min_child_samples': 28}
#
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 2        Random Forest  0.709265   0.759162  0.763158  0.761155  0.781001
# 3              XGBoost  0.741214   0.776650  0.805263  0.790698  0.775225
# 4             LightGBM  0.702875   0.751295  0.763158  0.757180  0.774283
# 0  Logistic Regression  0.670927   0.720812  0.747368  0.733850  0.716945
# 1        Decision Tree  0.635783   0.713483  0.668421  0.690217  0.627920

# %%
#Escolhendo o modelo
best_model_name = results_m3_df.sort_values(by='ROC AUC', ascending=False).iloc[0]['Model']
best_model_m3 = models_m3[best_model_name]

# %%
# Ajuste de limiar com base no conjunto de treinamento
best_model_m3.fit(X_train_m3, y_train_m3)  # Treine o modelo primeiro!

y_prob_train = best_model_m3.predict_proba(X_train_m3)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_train_m3, y_prob_train)

# Encontrar o melhor limiar com base no F1 Score
best_threshold = 0.5
best_f1 = 0
for threshold in thresholds:
    y_pred_adjusted = (y_prob_train >= threshold).astype(int)
    f1 = f1_score(y_train_m3, y_pred_adjusted)
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

print(f"Melhor limiar: {best_threshold} com F1 Score: {best_f1}")

# Matriz de Confusão com limiar ajustado no conjunto de teste
y_prob_test = best_model_m3.predict_proba(X_test_m3)[:, 1]
y_pred_adjusted = (y_prob_test >= best_threshold).astype(int)
cm_adjusted = confusion_matrix(y_test_m3, y_pred_adjusted)

plt.figure(figsize=(6, 4))
sns.heatmap(cm_adjusted, annot=True, fmt='d', cmap='Blues', xticklabels=['Permanece', 'Migrou'], yticklabels=['Permanece', 'Migrou'])
plt.xlabel('Previsto')
plt.ylabel('Real')
plt.title(f'Matriz de Confusão - Ajuste de Limiar ({best_model_name})')
plt.show()
# Out:
# Melhor limiar: 0.61 com F1 Score: 1.0

# %%
print("ROC AUC: ", roc_auc_score(y_test_m3, y_prob_test))
print("Precision: ", precision_score(y_test_m3, y_pred_adjusted))
print("Accuracy: ", accuracy_score(y_test_m3, y_pred_adjusted))
print("Recall: ", recall_score(y_test_m3, y_pred_adjusted))
print("F1 Score: ", f1_score(y_test_m3, y_pred_adjusted))
print("Houve perda da área abaixo da curva ROC e no Recall. Nas outras métricas, houve melhora")
# Out:
# ROC AUC:  0.7866495507060335
# Precision:  0.8375
# Accuracy:  0.7380191693290735
# Recall:  0.7052631578947368
# F1 Score:  0.7657142857142857
# Houve perda da área abaixo da curva ROC e no Recall. Nas outras métricas, houve melhora

# %%
# Fazendo previsões de probabilidade no conjunto de teste
y_prob_best = best_model_m3.predict_proba(X_test_m3)[:, 1]

# Ajustando as previsões com o novo limiar
y_pred_adjusted = (y_prob_best >= best_threshold).astype(int)

# Imprimindo o relatório de classificação com o limiar ajustado
print(classification_report(y_test_m3, y_pred_adjusted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.79      0.70       123
#            1       0.84      0.71      0.77       190
#
#     accuracy                           0.74       313
#    macro avg       0.74      0.75      0.73       313
# weighted avg       0.76      0.74      0.74       313

# %%
explainer = shap.Explainer(best_model_m3.predict, 
                           X_test_m3)

shap_values = explainer(X_test_m3)
# Out:
# PermutationExplainer explainer: 314it [02:33,  1.92it/s]

# %%
#Recuperando o nome das variáveis
feature_names = preprocessor_m3.get_feature_names_out()

#Gerando o gráfico
shap.summary_plot(shap_values, features= X_train_m3, 
                  feature_names= feature_nomes_ajust, 
                  plot_type="bar")

# %% [markdown]
# ### Modelo 4

# %%
results_m4, models_m4 = treinando_avaliando_optuna(X_train_m4, y_train_m4, X_test_m4, y_test_m4)
results_m4_df = pd.DataFrame(results_m4)
print(results_m4_df.sort_values(by='ROC AUC', ascending=False))
# Out:
# [I 2025-03-05 15:16:23,064] A new study created in memory with name: no-name-3022829d-cbc8-4d89-a30d-e1b4e66f34eb
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,092] Trial 0 finished with value: 0.8638469529085873 and parameters: {'C': 0.4236726570185174}. Best is trial 0 with value: 0.8638469529085873.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,122] Trial 1 finished with value: 0.8642745844875346 and parameters: {'C': 2.138776772365831}. Best is trial 1 with value: 0.8642745844875346.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,171] Trial 2 finished with value: 0.8638002077562327 and parameters: {'C': 0.39678512232888763}. Best is trial 1 with value: 0.8642745844875346.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,195] Trial 3 finished with value: 0.8634608725761773 and parameters: {'C': 0.29489515323202514}. Best is trial 1 with value: 0.8642745844875346.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,228] Trial 4 finished with value: 0.8529432132963989 and parameters: {'C': 0.012074219199040758}. Best is trial 1 with value: 0.8642745844875346.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,238] Trial 5 finished with value: 0.8547091412742381 and parameters: {'C': 0.014440363856896562}. Best is trial 1 with value: 0.8642745844875346.
# Treinando modelo com Optuna: Logistic Regression
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,300] Trial 6 finished with value: 0.862917243767313 and parameters: {'C': 0.17098888631373763}. Best is trial 1 with value: 0.8642745844875346.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,335] Trial 7 finished with value: 0.8577545013850416 and parameters: {'C': 0.024074754495640303}. Best is trial 1 with value: 0.8642745844875346.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,384] Trial 8 finished with value: 0.8644494459833796 and parameters: {'C': 8.03190765706538}. Best is trial 8 with value: 0.8644494459833796.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,443] Trial 9 finished with value: 0.8643698060941829 and parameters: {'C': 6.886199894681441}. Best is trial 8 with value: 0.8644494459833796.
# C:\Users\HP I3\AppData\Local\Temp\ipykernel_8600\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-03-05 15:16:23,489] A new study created in memory with name: no-name-48c6c99f-57e3-47ce-a37a-a15054bfac26
# [I 2025-03-05 15:16:23,544] Trial 0 finished with value: 0.9169156855955679 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9169156855955679.
# [I 2025-03-05 15:16:23,610] Trial 1 finished with value: 0.9375147160664821 and parameters: {'max_depth': 7}. Best is trial 1 with value: 0.9375147160664821.
# [I 2025-03-05 15:16:23,654] Trial 2 finished with value: 0.9561210180055403 and parameters: {'max_depth': 8}. Best is trial 2 with value: 0.9561210180055403.
# Melhores parâmetros para Logistic Regression: {'C': 8.03190765706538}
#
# Treinando modelo com Optuna: Decision Tree
# [I 2025-03-05 15:16:23,690] Trial 3 finished with value: 0.8989603531855955 and parameters: {'max_depth': 5}. Best is trial 2 with value: 0.9561210180055403.
# [I 2025-03-05 15:16:23,738] Trial 4 finished with value: 0.8788417590027702 and parameters: {'max_depth': 4}. Best is trial 2 with value: 0.9561210180055403.
# [I 2025-03-05 15:16:23,771] Trial 5 finished with value: 0.8788417590027702 and parameters: {'max_depth': 4}. Best is trial 2 with value: 0.9561210180055403.
# [I 2025-03-05 15:16:23,838] Trial 6 finished with value: 0.9375147160664821 and parameters: {'max_depth': 7}. Best is trial 2 with value: 0.9561210180055403.
# [I 2025-03-05 15:16:23,909] Trial 7 finished with value: 0.9806353878116343 and parameters: {'max_depth': 10}. Best is trial 7 with value: 0.9806353878116343.
# [I 2025-03-05 15:16:23,966] Trial 8 finished with value: 0.9686288088642658 and parameters: {'max_depth': 9}. Best is trial 7 with value: 0.9806353878116343.
# [I 2025-03-05 15:16:24,009] Trial 9 finished with value: 0.9169156855955679 and parameters: {'max_depth': 6}. Best is trial 7 with value: 0.9806353878116343.
# [I 2025-03-05 15:16:24,070] A new study created in memory with name: no-name-2c24b8f8-28d0-4cda-9843-9d64dfaaa805
# Melhores parâmetros para Decision Tree: {'max_depth': 10}
#
# Treinando modelo com Optuna: Random Forest
# [I 2025-03-05 15:16:24,871] Trial 0 finished with value: 0.9801298476454293 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 10}. Best is trial 0 with value: 0.9801298476454293.
# [I 2025-03-05 15:16:27,555] Trial 1 finished with value: 0.9346606648199446 and parameters: {'n_estimators': 400, 'max_depth': 5, 'min_samples_split': 9}. Best is trial 0 with value: 0.9801298476454293.
# [I 2025-03-05 15:16:29,071] Trial 2 finished with value: 0.9668074792243767 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 8}. Best is trial 0 with value: 0.9801298476454293.
# [I 2025-03-05 15:16:31,164] Trial 3 finished with value: 0.9867191828254848 and parameters: {'n_estimators': 200, 'max_depth': 9, 'min_samples_split': 6}. Best is trial 3 with value: 0.9867191828254848.
# [I 2025-03-05 15:16:33,149] Trial 4 finished with value: 0.9940304709141276 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 3}. Best is trial 4 with value: 0.9940304709141276.
# [I 2025-03-05 15:16:36,764] Trial 5 finished with value: 0.9559677977839336 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 4}. Best is trial 4 with value: 0.9940304709141276.
# [I 2025-03-05 15:16:38,202] Trial 6 finished with value: 0.9714179362880887 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 4 with value: 0.9940304709141276.
# [I 2025-03-05 15:16:39,452] Trial 7 finished with value: 0.9508189058171745 and parameters: {'n_estimators': 200, 'max_depth': 6, 'min_samples_split': 9}. Best is trial 4 with value: 0.9940304709141276.
# [I 2025-03-05 15:16:40,564] Trial 8 finished with value: 0.9329553324099724 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 10}. Best is trial 4 with value: 0.9940304709141276.
# [I 2025-03-05 15:16:42,250] Trial 9 finished with value: 0.9333015927977839 and parameters: {'n_estimators': 300, 'max_depth': 5, 'min_samples_split': 10}. Best is trial 4 with value: 0.9940304709141276.
# [I 2025-03-05 15:16:43,797] A new study created in memory with name: no-name-b9dbb5fe-1b19-402d-8e14-e51a7a3a0367
# Melhores parâmetros para Random Forest: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 3}
#
# Treinando modelo com Optuna: XGBoost
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:44,821] Trial 0 finished with value: 0.9999930747922438 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.052861500979038495, 'subsample': 0.8266508251832146, 'colsample_bytree': 0.7048011581452595, 'gamma': 0.27820635251588516}. Best is trial 0 with value: 0.9999930747922438.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:45,690] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.05422216747523006, 'subsample': 0.8146613752031634, 'colsample_bytree': 0.8380003902154826, 'gamma': 0.4230076528032978}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:46,688] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.07549397148472439, 'subsample': 0.7870110790629844, 'colsample_bytree': 0.8237478668624023, 'gamma': 0.1419183276449723}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:48,474] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 500, 'max_depth': 9, 'learning_rate': 0.04804737826218851, 'subsample': 0.7520285725821301, 'colsample_bytree': 0.8736845976996053, 'gamma': 0.28349270118879766}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:49,848] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.08201595703017577, 'subsample': 0.8426501684782934, 'colsample_bytree': 0.9817351991923614, 'gamma': 0.18611166567110632}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:51,073] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.09350552215632754, 'subsample': 0.7701510200816846, 'colsample_bytree': 0.7308447705686462, 'gamma': 0.22425875509624665}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:51,943] Trial 6 finished with value: 0.9649809556786704 and parameters: {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.019193697020244954, 'subsample': 0.7449229489995417, 'colsample_bytree': 0.8971059163829708, 'gamma': 0.12422115107334886}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:53,092] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.07538479833604855, 'subsample': 0.9591335543340884, 'colsample_bytree': 0.7545944549448523, 'gamma': 0.4147373027641995}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:54,491] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.05953316150949039, 'subsample': 0.7183873858246793, 'colsample_bytree': 0.7380432276694419, 'gamma': 0.041660355603067634}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:55,455] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.09625945908378528, 'subsample': 0.8533023077333317, 'colsample_bytree': 0.8570391063242347, 'gamma': 0.4509036471834559}. Best is trial 1 with value: 1.0.
# C:\Users\HP I3\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:16:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-05 15:16:56,409] A new study created in memory with name: no-name-159af184-cc06-4e25-a9c8-15c4cd7f0f60
# Melhores parâmetros para XGBoost: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.05422216747523006, 'subsample': 0.8146613752031634, 'colsample_bytree': 0.8380003902154826, 'gamma': 0.4230076528032978}
#
# Treinando modelo com Optuna: LightGBM
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000873 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:16:56,717] Trial 0 finished with value: 0.9997333795013851 and parameters: {'n_estimators': 100, 'learning_rate': 0.0601853848734642, 'num_leaves': 32, 'min_child_samples': 29}. Best is trial 0 with value: 0.9997333795013851.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:16:57,789] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.06002275767188463, 'num_leaves': 24, 'min_child_samples': 29}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000873 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:16:59,146] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.07335827734158051, 'num_leaves': 32, 'min_child_samples': 19}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000625 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:17:00,745] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.0511706924786522, 'num_leaves': 36, 'min_child_samples': 17}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000590 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:17:01,114] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.08911090986162318, 'num_leaves': 33, 'min_child_samples': 14}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000877 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:17:01,573] Trial 5 finished with value: 0.9997177977839335 and parameters: {'n_estimators': 200, 'learning_rate': 0.037486414195288094, 'num_leaves': 26, 'min_child_samples': 30}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001125 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:17:01,854] Trial 6 finished with value: 0.9794615650969528 and parameters: {'n_estimators': 100, 'learning_rate': 0.03255818141370804, 'num_leaves': 25, 'min_child_samples': 25}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001042 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:17:02,246] Trial 7 finished with value: 0.9999878808864266 and parameters: {'n_estimators': 100, 'learning_rate': 0.0641499716632127, 'num_leaves': 37, 'min_child_samples': 19}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:17:03,041] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 300, 'learning_rate': 0.08504290539270874, 'num_leaves': 27, 'min_child_samples': 15}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000701 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-03-05 15:17:04,356] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 400, 'learning_rate': 0.0315373229670307, 'num_leaves': 30, 'min_child_samples': 21}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000786 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3902
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Melhores parâmetros para LightGBM: {'n_estimators': 500, 'learning_rate': 0.06002275767188463, 'num_leaves': 24, 'min_child_samples': 29}
#
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 2        Random Forest  0.792332   0.861272  0.784211  0.820937  0.856996
# 3              XGBoost  0.773163   0.821622  0.800000  0.810667  0.849636
# 0  Logistic Regression  0.785942   0.872727  0.757895  0.811268  0.843688
# 4             LightGBM  0.769968   0.817204  0.800000  0.808511  0.836029
# 1        Decision Tree  0.747604   0.824561  0.742105  0.781163  0.736521

# %%
best_model_name = results_m4_df.sort_values(by='ROC AUC', 
                                         ascending=False).iloc[0]['Model']

best_model_m4 = models_m4[best_model_name]

# %%
# Ajuste de limiar com base no conjunto de treinamento
best_model_m4.fit(X_train_m4, y_train_m4)  # Treine o modelo primeiro!

y_prob_train = best_model_m4.predict_proba(X_train_m4)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_train_m4, y_prob_train)

# Encontrar o melhor limiar com base no F1 Score
best_threshold = 0.5
best_f1 = 0
for threshold in thresholds:
    y_pred_adjusted = (y_prob_train >= threshold).astype(int)
    f1 = f1_score(y_train_m4, y_pred_adjusted)
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

print(f"Melhor limiar: {best_threshold} com F1 Score: {best_f1}")

# Matriz de Confusão com limiar ajustado no conjunto de teste
y_prob_test = best_model_m4.predict_proba(X_test_m4)[:, 1]
y_pred_adjusted = (y_prob_test >= best_threshold).astype(int)
cm_adjusted = confusion_matrix(y_test_m3, y_pred_adjusted)

plt.figure(figsize=(6, 4))
sns.heatmap(cm_adjusted, annot=True, fmt='d', cmap='Blues', xticklabels=['Permanece', 'Migrou'], yticklabels=['Permanece', 'Migrou'])
plt.xlabel('Previsto')
plt.ylabel('Real')
plt.title(f'Matriz de Confusão - Ajuste de Limiar ({best_model_name})')
plt.show()
# Out:
# Melhor limiar: 0.58 com F1 Score: 1.0

# %%
print("ROC AUC: ", roc_auc_score(y_test_m4, y_prob_test))
print("Precision: ", precision_score(y_test_m4, y_pred_adjusted))
print("Accuracy: ", accuracy_score(y_test_m4, y_pred_adjusted))
print("Recall: ", recall_score(y_test_m4, y_pred_adjusted))
print("F1 Score: ", f1_score(y_test_m4, y_pred_adjusted))
print("Houve perda da área abaixo da curva ROC e no Recall. Nas outras métricas, houve melhora")
# Out:
# ROC AUC:  0.8550919982884039
# Precision:  0.8809523809523809
# Accuracy:  0.8019169329073482
# Recall:  0.7789473684210526
# F1 Score:  0.8268156424581006
# Houve perda da área abaixo da curva ROC e no Recall. Nas outras métricas, houve melhora

# %%
# Fazendo previsões de probabilidade no conjunto de teste
y_prob_best = best_model_m4.predict_proba(X_test_m4)[:, 1]

# Ajustando as previsões com o novo limiar
y_pred_adjusted = (y_prob_best >= best_threshold).astype(int)

# Imprimindo o relatório de classificação com o limiar ajustado
print(classification_report(y_test_m4, y_pred_adjusted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77       123
#            1       0.88      0.78      0.83       190
#
#     accuracy                           0.80       313
#    macro avg       0.80      0.81      0.80       313
# weighted avg       0.81      0.80      0.80       313

# %%
# Dicionário para armazenar os resultados
best_models = {}
best_thresholds = {}
y_probs = {}

# Treinando cada modelo e calculando as métricas
for name, model in models.items():
    print(f"Treinando {name}...")
    model.fit(X_train_m4, y_train_m4)
    y_prob = model.predict_proba(X_test_m4)[:, 1]
    y_probs[name] = y_prob
    
    # Encontrar o melhor threshold usando precision-recall
    precision, recall, thresholds = precision_recall_curve(y_test_m4, y_prob)
    fscore = (2 * precision * recall) / (precision + recall)
    ix = np.argmax(fscore)
    best_threshold = thresholds[ix] if ix < len(thresholds) else 0.5
    
    best_models[name] = model
    best_thresholds[name] = best_threshold
    
    print(f"{name} - AUC: {roc_auc_score(y_test_m4, y_prob):.4f}, Melhor Threshold: {best_threshold:.4f}")

# Plotando a curva ROC para todos os modelos
plt.figure(figsize=(12, 8))

for name, y_prob in y_probs.items():
    fpr, tpr, _ = roc_curve(y_test_m4, y_prob)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{name} (AUC = {roc_auc:.3f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falsos Positivos')
plt.ylabel('Taxa de Verdadeiros Positivos')
plt.title('Curva ROC - Comparação de Modelos')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Treinando Logistic Regression...
# Logistic Regression - AUC: 0.8448, Melhor Threshold: 0.3218
# Treinando Decision Tree...
# Decision Tree - AUC: 0.6367, Melhor Threshold: 0.0000
# Treinando Random Forest...
# Random Forest - AUC: 0.8440, Melhor Threshold: 0.5700
# Treinando XGBoost...
# XGBoost - AUC: 0.8315, Melhor Threshold: 0.5170
# Treinando LightGBM...
# [LightGBM] [Info] Number of positive: 760, number of negative: 760
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000291 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4163
# [LightGBM] [Info] Number of data points in the train set: 1520, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# c:\Users\Lapei_Cigets\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:36:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# LightGBM - AUC: 0.8417, Melhor Threshold: 0.6496

# %%
explainer = shap.Explainer(best_model_m4.predict, 
                           X_test_m4)

shap_values = explainer(X_test_m4)
# Out:
# PermutationExplainer explainer: 314it [02:39,  1.83it/s]

# %%
# Recuperando o nome das variáveis
feature_names = preprocessor_m4.get_feature_names_out()

shap.summary_plot(shap_values, 
                  X_test_m4, 
                  feature_names=feature_names,
                  max_display = 10)

# %%
#Gerando o gráfico
shap.summary_plot(shap_values, features= X_test_m4, 
                  feature_names= feature_names, 
                  plot_type="bar", 
                  max_display = 10)

# %%
if 'num__media_vinculos_mes' in feature_names:
    shap.dependence_plot('num__media_vinculos_mes', shap_values.values, X_test_m4, feature_names=feature_names, 
                         interaction_index='num__idade')
