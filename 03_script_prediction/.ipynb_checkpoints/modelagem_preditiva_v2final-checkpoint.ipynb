# %% [markdown]
# # Análise preditiva do Programa Mais Médicos

# %% [markdown]
# ## 1. Análise preditiva para desfecho categórico (churn)

# %%
import pandas as pd
import numpy as np
import shap
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report
import optuna

# %% [markdown]
# ### Carregamento dos dados

# %%
df_completo = pd.read_csv(r"C:\Users\alefs\OneDrive\Documentos\GitHub\sa_maismedicos\01_dados\dados resultantes\df_modelagem.csv")

list(df_completo.columns)
# Out:
# ['Unnamed: 0',
#  'meses_no_local_alocado',
#  'churn',
#  'idade',
#  'anos_formacao',
#  'atuacao_previa_no_municipio',
#  'anos_atuacao_previa_no_municipio',
#  'media_vinculos_mes',
#  'Prorrogado',
#  'm_agente_saude',
#  'm_tec_aux_enf',
#  'm_enfermeiro',
#  'm_dentista',
#  'regiao_destino',
#  'populacao',
#  'porte',
#  'pib_percapita',
#  'variacao_pib',
#  'tx_pop_ocupada_2019',
#  'orcamento_saude',
#  'esgotamento_sanitario',
#  'taxa_homicidio',
#  'ideb_anosfinais',
#  'investimento_infraestrutura',
#  'equipamentos_esportivos',
#  'equipamentos_culturais',
#  'distancia_capital']

# %%
df_completo = df_completo.drop(["Unnamed: 0",
              "meses_no_local_alocado"], 
             axis='columns')

df_completo[['m_agente_saude', 'm_tec_aux_enf', 'm_enfermeiro', 'm_dentista']] = df_completo[['m_agente_saude', 'm_tec_aux_enf', 
                                                                                     'm_enfermeiro', 'm_dentista']].fillna(0)
df_completo['churn'] = df_completo['churn'].map({'permanece': 0, 'migrou': 1})

df_m1 = df_completo[['churn', 'idade', 'anos_formacao', 'atuacao_previa_no_municipio' ,'anos_atuacao_previa_no_municipio',
                   'regiao_destino']]

df_m2 = df_completo[['churn', 'idade', 'anos_formacao', 'atuacao_previa_no_municipio' ,'anos_atuacao_previa_no_municipio',
                   'media_vinculos_mes', 'm_agente_saude', 'm_tec_aux_enf', 'm_enfermeiro', 'm_dentista']]

df_m3 = df_completo.drop(['Prorrogado'], axis='columns')

df_m4 = df_completo

# %%
df_m3.head()
# Out:
#    churn  idade  anos_formacao atuacao_previa_no_municipio  \
# 0      0     35       3.167693                         Não
# 1      1     30       0.084873                         Não
# 2      0     75      42.083504                         Não
# 3      1     37       4.084873                         Não
# 4      1     62      28.914442                         Não
#
#    anos_atuacao_previa_no_municipio  media_vinculos_mes Prorrogado  \
# 0                               0.0            2.343284        NÃO
# 1                               0.0            1.000000        NÃO
# 2                               0.0            1.000000        SIM
# 3                               0.0            1.000000        NÃO
# 4                               0.0            1.000000        SIM
#
#    m_agente_saude  m_tec_aux_enf  m_enfermeiro  ...  variacao_pib  \
# 0        9.473684       8.513158      4.815789  ...            66
# 1       13.375000       1.000000      1.625000  ...            61
# 2        9.411765       3.562500      1.889706  ...           120
# 3        7.771429       1.000000      1.000000  ...           111
# 4        5.328358       2.014925      1.000000  ...           109
#
#   tx_pop_ocupada_2019  orcamento_saude esgotamento_sanitario  taxa_homicidio  \
# 0           11.356216           366.57                   0.0          33.946
# 1           15.844714           683.09                   0.0          64.522
# 2            8.658503           626.30                   0.0          37.161
# 3            3.407013           457.94                   0.0          19.552
# 4           17.059704           614.94                   0.0          24.491
#
#    ideb_anosfinais  investimento_infraestrutura  equipamentos_esportivos  \
# 0              4.3                      103.676                    5.703
# 1              4.7                     5021.768                   18.540
# 2              4.6                     3097.942                    0.000
# 3              5.3                     3190.453                    2.464
# 4              4.0                     4048.908                   12.291
#
#    equipamentos_culturais  distancia_capital
# 0                   9.125              636.0
# 1                   4.635              114.0
# 2                   4.144              147.0
# 3                   4.928              155.0
# 4                   4.097              158.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Pré-processamento e divisão em treino e teste

# %%
def dividir_e_balancear(df):
    y = df['churn']  
    X = df.drop(columns=['churn']) 

    num_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
    cat_features = X.select_dtypes(include=['object', 'category']).columns.tolist()

    num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ])

    cat_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
    ])

    preprocessor = ColumnTransformer([
        ('num', num_pipeline, num_features),
        ('cat', cat_pipeline, cat_features)
    ])
    
    # Divisão dos dados em treino e teste
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

    # Aplicar o pré-processamento
    X_train_processed = preprocessor.fit_transform(X_train)
    X_test_processed = preprocessor.transform(X_test)

    # Aplicação do SMOTE para balanceamento
    smote = SMOTE(sampling_strategy='auto', random_state=42)
    y_train = y_train.astype(int)  # Garantir que y_train seja numérico
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train_processed, y_train)
    
    return X_train_resampled, X_test_processed, y_train_resampled, y_test

# %%
X_train_m1, X_test_m1, y_train_m1, y_test_m1 = dividir_e_balancear(df_m1)
X_train_m2, X_test_m2, y_train_m2, y_test_m2 = dividir_e_balancear(df_m2)
X_train_m3, X_test_m3, y_train_m3, y_test_m3 = dividir_e_balancear(df_m3)
X_train_m4, X_test_m4, y_train_m4, y_test_m4 = dividir_e_balancear(df_m4)

# %% [markdown]
# ## Instanciando modelos e rodando modelos

# %% [markdown]
# No bloco de código abaixo é definida a função para treinar e avaliar os modelos sem Optuna.

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    'LightGBM': lgb.LGBMClassifier()
}

param_grids = {
    'Logistic Regression': {'classifier__C': [0.01, 0.1, 1, 10]},
    'Decision Tree': {'classifier__max_depth': [3, 5, 10]},
    'Random Forest': {
        'classifier__n_estimators': [100, 300, 500],
        'classifier__max_depth': [3, 5, 10],
        'classifier__min_samples_split': [2, 5, 10]
    },
    'XGBoost': {
        'classifier__n_estimators': [100, 300, 500],
        'classifier__max_depth': [3, 6, 9],
        'classifier__learning_rate': [0.01, 0.05, 0.1],
        'classifier__subsample': [0.7, 0.85, 1.0],
        'classifier__colsample_bytree': [0.7, 0.85, 1.0],
        'classifier__gamma': [0, 0.1, 0.5]
    },
    'LightGBM': {
        'classifier__n_estimators': [100, 300, 500],
        'classifier__learning_rate': [0.01, 0.05, 0.1],
        'classifier__num_leaves': [20, 31, 40],
        'classifier__min_child_samples': [10, 20, 30]
    }
}


def treinando_avaliando(x_train, y_train, x_test, y_test):
    # Validação cruzada e otimização de hiperparâmetros
    best_models = {}

    for name, model in models.items():
        print(f"Treinando modelo: {name}")
        pipeline = Pipeline([('classifier', model)])

        param_grid = param_grids.get(name, {})
        cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        grid_search = GridSearchCV(pipeline, param_grid, cv=cv, scoring='roc_auc', n_jobs=-1)
        grid_search.fit(x_train, y_train)

        best_models[name] = grid_search.best_estimator_
        print(f"Melhores parâmetros para {name}: {grid_search.best_params_}\n")

    # Avaliação final no conjunto de teste
    results = []
    for name, model in best_models.items():
        y_pred = model.predict(x_test)
        y_prob = model.predict_proba(x_test)[:, 1]
        results.append({
            'Model': name,
            'Accuracy': accuracy_score(y_test, y_pred),
            'Precision': precision_score(y_test, y_pred),
            'Recall': recall_score(y_test, y_pred),
            'F1 Score': f1_score(y_test, y_pred),
            'ROC AUC': roc_auc_score(y_test, y_prob)
        })
    
    return results, models

# %% [markdown]
# No bloco de código abaixo é definida a função para treinar e avaliar os modelos com Optuna.

# %%
# Definir uma função objetivo para o Optuna
def objective(trial, model_name, x_train, y_train):
    # Definir os hiperparâmetros a serem otimizados para cada modelo
    if model_name == 'Logistic Regression':
        C = trial.suggest_loguniform('C', 0.01, 10)
        model = LogisticRegression(C=C)
    
    elif model_name == 'Decision Tree':
        max_depth = trial.suggest_int('max_depth', 3, 10)
        model = DecisionTreeClassifier(max_depth=max_depth)
    
    elif model_name == 'Random Forest':
        n_estimators = trial.suggest_int('n_estimators', 100, 500, step=100)
        max_depth = trial.suggest_int('max_depth', 3, 10)
        min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split)
    
    elif model_name == 'XGBoost':
        n_estimators = trial.suggest_int('n_estimators', 100, 500, step=100)
        max_depth = trial.suggest_int('max_depth', 3, 9)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.1)
        subsample = trial.suggest_float('subsample', 0.7, 1.0)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.7, 1.0)
        gamma = trial.suggest_float('gamma', 0, 0.5)
        model = xgb.XGBClassifier(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate, subsample=subsample, colsample_bytree=colsample_bytree, gamma=gamma, use_label_encoder=False, eval_metric='logloss')
    
    elif model_name == 'LightGBM':
        n_estimators = trial.suggest_int('n_estimators', 100, 500, step=100)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.1)
        num_leaves = trial.suggest_int('num_leaves', 20, 40)
        min_child_samples = trial.suggest_int('min_child_samples', 10, 30)
        model = lgb.LGBMClassifier(n_estimators=n_estimators, learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples)
    
    # Treinamento do modelo
    model.fit(x_train, y_train)
    
    # Obter a probabilidade da classe positiva (para calcular o ROC AUC)
    y_prob = model.predict_proba(x_train)[:, 1]
    
    # Calcular o ROC AUC para esta combinação de hiperparâmetros
    roc_auc = roc_auc_score(y_train, y_prob)
    
    # Retornar tanto o modelo quanto o ROC AUC
    return model, roc_auc

def treinando_avaliando_optuna(x_train, y_train, x_test, y_test):
    best_models = {}
    best_roc_auc = {}

    for name in models.keys():
        print(f"Treinando modelo com Optuna: {name}")

        # Otimização de hiperparâmetros com Optuna
        study = optuna.create_study(direction="maximize")  # Maximizar o ROC AUC
        study.optimize(lambda trial: objective(trial, name, x_train, y_train)[1], n_trials=10)  # Aqui estamos otimizar apenas o ROC AUC

        # Obter o melhor modelo do estudo
        best_model, best_roc = objective(study.best_trial, name, x_train, y_train)
        best_models[name] = best_model
        best_roc_auc[name] = best_roc
        
        print(f"Melhores parâmetros para {name}: {study.best_params}\n")

    # Avaliação final no conjunto de teste
    results = []
    for name, model in best_models.items():
        y_pred = model.predict(x_test)
        y_prob = model.predict_proba(x_test)[:, 1]
        results.append({
            'Model': name,
            'Accuracy': accuracy_score(y_test, y_pred),
            'Precision': precision_score(y_test, y_pred),
            'Recall': recall_score(y_test, y_pred),
            'F1 Score': f1_score(y_test, y_pred),
            'ROC AUC': roc_auc_score(y_test, y_prob)
        })
    
    return results, models

# %% [markdown]
# ### Modelo 1

# %%
results_m1, models_m1 = treinando_avaliando_optuna(X_train_m1, y_train_m1, X_test_m1, y_test_m1)
results_m1_df = pd.DataFrame(results_m1)
print(results_m1_df.sort_values(by='ROC AUC', ascending=False))
# Out:
# [I 2025-02-25 16:24:52,045] A new study created in memory with name: no-name-f8a4e27c-7248-40ae-951e-478c335d65e5
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,053] Trial 0 finished with value: 0.6893896335164527 and parameters: {'C': 0.05359549104408004}. Best is trial 0 with value: 0.6893896335164527.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,065] Trial 1 finished with value: 0.6897786359844571 and parameters: {'C': 3.6394143736886906}. Best is trial 1 with value: 0.6897786359844571.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,074] Trial 2 finished with value: 0.689759185861057 and parameters: {'C': 1.1512282785559749}. Best is trial 1 with value: 0.6897786359844571.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,084] Trial 3 finished with value: 0.6894706756972868 and parameters: {'C': 0.07611740559202701}. Best is trial 1 with value: 0.6897786359844571.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,093] Trial 4 finished with value: 0.6897991666702685 and parameters: {'C': 7.990476214674092}. Best is trial 4 with value: 0.6897991666702685.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,100] Trial 5 finished with value: 0.6891529903484165 and parameters: {'C': 0.01968407113226427}. Best is trial 4 with value: 0.6897991666702685.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,108] Trial 6 finished with value: 0.6892556437774733 and parameters: {'C': 0.04064133731274164}. Best is trial 4 with value: 0.6897991666702685.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,116] Trial 7 finished with value: 0.6897732331724016 and parameters: {'C': 3.5425440855111185}. Best is trial 4 with value: 0.6897991666702685.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,127] Trial 8 finished with value: 0.6897797165468683 and parameters: {'C': 4.835078373318897}. Best is trial 4 with value: 0.6897991666702685.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,138] Trial 9 finished with value: 0.6897710720475794 and parameters: {'C': 1.7476363563541402}. Best is trial 4 with value: 0.6897991666702685.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:24:52,148] A new study created in memory with name: no-name-8322cc00-34e3-4217-abe6-64a5a0603db8
# [I 2025-02-25 16:24:52,157] Trial 0 finished with value: 0.8709030476182243 and parameters: {'max_depth': 9}. Best is trial 0 with value: 0.8709030476182243.
# [I 2025-02-25 16:24:52,167] Trial 1 finished with value: 0.7685467732245279 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.8709030476182243.
# [I 2025-02-25 16:24:52,178] Trial 2 finished with value: 0.8709030476182243 and parameters: {'max_depth': 9}. Best is trial 0 with value: 0.8709030476182243.
# [I 2025-02-25 16:24:52,186] Trial 3 finished with value: 0.7399032248304598 and parameters: {'max_depth': 4}. Best is trial 0 with value: 0.8709030476182243.
# [I 2025-02-25 16:24:52,194] Trial 4 finished with value: 0.8949385376100553 and parameters: {'max_depth': 10}. Best is trial 4 with value: 0.8949385376100553.
# [I 2025-02-25 16:24:52,201] Trial 5 finished with value: 0.7399032248304598 and parameters: {'max_depth': 4}. Best is trial 4 with value: 0.8949385376100553.
# [I 2025-02-25 16:24:52,208] Trial 6 finished with value: 0.8399249441349234 and parameters: {'max_depth': 8}. Best is trial 4 with value: 0.8949385376100553.
# [I 2025-02-25 16:24:52,215] Trial 7 finished with value: 0.7196648311513176 and parameters: {'max_depth': 3}. Best is trial 4 with value: 0.8949385376100553.
# [I 2025-02-25 16:24:52,225] Trial 8 finished with value: 0.7399032248304598 and parameters: {'max_depth': 4}. Best is trial 4 with value: 0.8949385376100553.
# Treinando modelo com Optuna: Logistic Regression
# Melhores parâmetros para Logistic Regression: {'C': 7.990476214674092}
#
# Treinando modelo com Optuna: Decision Tree
# [I 2025-02-25 16:24:52,233] Trial 9 finished with value: 0.7196648311513176 and parameters: {'max_depth': 3}. Best is trial 4 with value: 0.8949385376100553.
# [I 2025-02-25 16:24:52,241] A new study created in memory with name: no-name-9aad26f0-eeec-40f2-a115-08adc6c6c430
# [I 2025-02-25 16:24:52,404] Trial 0 finished with value: 0.7793383500244208 and parameters: {'n_estimators': 100, 'max_depth': 4, 'min_samples_split': 5}. Best is trial 0 with value: 0.7793383500244208.
# Melhores parâmetros para Decision Tree: {'max_depth': 10}
#
# Treinando modelo com Optuna: Random Forest
# [I 2025-02-25 16:24:53,145] Trial 1 finished with value: 0.7797835417378037 and parameters: {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 8}. Best is trial 1 with value: 0.7797835417378037.
# [I 2025-02-25 16:24:54,031] Trial 2 finished with value: 0.920801798920302 and parameters: {'n_estimators': 400, 'max_depth': 9, 'min_samples_split': 6}. Best is trial 2 with value: 0.920801798920302.
# [I 2025-02-25 16:24:54,320] Trial 3 finished with value: 0.9404215706190758 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 4}. Best is trial 3 with value: 0.9404215706190758.
# [I 2025-02-25 16:24:55,667] Trial 4 finished with value: 0.7810753541003022 and parameters: {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 3}. Best is trial 3 with value: 0.9404215706190758.
# [I 2025-02-25 16:24:56,918] Trial 5 finished with value: 0.9424130471427768 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 5 with value: 0.9424130471427768.
# [I 2025-02-25 16:24:57,390] Trial 6 finished with value: 0.7507585548126089 and parameters: {'n_estimators': 300, 'max_depth': 3, 'min_samples_split': 7}. Best is trial 5 with value: 0.9424130471427768.
# [I 2025-02-25 16:24:58,452] Trial 7 finished with value: 0.9391983739696838 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 6}. Best is trial 5 with value: 0.9424130471427768.
# [I 2025-02-25 16:24:58,838] Trial 8 finished with value: 0.9030713905973782 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 5 with value: 0.9424130471427768.
# [I 2025-02-25 16:24:59,235] Trial 9 finished with value: 0.9122361806873241 and parameters: {'n_estimators': 200, 'max_depth': 9, 'min_samples_split': 10}. Best is trial 5 with value: 0.9424130471427768.
# [I 2025-02-25 16:25:00,294] A new study created in memory with name: no-name-39c1d1ea-c689-4498-9823-3fa9f2737645
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:00,407] Trial 0 finished with value: 0.9511553373299735 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.09747219108818346, 'subsample': 0.9564965138816859, 'colsample_bytree': 0.7894179439304901, 'gamma': 0.06858507734504649}. Best is trial 0 with value: 0.9511553373299735.
# Melhores parâmetros para Random Forest: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 5}
#
# Treinando modelo com Optuna: XGBoost
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:00,501] Trial 1 finished with value: 0.9476418886502046 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.0636603713631026, 'subsample': 0.9683715999046324, 'colsample_bytree': 0.8396333731625522, 'gamma': 0.15001621115580466}. Best is trial 0 with value: 0.9511553373299735.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:00,577] Trial 2 finished with value: 0.9310001469564879 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.07731098223344418, 'subsample': 0.7416304995137115, 'colsample_bytree': 0.8628537020726994, 'gamma': 0.16588603851974998}. Best is trial 0 with value: 0.9511553373299735.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:00,730] Trial 3 finished with value: 0.9538156819861601 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.06586849694289948, 'subsample': 0.7019560741611838, 'colsample_bytree': 0.9325370939521511, 'gamma': 0.17262486201563143}. Best is trial 3 with value: 0.9538156819861601.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:00,971] Trial 4 finished with value: 0.9631647079672028 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.034591365164240245, 'subsample': 0.711809138891097, 'colsample_bytree': 0.8191855300303578, 'gamma': 0.09155274759128124}. Best is trial 4 with value: 0.9631647079672028.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:01,169] Trial 5 finished with value: 0.9533575235238436 and parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.05412394463856224, 'subsample': 0.8444234326089791, 'colsample_bytree': 0.7150806110682398, 'gamma': 0.46567648429233927}. Best is trial 4 with value: 0.9631647079672028.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:01,251] Trial 6 finished with value: 0.9488126780226572 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.08952737645235469, 'subsample': 0.9124484954556749, 'colsample_bytree': 0.8158521457566431, 'gamma': 0.020555426951890443}. Best is trial 4 with value: 0.9631647079672028.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:01,357] Trial 7 finished with value: 0.9600251338816826 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.06491269794956618, 'subsample': 0.8805975933966731, 'colsample_bytree': 0.9785968642916225, 'gamma': 0.10511763048372119}. Best is trial 4 with value: 0.9631647079672028.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:01,592] Trial 8 finished with value: 0.9717049329835193 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.04555357312666396, 'subsample': 0.7998692237468545, 'colsample_bytree': 0.807645599959423, 'gamma': 0.02962723304810505}. Best is trial 8 with value: 0.9717049329835193.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:01,834] Trial 9 finished with value: 0.9576046740807655 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.04815491519784131, 'subsample': 0.9261041954546468, 'colsample_bytree': 0.8335278726413553, 'gamma': 0.03572388492200673}. Best is trial 8 with value: 0.9717049329835193.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:02,063] A new study created in memory with name: no-name-8348258c-1177-4bbc-a4de-4f37c48e1c04
# [I 2025-02-25 16:25:02,207] Trial 0 finished with value: 0.9758418661745065 and parameters: {'n_estimators': 300, 'learning_rate': 0.056737245893361626, 'num_leaves': 28, 'min_child_samples': 20}. Best is trial 0 with value: 0.9758418661745065.
# Melhores parâmetros para XGBoost: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.04555357312666396, 'subsample': 0.7998692237468545, 'colsample_bytree': 0.807645599959423, 'gamma': 0.02962723304810505}
#
# Treinando modelo com Optuna: LightGBM
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:25:02,422] Trial 1 finished with value: 0.9902900661736421 and parameters: {'n_estimators': 400, 'learning_rate': 0.08553504411724047, 'num_leaves': 33, 'min_child_samples': 25}. Best is trial 1 with value: 0.9902900661736421.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:25:02,625] Trial 2 finished with value: 0.985163878095271 and parameters: {'n_estimators': 500, 'learning_rate': 0.061838387755314826, 'num_leaves': 28, 'min_child_samples': 24}. Best is trial 1 with value: 0.9902900661736421.
# [I 2025-02-25 16:25:02,708] Trial 3 finished with value: 0.977160692597283 and parameters: {'n_estimators': 200, 'learning_rate': 0.09655193385379118, 'num_leaves': 28, 'min_child_samples': 24}. Best is trial 1 with value: 0.9902900661736421.
# [I 2025-02-25 16:25:02,764] Trial 4 finished with value: 0.9574669023733472 and parameters: {'n_estimators': 100, 'learning_rate': 0.07056109054796149, 'num_leaves': 40, 'min_child_samples': 28}. Best is trial 1 with value: 0.9902900661736421.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000111 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000138 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000138 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:25:03,007] Trial 5 finished with value: 0.9893915785287927 and parameters: {'n_estimators': 500, 'learning_rate': 0.05120925827283016, 'num_leaves': 35, 'min_child_samples': 18}. Best is trial 1 with value: 0.9902900661736421.
# [I 2025-02-25 16:25:03,156] Trial 6 finished with value: 0.9849126473346849 and parameters: {'n_estimators': 400, 'learning_rate': 0.09137586741147026, 'num_leaves': 24, 'min_child_samples': 27}. Best is trial 1 with value: 0.9902900661736421.
# [I 2025-02-25 16:25:03,202] Trial 7 finished with value: 0.8932031543777904 and parameters: {'n_estimators': 100, 'learning_rate': 0.023689951048665343, 'num_leaves': 30, 'min_child_samples': 30}. Best is trial 1 with value: 0.9902900661736421.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:25:03,277] Trial 8 finished with value: 0.9823722451061329 and parameters: {'n_estimators': 200, 'learning_rate': 0.07877659891100844, 'num_leaves': 28, 'min_child_samples': 11}. Best is trial 1 with value: 0.9902900661736421.
# [I 2025-02-25 16:25:03,379] Trial 9 finished with value: 0.9487402803411119 and parameters: {'n_estimators': 200, 'learning_rate': 0.020339578678512407, 'num_leaves': 36, 'min_child_samples': 14}. Best is trial 1 with value: 0.9902900661736421.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000133 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 628
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Melhores parâmetros para LightGBM: {'n_estimators': 400, 'learning_rate': 0.08553504411724047, 'num_leaves': 33, 'min_child_samples': 25}
#
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 0  Logistic Regression  0.709265   0.878788  0.721992  0.792711  0.710379
# 2        Random Forest  0.712460   0.835556  0.780083  0.806867  0.692975
# 3              XGBoost  0.747604   0.840336  0.829876  0.835073  0.687298
# 1        Decision Tree  0.648562   0.850267  0.659751  0.742991  0.683783
# 4             LightGBM  0.744409   0.820717  0.854772  0.837398  0.663843

# %%
best_model_name = results_m1_df.sort_values(by='ROC AUC', ascending=False).iloc[0]['Model']
best_model_m1 = models_m1[best_model_name]

# %%
# Treinando o modelo
best_model_m1.fit(X_train_m1, y_train_m1)

# Fazendo previsões no conjunto de teste
y_pred = best_model_m1.predict(X_test_m1)

# Imprimindo o relatório de classificação
print(classification_report(y_test_m1, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.67      0.51        72
#            1       0.88      0.72      0.79       241
#
#     accuracy                           0.71       313
#    macro avg       0.65      0.69      0.65       313
# weighted avg       0.77      0.71      0.73       313

# %%
import shap

shap.initjs() #habilitando a visualização dos gráficos
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
explainer = shap.KernelExplainer(best_model_m1.predict, 
                           X_test_m1)

shap_values = explainer(X_test_m1)
# Out:
# Using 313 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/313 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1692\2347216793.py in <module>
#       2                            X_test_m1)
#       3
# ----> 4 shap_values = explainer(X_test_m1)
#
# ~\anaconda3\lib\site-packages\shap\explainers\_kernel.py in __call__(self, X, l1_reg, silent)
#     161             feature_names = getattr(self, "data_feature_names", None)
#     162
# --> 163         v = self.shap_values(X, l1_reg=l1_reg, silent=silent)
#     164         if isinstance(v, list):
#     165             v = np.stack(v, axis=-1) # put outputs at the end
#
# ~\anaconda3\lib\site-packages\shap\explainers\_kernel.py in shap_values(self, X, **kwargs)
#     269                 if self.keep_index:
#     270                     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 271                 explanations.append(self.explain(data, **kwargs))
#     272                 if kwargs.get("gc_collect", False):
#     273                     gc.collect()
#
# ~\anaconda3\lib\site-packages\shap\explainers\_kernel.py in explain(self, incoming_instance, **kwargs)
#     360
#     361             # reserve space for some of our computations
# --> 362             self.allocate()
#     363
#     364             # weight the different subset sizes
#
# ~\anaconda3\lib\site-packages\shap\explainers\_kernel.py in allocate(self)
#     569         self.maskMatrix = np.zeros((self.nsamples, self.M))
#     570         self.kernelWeights = np.zeros(self.nsamples)
# --> 571         self.y = np.zeros((self.nsamples * self.N, self.D))
#     572         self.ey = np.zeros((self.nsamples, self.D))
#     573         self.lastMask = np.zeros(self.nsamples)
#
# KeyboardInterrupt:

# %%
shap.summary_plot(shap_values, features= X_train_m1, 
                  feature_names= df_m1.columns, 
                  plot_type="bar")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1692\1936208299.py in <module>
# ----> 1 shap.summary_plot(shap_values, features= X_train_m1,
#       2                   feature_names= df_m1.columns,
#       3                   plot_type="bar")
#
# ~\anaconda3\lib\site-packages\shap\plots\_beeswarm.py in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale)
#     538                     "provided data matrix."
#     539         if num_features - 1 == features.shape[1]:
# --> 540             assert False, shape_msg + " Perhaps the extra column in the shap_values matrix is the " \
#     541                           "constant offset? Of so just pass shap_values[:,:-1]."
#     542         else:
#
# AssertionError: The shape of the shap_values matrix does not match the shape of the provided data matrix. Perhaps the extra column in the shap_values matrix is the constant offset? Of so just pass shap_values[:,:-1].

# %% [markdown]
# ### Modelo 2

# %%
results_m2, models_m2 = treinando_avaliando_optuna(X_train_m2, y_train_m2, X_test_m2, y_test_m2)
results_m2_df = pd.DataFrame(results_m2)
print(results_m2_df.sort_values(by='ROC AUC', ascending=False))
# Out:
# [I 2025-02-25 16:25:25,500] A new study created in memory with name: no-name-b5374e53-2116-4c8a-bf57-c745531e11ad
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,512] Trial 0 finished with value: 0.7198641949161699 and parameters: {'C': 0.1474814715312944}. Best is trial 0 with value: 0.7198641949161699.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,523] Trial 1 finished with value: 0.7201397383310065 and parameters: {'C': 9.252778370431411}. Best is trial 1 with value: 0.7201397383310065.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,531] Trial 2 finished with value: 0.7199711705948713 and parameters: {'C': 0.2480340655452932}. Best is trial 1 with value: 0.7201397383310065.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,540] Trial 3 finished with value: 0.719987379031038 and parameters: {'C': 0.2949022059909856}. Best is trial 1 with value: 0.7201397383310065.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,548] Trial 4 finished with value: 0.7200565350253499 and parameters: {'C': 0.5995917729996971}. Best is trial 1 with value: 0.7201397383310065.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,555] Trial 5 finished with value: 0.7200608572749945 and parameters: {'C': 0.6257250436742812}. Best is trial 1 with value: 0.7201397383310065.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,563] Trial 6 finished with value: 0.7190245979227268 and parameters: {'C': 0.0479316642864428}. Best is trial 1 with value: 0.7201397383310065.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,571] Trial 7 finished with value: 0.7197723471112245 and parameters: {'C': 0.1227407187253024}. Best is trial 1 with value: 0.7201397383310065.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,579] Trial 8 finished with value: 0.7201408188934176 and parameters: {'C': 2.057694821825745}. Best is trial 8 with value: 0.7201408188934176.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,587] Trial 9 finished with value: 0.7201462217054733 and parameters: {'C': 2.768430349988887}. Best is trial 9 with value: 0.7201462217054733.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:25:25,596] A new study created in memory with name: no-name-8cf7e94b-1e62-4bf3-bfd8-7b440c921ab3
# [I 2025-02-25 16:25:25,609] Trial 0 finished with value: 0.9059737812336566 and parameters: {'max_depth': 7}. Best is trial 0 with value: 0.9059737812336566.
# [I 2025-02-25 16:25:25,624] Trial 1 finished with value: 0.9567153712164108 and parameters: {'max_depth': 9}. Best is trial 1 with value: 0.9567153712164108.
# [I 2025-02-25 16:25:25,639] Trial 2 finished with value: 0.9737428736908986 and parameters: {'max_depth': 10}. Best is trial 2 with value: 0.9737428736908986.
# [I 2025-02-25 16:25:25,651] Trial 3 finished with value: 0.8707976927831398 and parameters: {'max_depth': 6}. Best is trial 2 with value: 0.9737428736908986.
# [I 2025-02-25 16:25:25,659] Trial 4 finished with value: 0.7901331685115469 and parameters: {'max_depth': 4}. Best is trial 2 with value: 0.9737428736908986.
# [I 2025-02-25 16:25:25,674] Trial 5 finished with value: 0.9345714057252518 and parameters: {'max_depth': 8}. Best is trial 2 with value: 0.9737428736908986.
# [I 2025-02-25 16:25:25,688] Trial 6 finished with value: 0.9345714057252518 and parameters: {'max_depth': 8}. Best is trial 2 with value: 0.9737428736908986.
# Treinando modelo com Optuna: Logistic Regression
# Melhores parâmetros para Logistic Regression: {'C': 2.768430349988887}
#
# Treinando modelo com Optuna: Decision Tree
# [I 2025-02-25 16:25:25,700] Trial 7 finished with value: 0.8707976927831398 and parameters: {'max_depth': 6}. Best is trial 2 with value: 0.9737428736908986.
# [I 2025-02-25 16:25:25,716] Trial 8 finished with value: 0.9564565765189466 and parameters: {'max_depth': 9}. Best is trial 2 with value: 0.9737428736908986.
# [I 2025-02-25 16:25:25,727] Trial 9 finished with value: 0.8707976927831398 and parameters: {'max_depth': 6}. Best is trial 2 with value: 0.9737428736908986.
# [I 2025-02-25 16:25:25,743] A new study created in memory with name: no-name-fc00207c-657d-4ea5-8061-b9cbe8699086
# Melhores parâmetros para Decision Tree: {'max_depth': 10}
#
# Treinando modelo com Optuna: Random Forest
# [I 2025-02-25 16:25:27,013] Trial 0 finished with value: 0.9389752378317867 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 8}. Best is trial 0 with value: 0.9389752378317867.
# [I 2025-02-25 16:25:27,433] Trial 1 finished with value: 0.8206374453775701 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 8}. Best is trial 0 with value: 0.9389752378317867.
# [I 2025-02-25 16:25:28,730] Trial 2 finished with value: 0.8852961389343925 and parameters: {'n_estimators': 500, 'max_depth': 5, 'min_samples_split': 3}. Best is trial 0 with value: 0.9389752378317867.
# [I 2025-02-25 16:25:30,367] Trial 3 finished with value: 0.9619317862561106 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 6}. Best is trial 3 with value: 0.9619317862561106.
# [I 2025-02-25 16:25:31,472] Trial 4 finished with value: 0.9142173918681195 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 4}. Best is trial 3 with value: 0.9619317862561106.
# [I 2025-02-25 16:25:31,697] Trial 5 finished with value: 0.8513637778190793 and parameters: {'n_estimators': 100, 'max_depth': 4, 'min_samples_split': 3}. Best is trial 3 with value: 0.9619317862561106.
# [I 2025-02-25 16:25:32,038] Trial 6 finished with value: 0.9650005835037019 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 4}. Best is trial 6 with value: 0.9650005835037019.
# [I 2025-02-25 16:25:32,379] Trial 7 finished with value: 0.9660519707297255 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 2}. Best is trial 7 with value: 0.9660519707297255.
# [I 2025-02-25 16:25:32,790] Trial 8 finished with value: 0.8189885071381953 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 9}. Best is trial 7 with value: 0.9660519707297255.
# [I 2025-02-25 16:25:33,916] Trial 9 finished with value: 0.9106374886000665 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 9}. Best is trial 7 with value: 0.9660519707297255.
# [I 2025-02-25 16:25:34,262] A new study created in memory with name: no-name-7a392217-8321-4916-be73-b867a5759391
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:34,458] Trial 0 finished with value: 0.9996401727170958 and parameters: {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.09728497471287213, 'subsample': 0.8440466891342198, 'colsample_bytree': 0.7926277281892342, 'gamma': 0.3686978060222706}. Best is trial 0 with value: 0.9996401727170958.
# Melhores parâmetros para Random Forest: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 2}
#
# Treinando modelo com Optuna: XGBoost
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:34,685] Trial 1 finished with value: 0.9999524552539105 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.0711344196770899, 'subsample': 0.9086112028548181, 'colsample_bytree': 0.9398163674704284, 'gamma': 0.31979319116932264}. Best is trial 1 with value: 0.9999524552539105.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:34,802] Trial 2 finished with value: 0.9993322124299255 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.0603248519329196, 'subsample': 0.96457493552051, 'colsample_bytree': 0.933678728378275, 'gamma': 0.46142844514682846}. Best is trial 1 with value: 0.9999524552539105.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:34,996] Trial 3 finished with value: 0.9974477115849257 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.028419895765913528, 'subsample': 0.9106720530923434, 'colsample_bytree': 0.8491652230914081, 'gamma': 0.12586653993486757}. Best is trial 1 with value: 0.9999524552539105.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:35,073] Trial 4 finished with value: 0.9718254156923596 and parameters: {'n_estimators': 200, 'max_depth': 4, 'learning_rate': 0.08446456927890864, 'subsample': 0.9989963243058096, 'colsample_bytree': 0.7352188456507351, 'gamma': 0.48092219625232774}. Best is trial 1 with value: 0.9999524552539105.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:35,246] Trial 5 finished with value: 0.9997525512078527 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.0634042411687725, 'subsample': 0.9320340450031108, 'colsample_bytree': 0.7160738443202117, 'gamma': 0.4653738096716473}. Best is trial 1 with value: 0.9999524552539105.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:35,320] Trial 6 finished with value: 0.9068274255384443 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.03274785532348406, 'subsample': 0.8791977511697403, 'colsample_bytree': 0.9018751985795836, 'gamma': 0.4223367327743402}. Best is trial 1 with value: 0.9999524552539105.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:35,486] Trial 7 finished with value: 0.9517831440908364 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.020140702534749387, 'subsample': 0.8246815469158774, 'colsample_bytree': 0.8575130298462368, 'gamma': 0.0702467043755261}. Best is trial 1 with value: 0.9999524552539105.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:35,655] Trial 8 finished with value: 0.9999837915638331 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.09419166750336197, 'subsample': 0.7891808112345361, 'colsample_bytree': 0.7238292404141659, 'gamma': 0.4858020820320244}. Best is trial 8 with value: 0.9999837915638331.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:35,944] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.07283106950950033, 'subsample': 0.8137729149251777, 'colsample_bytree': 0.8312750732941128, 'gamma': 0.12371799089220853}. Best is trial 9 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:25:36,232] A new study created in memory with name: no-name-1ad5752e-903c-48a7-b571-2fb5c38db610
# Melhores parâmetros para XGBoost: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.07283106950950033, 'subsample': 0.8137729149251777, 'colsample_bytree': 0.8312750732941128, 'gamma': 0.12371799089220853}
#
# Treinando modelo com Optuna: LightGBM
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:25:36,427] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 400, 'learning_rate': 0.08208251967948697, 'num_leaves': 30, 'min_child_samples': 15}. Best is trial 0 with value: 1.0.
# [I 2025-02-25 16:25:36,533] Trial 1 finished with value: 0.9994910551043608 and parameters: {'n_estimators': 300, 'learning_rate': 0.05272665510304566, 'num_leaves': 20, 'min_child_samples': 21}. Best is trial 0 with value: 1.0.
# [I 2025-02-25 16:25:36,623] Trial 2 finished with value: 0.9803326835551367 and parameters: {'n_estimators': 200, 'learning_rate': 0.024887140166172064, 'num_leaves': 26, 'min_child_samples': 26}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000173 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000111 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:25:36,697] Trial 3 finished with value: 0.999842237887976 and parameters: {'n_estimators': 200, 'learning_rate': 0.07804333198703786, 'num_leaves': 22, 'min_child_samples': 17}. Best is trial 0 with value: 1.0.
# [I 2025-02-25 16:25:36,756] Trial 4 finished with value: 0.9630010027619176 and parameters: {'n_estimators': 100, 'learning_rate': 0.02290173281009775, 'num_leaves': 35, 'min_child_samples': 20}. Best is trial 0 with value: 1.0.
# [I 2025-02-25 16:25:36,804] Trial 5 finished with value: 0.9589569979382869 and parameters: {'n_estimators': 100, 'learning_rate': 0.029812840437961716, 'num_leaves': 24, 'min_child_samples': 15}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000109 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:25:37,015] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.08979597070267392, 'num_leaves': 25, 'min_child_samples': 15}. Best is trial 0 with value: 1.0.
# [I 2025-02-25 16:25:37,107] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 200, 'learning_rate': 0.09876826661788565, 'num_leaves': 30, 'min_child_samples': 22}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000116 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:25:37,265] Trial 8 finished with value: 0.9944577953933463 and parameters: {'n_estimators': 300, 'learning_rate': 0.020655805608110783, 'num_leaves': 33, 'min_child_samples': 28}. Best is trial 0 with value: 1.0.
# [I 2025-02-25 16:25:37,455] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 400, 'learning_rate': 0.04622362398144904, 'num_leaves': 29, 'min_child_samples': 19}. Best is trial 0 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000135 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1881
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Melhores parâmetros para LightGBM: {'n_estimators': 400, 'learning_rate': 0.08208251967948697, 'num_leaves': 30, 'min_child_samples': 15}
#
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 2        Random Forest  0.734824   0.862385  0.780083  0.819172  0.759221
# 0  Logistic Regression  0.734824   0.876190  0.763485  0.815965  0.752420
# 4             LightGBM  0.747604   0.829268  0.846473  0.837782  0.748847
# 3              XGBoost  0.753994   0.836066  0.846473  0.841237  0.745505
# 1        Decision Tree  0.667732   0.827751  0.717842  0.768889  0.595580

# %%
#Escolhendo o modelo
best_model_name = results_m2_df.sort_values(by='ROC AUC', ascending=False).iloc[0]['Model']
best_model_m2 = models_m2[best_model_name]

# %%
# Treinando o modelo
best_model_m2.fit(X_train_m2, y_train_m2)

# Fazendo previsões no conjunto de teste
y_pred = best_model_m2.predict(X_test_m2)

# Imprimindo o relatório de classificação
print(classification_report(y_test_m2, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.51      0.49        72
#            1       0.85      0.82      0.84       241
#
#     accuracy                           0.75       313
#    macro avg       0.66      0.67      0.66       313
# weighted avg       0.76      0.75      0.76       313

# %%
explainer = shap.Explainer(best_model_m2.predict, 
                           X_test_m2)

shap_values = explainer(X_test_m2)
# Out:
# ExactExplainer explainer: 314it [00:45,  5.39it/s]

# %%
shap.summary_plot(shap_values, features= X_train_m2, 
                  feature_names= df_m2.columns, 
                  plot_type="bar")

# %% [markdown]
# ### Modelo 3

# %%
results_m3, models_m3 = treinando_avaliando_optuna(X_train_m3, y_train_m3, X_test_m3, y_test_m3)
results_m3_df = pd.DataFrame(results_m3)
print(results_m3_df.sort_values(by='ROC AUC', ascending=False))
# Out:
# [I 2025-02-25 16:53:30,571] A new study created in memory with name: no-name-68fd7fdf-75bc-4c38-bed7-11b18ce4855f
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,582] Trial 0 finished with value: 0.7435187866580797 and parameters: {'C': 0.02848782850821025}. Best is trial 0 with value: 0.7435187866580797.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,596] Trial 1 finished with value: 0.7489745462718437 and parameters: {'C': 0.4332650776277547}. Best is trial 1 with value: 0.7489745462718437.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,605] Trial 2 finished with value: 0.7395768949823004 and parameters: {'C': 0.01392075928750085}. Best is trial 1 with value: 0.7489745462718437.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,620] Trial 3 finished with value: 0.7493743543639593 and parameters: {'C': 3.003209522698826}. Best is trial 3 with value: 0.7493743543639593.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,633] Trial 4 finished with value: 0.7493440986164479 and parameters: {'C': 6.189184353063565}. Best is trial 3 with value: 0.7493743543639593.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,646] Trial 5 finished with value: 0.7492781843093692 and parameters: {'C': 0.9580951928177165}. Best is trial 3 with value: 0.7493743543639593.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,658] Trial 6 finished with value: 0.7489475322115655 and parameters: {'C': 0.3840346267456659}. Best is trial 3 with value: 0.7493743543639593.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,671] Trial 7 finished with value: 0.7490653135143779 and parameters: {'C': 0.5159049781204257}. Best is trial 3 with value: 0.7493743543639593.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,685] Trial 8 finished with value: 0.7492943927455361 and parameters: {'C': 1.8317201045596512}. Best is trial 3 with value: 0.7493743543639593.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,693] Trial 9 finished with value: 0.7401992989311076 and parameters: {'C': 0.015098424957718733}. Best is trial 3 with value: 0.7493743543639593.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:53:30,706] A new study created in memory with name: no-name-31a42f94-fa16-4e39-b3f4-3b2ddc68778d
# [I 2025-02-25 16:53:30,745] Trial 0 finished with value: 0.9678246333651739 and parameters: {'max_depth': 9}. Best is trial 0 with value: 0.9678246333651739.
# [I 2025-02-25 16:53:30,770] Trial 1 finished with value: 0.8821706121602172 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9678246333651739.
# Treinando modelo com Optuna: Logistic Regression
# Melhores parâmetros para Logistic Regression: {'C': 3.003209522698826}
#
# Treinando modelo com Optuna: Decision Tree
# [I 2025-02-25 16:53:30,802] Trial 2 finished with value: 0.943553580767718 and parameters: {'max_depth': 8}. Best is trial 0 with value: 0.9678246333651739.
# [I 2025-02-25 16:53:30,832] Trial 3 finished with value: 0.9138937634259879 and parameters: {'max_depth': 7}. Best is trial 0 with value: 0.9678246333651739.
# [I 2025-02-25 16:53:30,865] Trial 4 finished with value: 0.943553580767718 and parameters: {'max_depth': 8}. Best is trial 0 with value: 0.9678246333651739.
# [I 2025-02-25 16:53:30,891] Trial 5 finished with value: 0.8821706121602172 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9678246333651739.
# [I 2025-02-25 16:53:30,916] Trial 6 finished with value: 0.8821706121602172 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9678246333651739.
# [I 2025-02-25 16:53:30,940] Trial 7 finished with value: 0.8479751340977952 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.9678246333651739.
# [I 2025-02-25 16:53:30,977] Trial 8 finished with value: 0.9855966433409261 and parameters: {'max_depth': 10}. Best is trial 8 with value: 0.9855966433409261.
# [I 2025-02-25 16:53:30,998] Trial 9 finished with value: 0.8479751340977952 and parameters: {'max_depth': 5}. Best is trial 8 with value: 0.9855966433409261.
# [I 2025-02-25 16:53:31,033] A new study created in memory with name: no-name-2c796bae-c583-482a-bfd2-83959415c4d6
# Melhores parâmetros para Decision Tree: {'max_depth': 10}
#
# Treinando modelo com Optuna: Random Forest
# [I 2025-02-25 16:53:31,885] Trial 0 finished with value: 0.9721096036064851 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 0 with value: 0.9721096036064851.
# [I 2025-02-25 16:53:32,763] Trial 1 finished with value: 0.8800943114872428 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 6}. Best is trial 0 with value: 0.9721096036064851.
# [I 2025-02-25 16:53:33,289] Trial 2 finished with value: 0.8499017768768289 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 7}. Best is trial 0 with value: 0.9721096036064851.
# [I 2025-02-25 16:53:34,076] Trial 3 finished with value: 0.8514880424963586 and parameters: {'n_estimators': 300, 'max_depth': 3, 'min_samples_split': 5}. Best is trial 0 with value: 0.9721096036064851.
# [I 2025-02-25 16:53:36,526] Trial 4 finished with value: 0.9937575909509382 and parameters: {'n_estimators': 500, 'max_depth': 9, 'min_samples_split': 7}. Best is trial 4 with value: 0.9937575909509382.
# [I 2025-02-25 16:53:37,198] Trial 5 finished with value: 0.9155270335104015 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 2}. Best is trial 4 with value: 0.9937575909509382.
# [I 2025-02-25 16:53:37,536] Trial 6 finished with value: 0.9079933523800467 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 9}. Best is trial 4 with value: 0.9937575909509382.
# [I 2025-02-25 16:53:38,580] Trial 7 finished with value: 0.9111161777481943 and parameters: {'n_estimators': 300, 'max_depth': 5, 'min_samples_split': 9}. Best is trial 4 with value: 0.9937575909509382.
# [I 2025-02-25 16:53:39,495] Trial 8 finished with value: 0.8774939380448736 and parameters: {'n_estimators': 300, 'max_depth': 4, 'min_samples_split': 10}. Best is trial 4 with value: 0.9937575909509382.
# [I 2025-02-25 16:53:40,004] Trial 9 finished with value: 0.8497088964864432 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 9}. Best is trial 4 with value: 0.9937575909509382.
# [I 2025-02-25 16:53:42,469] A new study created in memory with name: no-name-09dd41f9-f98e-4e01-92df-06493a64bb79
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:42,623] Trial 0 finished with value: 0.9944318618954794 and parameters: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.08664633663660322, 'subsample': 0.8121997322099932, 'colsample_bytree': 0.9508978570494733, 'gamma': 0.012504317347796001}. Best is trial 0 with value: 0.9944318618954794.
# Melhores parâmetros para Random Forest: {'n_estimators': 500, 'max_depth': 9, 'min_samples_split': 7}
#
# Treinando modelo com Optuna: XGBoost
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:42,924] Trial 1 finished with value: 0.9987994951612414 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.03262654538481445, 'subsample': 0.8708692953695302, 'colsample_bytree': 0.8141589509733733, 'gamma': 0.15624783204095088}. Best is trial 1 with value: 0.9987994951612414.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:43,609] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.03736804529815515, 'subsample': 0.8874614404413557, 'colsample_bytree': 0.8676443638836878, 'gamma': 0.320258950364962}. Best is trial 2 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:43,820] Trial 3 finished with value: 0.9999794693141887 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.0882770882889313, 'subsample': 0.7663609729369416, 'colsample_bytree': 0.8394197318191944, 'gamma': 0.11390930898923368}. Best is trial 2 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:44,229] Trial 4 finished with value: 0.9999405690673882 and parameters: {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.05887768615700942, 'subsample': 0.9162126701251421, 'colsample_bytree': 0.8170033120412824, 'gamma': 0.12679457406162453}. Best is trial 2 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:45,010] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.024169556345035023, 'subsample': 0.9882955732450109, 'colsample_bytree': 0.7642827062193969, 'gamma': 0.24553906184072194}. Best is trial 2 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:45,089] Trial 6 finished with value: 0.9082613318580055 and parameters: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.013852998877956555, 'subsample': 0.7148656872311038, 'colsample_bytree': 0.8901932147803548, 'gamma': 0.02467424051202388}. Best is trial 2 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:45,348] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.09263292104995136, 'subsample': 0.7913628593629944, 'colsample_bytree': 0.7082425747967547, 'gamma': 0.13886628316727168}. Best is trial 2 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:45,608] Trial 8 finished with value: 0.9991982226909462 and parameters: {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.08019733950866839, 'subsample': 0.8926831716059977, 'colsample_bytree': 0.9839394719749502, 'gamma': 0.35797577602404784}. Best is trial 2 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:45,943] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.09278101185374107, 'subsample': 0.7852302177865191, 'colsample_bytree': 0.7769269212933796, 'gamma': 0.028096169660557058}. Best is trial 2 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:53:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:53:46,502] A new study created in memory with name: no-name-46b4ee29-6685-4930-ab08-435c3a3ecb97
# [I 2025-02-25 16:53:46,608] Trial 0 finished with value: 0.9996779924014851 and parameters: {'n_estimators': 100, 'learning_rate': 0.05116693037651693, 'num_leaves': 39, 'min_child_samples': 30}. Best is trial 0 with value: 0.9996779924014851.
# Melhores parâmetros para XGBoost: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.03736804529815515, 'subsample': 0.8874614404413557, 'colsample_bytree': 0.8676443638836878, 'gamma': 0.320258950364962}
#
# Treinando modelo com Optuna: LightGBM
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000377 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:53:46,791] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 300, 'learning_rate': 0.0610475283932016, 'num_leaves': 22, 'min_child_samples': 25}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000436 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:53:47,170] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 400, 'learning_rate': 0.018635420407752536, 'num_leaves': 36, 'min_child_samples': 11}. Best is trial 1 with value: 1.0.
# [I 2025-02-25 16:53:47,312] Trial 3 finished with value: 0.9999999999999999 and parameters: {'n_estimators': 200, 'learning_rate': 0.05703493426023226, 'num_leaves': 26, 'min_child_samples': 23}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000312 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:53:47,491] Trial 4 finished with value: 0.9999330051305103 and parameters: {'n_estimators': 200, 'learning_rate': 0.032863365390345047, 'num_leaves': 33, 'min_child_samples': 26}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000389 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:53:47,869] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 400, 'learning_rate': 0.0580646871346146, 'num_leaves': 39, 'min_child_samples': 27}. Best is trial 1 with value: 1.0.
# [I 2025-02-25 16:53:47,944] Trial 6 finished with value: 0.999991355500711 and parameters: {'n_estimators': 100, 'learning_rate': 0.09982023911361232, 'num_leaves': 24, 'min_child_samples': 11}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000338 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000321 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:53:48,137] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 200, 'learning_rate': 0.06581713643347534, 'num_leaves': 38, 'min_child_samples': 14}. Best is trial 1 with value: 1.0.
# [I 2025-02-25 16:53:48,236] Trial 8 finished with value: 0.9729130017591555 and parameters: {'n_estimators': 100, 'learning_rate': 0.013715908776419984, 'num_leaves': 36, 'min_child_samples': 20}. Best is trial 1 with value: 1.0.
# [I 2025-02-25 16:53:48,319] Trial 9 finished with value: 0.9999546163787326 and parameters: {'n_estimators': 100, 'learning_rate': 0.08507738229251803, 'num_leaves': 28, 'min_child_samples': 27}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000425 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000317 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5241
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Melhores parâmetros para LightGBM: {'n_estimators': 300, 'learning_rate': 0.0610475283932016, 'num_leaves': 22, 'min_child_samples': 25}
#
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 2        Random Forest  0.741214   0.841880  0.817427  0.829474  0.757550
# 3              XGBoost  0.744409   0.818182  0.858921  0.838057  0.736053
# 0  Logistic Regression  0.709265   0.871287  0.730290  0.794582  0.726948
# 4             LightGBM  0.734824   0.813492  0.850622  0.831643  0.719744
# 1        Decision Tree  0.658147   0.810185  0.726141  0.765864  0.568465

# %%
#Escolhendo o modelo
best_model_name = results_m3_df.sort_values(by='ROC AUC', ascending=False).iloc[0]['Model']
best_model_m3 = models_m3[best_model_name]

# %%
# Treinando o modelo
best_model_m3.fit(X_train_m3, y_train_m3)

# Fazendo previsões no conjunto de teste
y_pred = best_model_m3.predict(X_test_m3)

# Imprimindo o relatório de classificação
print(classification_report(y_test_m3, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.38      0.43        72
#            1       0.83      0.89      0.86       241
#
#     accuracy                           0.77       313
#    macro avg       0.67      0.63      0.65       313
# weighted avg       0.75      0.77      0.76       313

# %%
explainer = shap.Explainer(best_model_m3.predict, 
                           X_test_m3)

shap_values = explainer(X_test_m3)
# Out:
# PermutationExplainer explainer: 314it [01:15,  3.59it/s]

# %%
shap.summary_plot(shap_values, features= X_train_m3, 
                  feature_names= df_m3.columns, 
                  plot_type="bar")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1692\3576019836.py in <module>
# ----> 1 shap.summary_plot(shap_values, features= X_train_m3,
#       2                   feature_names= df_m3.columns,
#       3                   plot_type="bar")
#
# ~\anaconda3\lib\site-packages\shap\plots\_beeswarm.py in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale)
#     873         pl.barh(y_pos, global_shap_values[feature_inds], 0.7, align='center', color=color)
#     874         pl.yticks(y_pos, fontsize=13)
# --> 875         pl.gca().set_yticklabels([feature_names[i] for i in feature_inds])
#     876
#     877     elif multi_class and plot_type == "bar":
#
# ~\anaconda3\lib\site-packages\shap\plots\_beeswarm.py in <listcomp>(.0)
#     873         pl.barh(y_pos, global_shap_values[feature_inds], 0.7, align='center', color=color)
#     874         pl.yticks(y_pos, fontsize=13)
# --> 875         pl.gca().set_yticklabels([feature_names[i] for i in feature_inds])
#     876
#     877     elif multi_class and plot_type == "bar":
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    5051             # GH#44051 exclude bool, which would return a 2d ndarray
#    5052             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5053             return getitem(key)
#    5054
#    5055         if isinstance(key, slice):
#
# IndexError: index 25 is out of bounds for axis 0 with size 24

# %% [markdown]
# ### Modelo 4

# %%
results_m4, models_m4 = treinando_avaliando_optuna(X_train_m4, y_train_m4, X_test_m4, y_test_m4)
results_m4_df = pd.DataFrame(results_m4)
print(results_m4_df.sort_values(by='ROC AUC', ascending=False))
# Out:
# [I 2025-02-25 16:19:32,671] A new study created in memory with name: no-name-15215f6a-3372-4826-a42f-be1983d58862
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,682] Trial 0 finished with value: 0.8572706722394873 and parameters: {'C': 0.022679838984146487}. Best is trial 0 with value: 0.8572706722394873.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,694] Trial 1 finished with value: 0.8594685361837129 and parameters: {'C': 0.2440889251234737}. Best is trial 1 with value: 0.8594685361837129.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,705] Trial 2 finished with value: 0.8587499621803156 and parameters: {'C': 0.07145510483099948}. Best is trial 1 with value: 0.8594685361837129.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,717] Trial 3 finished with value: 0.858980121973885 and parameters: {'C': 0.09562241573984236}. Best is trial 1 with value: 0.8594685361837129.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,730] Trial 4 finished with value: 0.8592535042638992 and parameters: {'C': 0.1544957830670328}. Best is trial 1 with value: 0.8594685361837129.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,743] Trial 5 finished with value: 0.8599299363332628 and parameters: {'C': 1.341739804479155}. Best is trial 5 with value: 0.8599299363332628.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,758] Trial 6 finished with value: 0.8598056716559835 and parameters: {'C': 0.6391710850298712}. Best is trial 5 with value: 0.8599299363332628.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,773] Trial 7 finished with value: 0.8600034145772191 and parameters: {'C': 3.4100587107301297}. Best is trial 7 with value: 0.8600034145772191.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,784] Trial 8 finished with value: 0.8590373917816745 and parameters: {'C': 0.09936376818526448}. Best is trial 7 with value: 0.8600034145772191.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,795] Trial 9 finished with value: 0.8590687280915972 and parameters: {'C': 0.1068508990021425}. Best is trial 7 with value: 0.8600034145772191.
# C:\Users\alefs\AppData\Local\Temp\ipykernel_1692\4280298713.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 0.01, 10)
# [I 2025-02-25 16:19:32,808] A new study created in memory with name: no-name-27a107d7-5589-4a90-88e2-924747a4e8fa
# [I 2025-02-25 16:19:32,828] Trial 0 finished with value: 0.8944166259654825 and parameters: {'max_depth': 4}. Best is trial 0 with value: 0.8944166259654825.
# [I 2025-02-25 16:19:32,852] Trial 1 finished with value: 0.9128531818240757 and parameters: {'max_depth': 5}. Best is trial 1 with value: 0.9128531818240757.
# Treinando modelo com Optuna: Logistic Regression
# Melhores parâmetros para Logistic Regression: {'C': 3.4100587107301297}
#
# Treinando modelo com Optuna: Decision Tree
# [I 2025-02-25 16:19:32,883] Trial 2 finished with value: 0.9475268087534199 and parameters: {'max_depth': 7}. Best is trial 2 with value: 0.9475268087534199.
# [I 2025-02-25 16:19:32,906] Trial 3 finished with value: 0.9128531818240757 and parameters: {'max_depth': 5}. Best is trial 2 with value: 0.9475268087534199.
# [I 2025-02-25 16:19:32,940] Trial 4 finished with value: 0.9767770929413341 and parameters: {'max_depth': 9}. Best is trial 4 with value: 0.9767770929413341.
# [I 2025-02-25 16:19:32,965] Trial 5 finished with value: 0.9314507414819265 and parameters: {'max_depth': 6}. Best is trial 4 with value: 0.9767770929413341.
# [I 2025-02-25 16:19:32,992] Trial 6 finished with value: 0.9314507414819265 and parameters: {'max_depth': 6}. Best is trial 4 with value: 0.9767770929413341.
# [I 2025-02-25 16:19:33,028] Trial 7 finished with value: 0.9845441755524915 and parameters: {'max_depth': 10}. Best is trial 7 with value: 0.9845441755524915.
# [I 2025-02-25 16:19:33,043] Trial 8 finished with value: 0.8676505547607418 and parameters: {'max_depth': 3}. Best is trial 7 with value: 0.9845441755524915.
# [I 2025-02-25 16:19:33,079] Trial 9 finished with value: 0.9845441755524915 and parameters: {'max_depth': 10}. Best is trial 7 with value: 0.9845441755524915.
# [I 2025-02-25 16:19:33,112] A new study created in memory with name: no-name-5e5a6160-b5da-4ee0-8c73-f1f15014dbea
# Melhores parâmetros para Decision Tree: {'max_depth': 10}
#
# Treinando modelo com Optuna: Random Forest
# [I 2025-02-25 16:19:35,488] Trial 0 finished with value: 0.9896114729794563 and parameters: {'n_estimators': 500, 'max_depth': 9, 'min_samples_split': 10}. Best is trial 0 with value: 0.9896114729794563.
# [I 2025-02-25 16:19:36,095] Trial 1 finished with value: 0.9282982006474729 and parameters: {'n_estimators': 200, 'max_depth': 4, 'min_samples_split': 7}. Best is trial 0 with value: 0.9896114729794563.
# [I 2025-02-25 16:19:37,131] Trial 2 finished with value: 0.9972877883480794 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 4}. Best is trial 2 with value: 0.9972877883480794.
# [I 2025-02-25 16:19:39,381] Trial 3 finished with value: 0.9898740496453594 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 4}. Best is trial 2 with value: 0.9972877883480794.
# [I 2025-02-25 16:19:41,335] Trial 4 finished with value: 0.9969625390623312 and parameters: {'n_estimators': 400, 'max_depth': 10, 'min_samples_split': 5}. Best is trial 2 with value: 0.9972877883480794.
# [I 2025-02-25 16:19:43,800] Trial 5 finished with value: 0.9937435436395936 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 9}. Best is trial 2 with value: 0.9972877883480794.
# [I 2025-02-25 16:19:45,783] Trial 6 finished with value: 0.995992194017142 and parameters: {'n_estimators': 400, 'max_depth': 10, 'min_samples_split': 6}. Best is trial 2 with value: 0.9972877883480794.
# [I 2025-02-25 16:19:46,632] Trial 7 finished with value: 0.9804450620458935 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 4}. Best is trial 2 with value: 0.9972877883480794.
# [I 2025-02-25 16:19:48,042] Trial 8 finished with value: 0.9919789852222285 and parameters: {'n_estimators': 300, 'max_depth': 9, 'min_samples_split': 8}. Best is trial 2 with value: 0.9972877883480794.
# [I 2025-02-25 16:19:48,932] Trial 9 finished with value: 0.9862444405063947 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 9}. Best is trial 2 with value: 0.9972877883480794.
# [I 2025-02-25 16:19:49,948] A new study created in memory with name: no-name-a13f1b31-d2c4-4d78-a543-92900f9c13ea
# Melhores parâmetros para Random Forest: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 4}
#
# Treinando modelo com Optuna: XGBoost
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:50,687] Trial 0 finished with value: 1.0 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.02557829205526608, 'subsample': 0.8026018504237671, 'colsample_bytree': 0.8264956198784472, 'gamma': 0.30777520542486}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:51,653] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 500, 'max_depth': 9, 'learning_rate': 0.029509989007167593, 'subsample': 0.7360793440261777, 'colsample_bytree': 0.8380186176022569, 'gamma': 0.1808600309008227}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:51,760] Trial 2 finished with value: 0.9871715630551389 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.07727780242142228, 'subsample': 0.7711425437351802, 'colsample_bytree': 0.8123408697711164, 'gamma': 0.2154011473415438}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:51,948] Trial 3 finished with value: 0.9835981431615527 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.011292165479515552, 'subsample': 0.9982679337000819, 'colsample_bytree': 0.9126656828087245, 'gamma': 0.11191258942527438}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:52,043] Trial 4 finished with value: 0.9880932827918274 and parameters: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.08236438642937968, 'subsample': 0.9843265367215268, 'colsample_bytree': 0.9682473078791786, 'gamma': 0.2768091704693178}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:52,343] Trial 5 finished with value: 0.9878231421890465 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.018627596838863697, 'subsample': 0.7640393519919343, 'colsample_bytree': 0.9025840291267121, 'gamma': 0.3176193943754026}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:52,599] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.07769450374628518, 'subsample': 0.8941211207094193, 'colsample_bytree': 0.7243198445075065, 'gamma': 0.38028949838211007}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:52,881] Trial 7 finished with value: 0.9989831907711325 and parameters: {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.07546668500525625, 'subsample': 0.9451554279580425, 'colsample_bytree': 0.8774746758882402, 'gamma': 0.29936589303811245}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:53,378] Trial 8 finished with value: 0.9993214068058143 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.019159955810935693, 'subsample': 0.8536514267365022, 'colsample_bytree': 0.7999839182301066, 'gamma': 0.17752263058099627}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:53,641] Trial 9 finished with value: 0.9999956777503555 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.09697631023488217, 'subsample': 0.8201329013568576, 'colsample_bytree': 0.7582647780037034, 'gamma': 0.42405764432228343}. Best is trial 0 with value: 1.0.
# C:\Users\alefs\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [16:19:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-02-25 16:19:54,348] A new study created in memory with name: no-name-f60a171a-7498-445a-b8cd-d1dbc341a72b
# Melhores parâmetros para XGBoost: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.02557829205526608, 'subsample': 0.8026018504237671, 'colsample_bytree': 0.8264956198784472, 'gamma': 0.30777520542486}
#
# Treinando modelo com Optuna: LightGBM
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:19:54,681] Trial 0 finished with value: 0.9981976218982456 and parameters: {'n_estimators': 500, 'learning_rate': 0.011394558569523294, 'num_leaves': 24, 'min_child_samples': 28}. Best is trial 0 with value: 0.9981976218982456.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:19:55,077] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.08035399589469346, 'num_leaves': 29, 'min_child_samples': 20}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000429 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:19:55,345] Trial 2 finished with value: 1.0 and parameters: {'n_estimators': 300, 'learning_rate': 0.05383473612042168, 'num_leaves': 32, 'min_child_samples': 27}. Best is trial 1 with value: 1.0.
# [I 2025-02-25 16:19:55,531] Trial 3 finished with value: 1.0 and parameters: {'n_estimators': 200, 'learning_rate': 0.06466603118113022, 'num_leaves': 35, 'min_child_samples': 20}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000575 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000335 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:19:55,822] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 300, 'learning_rate': 0.09145058884377395, 'num_leaves': 34, 'min_child_samples': 16}. Best is trial 1 with value: 1.0.
# [I 2025-02-25 16:19:56,031] Trial 5 finished with value: 1.0 and parameters: {'n_estimators': 300, 'learning_rate': 0.06312761367982624, 'num_leaves': 23, 'min_child_samples': 22}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000335 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:19:56,338] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 400, 'learning_rate': 0.06144722014089016, 'num_leaves': 27, 'min_child_samples': 18}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2025-02-25 16:19:56,767] Trial 7 finished with value: 1.0 and parameters: {'n_estimators': 400, 'learning_rate': 0.06674919131734315, 'num_leaves': 40, 'min_child_samples': 30}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000335 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:19:57,118] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.04304851598924152, 'num_leaves': 23, 'min_child_samples': 14}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [I 2025-02-25 16:19:57,433] Trial 9 finished with value: 0.9995483249121503 and parameters: {'n_estimators': 300, 'learning_rate': 0.014178379553521026, 'num_leaves': 36, 'min_child_samples': 13}. Best is trial 1 with value: 1.0.
# [LightGBM] [Info] Number of positive: 962, number of negative: 962
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000445 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5285
# [LightGBM] [Info] Number of data points in the train set: 1924, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Melhores parâmetros para LightGBM: {'n_estimators': 500, 'learning_rate': 0.08035399589469346, 'num_leaves': 29, 'min_child_samples': 20}
#
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 2        Random Forest  0.753994   0.890476  0.775934  0.829268  0.813912
# 3              XGBoost  0.747604   0.834711  0.838174  0.836439  0.803366
# 0  Logistic Regression  0.709265   0.921348  0.680498  0.782816  0.788843
# 4             LightGBM  0.728435   0.825000  0.821577  0.823285  0.786538
# 1        Decision Tree  0.731629   0.861751  0.775934  0.816594  0.693119

# %%
best_model_name = results_m1_df.sort_values(by='ROC AUC', 
                                         ascending=False).iloc[0]['Model']

best_model = best_models[best_model_name]

# %%
plt.figure(figsize=(8, 6))
for name, model in best_models.items():
    y_prob = model.predict_proba(X_test_m1)[:, 1]
    fpr, tpr, _ = roc_curve(y_test_m1, y_prob)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f}')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curvas ROC para os Modelos')
plt.legend()
plt.show()

# %%
y_pred_best = best_model.predict(X_test_processed)
cm = confusion_matrix(y_test, y_pred_best)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Permanece', 'Migrou'], yticklabels=['Permanece', 'Migrou'])
plt.xlabel('Previsto')
plt.ylabel('Real')
plt.title(f'Matriz de Confusão - {best_model_name}')
plt.show()

# %%
# Ajuste de limiar
y_prob_best = best_model.predict_proba(X_test_processed)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_test, y_prob_best)

# Encontrar o melhor limiar com base no F1 Score
best_threshold = 0.5
best_f1 = 0
for threshold in thresholds:
    y_pred_adjusted = (y_prob_best >= threshold).astype(int)
    f1 = f1_score(y_test, y_pred_adjusted)
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

print(f"Melhor limiar: {best_threshold} com F1 Score: {best_f1}")

# Matriz de Confusão com limiar ajustado
y_pred_adjusted = (y_prob_best >= best_threshold).astype(int)
cm_adjusted = confusion_matrix(y_test, y_pred_adjusted)
plt.figure(figsize=(6, 4))
sns.heatmap(cm_adjusted, annot=True, fmt='d', cmap='Blues', xticklabels=['Permanece', 'Migrou'], yticklabels=['Permanece', 'Migrou'])
plt.xlabel('Previsto')
plt.ylabel('Real')
plt.title(f'Matriz de Confusão - Ajuste de Limiar ({best_model_name})')
plt.show()
# Out:
# Melhor limiar: 0.3833902915577487 com F1 Score: 0.8732394366197183

# %%
print("ROC AUC: ", roc_auc_score(y_test, y_pred_adjusted))
print("Precision: ", precision_score(y_test, y_pred_adjusted))
print("Accuracy: ", accuracy_score(y_test, y_pred_adjusted))
print("Recall: ", recall_score(y_test, y_pred_adjusted))
print("F1 Score: ", f1_score(y_test, y_pred))
print("Houve perda da área abaixo da curva ROC e no Recall. Nas outras métricas, houve melhora")
# Out:
# ROC AUC:  0.7617853849700323
# Precision:  0.9367816091954023
# Accuracy:  0.7156549520766773
# Recall:  0.6763485477178424
# F1 Score:  0.8281573498964804
# Houve perda da área abaixo da curva ROC e no Recall. Nas outras métricas, houve melhora

# %%
shap.summary_plot(shap_values, features= X_transformed, 
                  feature_names= X_transformed.columns, 
                  plot_type="bar")

# %%
# Criar explicação do SHAP para o melhor modelo
explainer = shap.Explainer(best_model.predict, 
                           X_test_processed)

shap_values = explainer(X_test_processed)

# Gerar gráfico de resumo do SHAP
feature_names = preprocessor.get_feature_names_out()

shap.summary_plot(shap_values, 
                  X_test_processed, 
                  feature_names=feature_names)
# Out:
# PermutationExplainer explainer: 314it [04:39,  1.08it/s]

# %% [markdown]
# O código abaixo é usado para treinar o modelo com a base completa

# %%
# Criar explicação do SHAP para o melhor modelo
explainer_full = shap.Explainer(best_model.predict, preprocessor.transform(X))
shap_values_full = explainer_full(preprocessor.transform(X))

# Gerar gráfico de resumo do SHAP para a base completa
shap.summary_plot(shap_values_full, preprocessor.transform(X), feature_names=feature_names)
explainer = shap.Explainer(best_model.predict, X_test_processed)
shap_values = explainer(X_test_processed)
# Out:
# PermutationExplainer explainer: 1565it [25:27,  1.02it/s]
# PermutationExplainer explainer: 314it [05:03,  1.00s/it]
