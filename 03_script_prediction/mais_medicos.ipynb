# %% [markdown]
# # Predictive analysis of Mais Médicos retention

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import pycaret
from pycaret.classification import *
import shap

# %% [markdown]
# Reading dataframe

# %%
df_original = pd.read_excel("database_mm_0312.xlsx")
df_original.head()
# Out:
#     ano   competen  codufmun  ibge_aloc municipio_destino uf_destino     cnes  \
# 0  2019 2019-06-01    240580     240580       JOAO CAMARA         RN  2474689
# 1  2019 2019-06-01    220020     220020       AGUA BRANCA         PI  2368455
# 2  2019 2019-10-01    520310     520310            BALIZA         GO  2500132
# 3  2019 2019-09-01    290195     290195          APUAREMA         BA  7050062
# 4  2019 2019-09-01    130340     130340         PARINTINS         AM  9640347
#
#    tp_unid                                     fantasia  \
# 0        2                          PSF 2 SAO FRANCISCO
# 1        2  POSTO DE SAUDE OTACIANA MARIA DO NASCIMENTO
# 2        2                     ESF MARLENE NERY RIBEIRO
# 3        2                                 USF OTACIANO
# 4        2   UNIDADE BASICA DE SAUDE DO BAIRRO DA UNIAO
#
#                          nomeprof  ...  orcamento_saude esgotamento_sanitario  \
# 0  MARLIO EVERTON MACEDO DE PAIVA  ...           617.07                 35.43
# 1            ANA MARIA REGO COSTA  ...           997.20                 35.77
# 2            RUBENS NOVAIS XAVIER  ...           785.85                  0.00
# 3          HERALDO ROCHA DE JESUS  ...           578.33                  0.00
# 4              KEDMA TAVARES BUAS  ...           469.07                  0.00
#
#   taxa_homicidio mortes_armasdefogo feminicidio ideb_anosiniciais  \
# 0         51.495                0.0      28.412               4.2
# 1         11.487                0.0      21.671               6.0
# 2         38.926                0.0       0.000               6.2
# 3         40.928                0.0      26.688               4.2
# 4         21.002                0.0       7.180               5.0
#
#    ideb_anosfinais investimento_infraestrutura  equipamentos_esportivos  \
# 0              3.0                    1076.540                    2.878
# 1              4.9                    3447.022                   46.112
# 2              4.9                    2781.115                   20.032
# 3              3.4                    4027.146                   13.587
# 4              4.4                    3341.453                    1.767
#
#    equpamentos_culturais
# 0                  5.756
# 1                 34.584
# 2                 20.032
# 3                 27.174
# 4                  1.767
#
# [5 rows x 51 columns]

# %% [markdown]
# Selecting only features which will be useful

# %%
df_original.columns
# Out:
# Index(['ano', 'competen', 'codufmun', 'ibge_aloc', 'municipio_destino',
#        'uf_destino', 'cnes', 'tp_unid', 'fantasia', 'nomeprof', 'cns_prof',
#        'cpf_prof', 'data_nascimento', 'data_formacao', 'participou_pmmb',
#        'sexo', 'ch_total', 'atuacao_previa_no_municipio',
#        'anos_atuacao_mesmo_municipio', 'media_vinculos',
#        'meses_no_local_alocado', 'churn', 'idade_em_anos', 'Prorrogado',
#        'anos_formacao', 'leitos_hospitalar_municipal_estadual',
#        'leitos_hospitalares_cirurgico_clinico_complementar',
#        'leitos_instalacao_fisica_urgencia',
#        'leitos_instalacao_fisica_ambulatorial',
#        'leitos_instalacao_fisical_cirurgico',
#        'leitos_instalacao_fisica_obstetrico', 'agente_saude', 'dentista',
#        'enfermeiro', 'tec_aux_enf', 'populacao', 'porte', 'pib_percapita',
#        'tx_pop_ocupada', 'cobertura_saude', 'vagas_medicina_milhab',
#        'orcamento_saude', 'esgotamento_sanitario', 'taxa_homicidio',
#        'mortes_armasdefogo', 'feminicidio', 'ideb_anosiniciais',
#        'ideb_anosfinais', 'investimento_infraestrutura',
#        'equipamentos_esportivos', 'equpamentos_culturais'],
#       dtype='object')

# %%
df_churn = df_original.loc[:,('uf_destino', 
                        'participou_pmmb',
                        'sexo',
                         'atuacao_previa_no_municipio',
                         'anos_atuacao_mesmo_municipio', 
                         'media_vinculos', 
                         'idade_em_anos',
                         'anos_formacao',
                         'leitos_hospitalares_cirurgico_clinico_complementar',
                         'leitos_instalacao_fisica_urgencia',
                        'leitos_instalacao_fisica_obstetrico', 
                        'agente_saude', 
                        'dentista',
                        'enfermeiro', 
                        'tec_aux_enf', 
                        'porte', 
                        'pib_percapita',
                        'tx_pop_ocupada', 
                        'cobertura_saude', 
                        'vagas_medicina_milhab',
                        'orcamento_saude', 
                        'esgotamento_sanitario', 
                        'taxa_homicidio',
                        'ideb_anosiniciais',
                        'ideb_anosfinais', 
                        'investimento_infraestrutura',
                        'equipamentos_esportivos', 
                        'equpamentos_culturais',
                        'churn')]

df_churn.head()
# Out:
#   uf_destino participou_pmmb    sexo atuacao_previa_no_municipio  \
# 0         RN             NÃO    Male                         Não
# 1         PI             NÃO  Female                         Não
# 2         GO             NaN    Male                         Não
# 3         BA             NaN    Male                         Não
# 4         AM             NaN  Female                         Não
#
#    anos_atuacao_mesmo_municipio  media_vinculos  idade_em_anos  anos_formacao  \
# 0                           0.0        1.000000      54.094456       0.084873
# 1                           0.0        1.000000      44.654346       0.084873
# 2                           0.0        1.278689      48.147844       1.333333
# 3                           0.0        1.000000      48.533881       0.917180
# 4                           0.0        1.209677      44.060233       0.999316
#
#    leitos_hospitalares_cirurgico_clinico_complementar  \
# 0                                                0.0
# 1                                                0.0
# 2                                                2.0
# 3                                                0.0
# 4                                                0.0
#
#    leitos_instalacao_fisica_urgencia  ...  vagas_medicina_milhab  \
# 0                                7.0  ...                    0.0
# 1                                4.0  ...                    0.0
# 2                                8.0  ...                    0.0
# 3                                5.0  ...                    0.0
# 4                               10.0  ...                    0.0
#
#    orcamento_saude  esgotamento_sanitario  taxa_homicidio  ideb_anosiniciais  \
# 0           617.07                  35.43          51.495                4.2
# 1           997.20                  35.77          11.487                6.0
# 2           785.85                   0.00          38.926                6.2
# 3           578.33                   0.00          40.928                4.2
# 4           469.07                   0.00          21.002                5.0
#
#   ideb_anosfinais  investimento_infraestrutura  equipamentos_esportivos  \
# 0             3.0                     1076.540                    2.878
# 1             4.9                     3447.022                   46.112
# 2             4.9                     2781.115                   20.032
# 3             3.4                     4027.146                   13.587
# 4             4.4                     3341.453                    1.767
#
#    equpamentos_culturais      churn
# 0                  5.756     migrou
# 1                 34.584  permanece
# 2                 20.032     migrou
# 3                 27.174     migrou
# 4                  1.767     migrou
#
# [5 rows x 29 columns]

# %%
clf1 = setup(data = df_churn, 
             target = 'churn',
             train_size=0.7,
             normalize=True,
             normalize_method='minmax',
             fix_imbalance=True,
             remove_multicollinearity=True,
             remove_outliers=True,
             fold=10)

clf1
# Out:
# <style type="text/css">
# #T_8e2e3_row11_col1, #T_8e2e3_row17_col1, #T_8e2e3_row19_col1, #T_8e2e3_row21_col1, #T_8e2e3_row23_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8e2e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e2e3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8e2e3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e2e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e2e3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8e2e3_row0_col1" class="data row0 col1" >7909</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e2e3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8e2e3_row1_col1" class="data row1 col1" >churn</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8e2e3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8e2e3_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8e2e3_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_8e2e3_row3_col1" class="data row3 col1" >migrou: 0, permanece: 1</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8e2e3_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_8e2e3_row4_col1" class="data row4 col1" >(1647, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8e2e3_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_8e2e3_row5_col1" class="data row5 col1" >(1625, 33)</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8e2e3_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_8e2e3_row6_col1" class="data row6 col1" >(1130, 33)</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8e2e3_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_8e2e3_row7_col1" class="data row7 col1" >(495, 33)</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8e2e3_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_8e2e3_row8_col1" class="data row8 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8e2e3_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_8e2e3_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8e2e3_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_8e2e3_row10_col1" class="data row10 col1" >33.2%</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8e2e3_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_8e2e3_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8e2e3_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_8e2e3_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8e2e3_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_8e2e3_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8e2e3_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_8e2e3_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8e2e3_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_8e2e3_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8e2e3_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_8e2e3_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8e2e3_row17_col0" class="data row17 col0" >Remove multicollinearity</td>
#       <td id="T_8e2e3_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8e2e3_row18_col0" class="data row18 col0" >Multicollinearity threshold</td>
#       <td id="T_8e2e3_row18_col1" class="data row18 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8e2e3_row19_col0" class="data row19 col0" >Remove outliers</td>
#       <td id="T_8e2e3_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_8e2e3_row20_col0" class="data row20 col0" >Outliers threshold</td>
#       <td id="T_8e2e3_row20_col1" class="data row20 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_8e2e3_row21_col0" class="data row21 col0" >Fix imbalance</td>
#       <td id="T_8e2e3_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_8e2e3_row22_col0" class="data row22 col0" >Fix imbalance method</td>
#       <td id="T_8e2e3_row22_col1" class="data row22 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_8e2e3_row23_col0" class="data row23 col0" >Normalize</td>
#       <td id="T_8e2e3_row23_col1" class="data row23 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_8e2e3_row24_col0" class="data row24 col0" >Normalize method</td>
#       <td id="T_8e2e3_row24_col1" class="data row24 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_8e2e3_row25_col0" class="data row25 col0" >Fold Generator</td>
#       <td id="T_8e2e3_row25_col1" class="data row25 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_8e2e3_row26_col0" class="data row26 col0" >Fold Number</td>
#       <td id="T_8e2e3_row26_col1" class="data row26 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_8e2e3_row27_col0" class="data row27 col0" >CPU Jobs</td>
#       <td id="T_8e2e3_row27_col1" class="data row27 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_8e2e3_row28_col0" class="data row28 col0" >Use GPU</td>
#       <td id="T_8e2e3_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_8e2e3_row29_col0" class="data row29 col0" >Log Experiment</td>
#       <td id="T_8e2e3_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8e2e3_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_8e2e3_row30_col0" class="data

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_3f4ce th {
#   text-align: left;
# }
# #T_3f4ce_row0_col0, #T_3f4ce_row1_col0, #T_3f4ce_row1_col1, #T_3f4ce_row1_col2, #T_3f4ce_row1_col3, #T_3f4ce_row1_col4, #T_3f4ce_row1_col5, #T_3f4ce_row1_col6, #T_3f4ce_row1_col7, #T_3f4ce_row2_col0, #T_3f4ce_row2_col1, #T_3f4ce_row2_col2, #T_3f4ce_row2_col3, #T_3f4ce_row2_col4, #T_3f4ce_row2_col5, #T_3f4ce_row2_col6, #T_3f4ce_row2_col7, #T_3f4ce_row3_col0, #T_3f4ce_row3_col1, #T_3f4ce_row3_col2, #T_3f4ce_row3_col3, #T_3f4ce_row3_col4, #T_3f4ce_row3_col5, #T_3f4ce_row3_col6, #T_3f4ce_row3_col7, #T_3f4ce_row4_col0, #T_3f4ce_row4_col1, #T_3f4ce_row4_col2, #T_3f4ce_row4_col3, #T_3f4ce_row4_col4, #T_3f4ce_row4_col5, #T_3f4ce_row4_col6, #T_3f4ce_row4_col7, #T_3f4ce_row5_col0, #T_3f4ce_row5_col1, #T_3f4ce_row5_col2, #T_3f4ce_row5_col3, #T_3f4ce_row5_col4, #T_3f4ce_row5_col5, #T_3f4ce_row5_col6, #T_3f4ce_row5_col7, #T_3f4ce_row6_col0, #T_3f4ce_row6_col1, #T_3f4ce_row6_col2, #T_3f4ce_row6_col3, #T_3f4ce_row6_col4, #T_3f4ce_row6_col5, #T_3f4ce_row6_col6, #T_3f4ce_row6_col7, #T_3f4ce_row7_col0, #T_3f4ce_row7_col1, #T_3f4ce_row7_col2, #T_3f4ce_row7_col3, #T_3f4ce_row7_col4, #T_3f4ce_row7_col5, #T_3f4ce_row7_col6, #T_3f4ce_row7_col7, #T_3f4ce_row8_col0, #T_3f4ce_row8_col1, #T_3f4ce_row8_col2, #T_3f4ce_row8_col3, #T_3f4ce_row8_col4, #T_3f4ce_row8_col5, #T_3f4ce_row8_col6, #T_3f4ce_row8_col7, #T_3f4ce_row9_col0, #T_3f4ce_row9_col1, #T_3f4ce_row9_col2, #T_3f4ce_row9_col3, #T_3f4ce_row9_col4, #T_3f4ce_row9_col5, #T_3f4ce_row9_col6, #T_3f4ce_row9_col7, #T_3f4ce_row10_col0, #T_3f4ce_row10_col1, #T_3f4ce_row10_col2, #T_3f4ce_row10_col3, #T_3f4ce_row10_col4, #T_3f4ce_row10_col5, #T_3f4ce_row10_col6, #T_3f4ce_row10_col7, #T_3f4ce_row11_col0, #T_3f4ce_row11_col1, #T_3f4ce_row11_col2, #T_3f4ce_row11_col3, #T_3f4ce_row11_col4, #T_3f4ce_row11_col5, #T_3f4ce_row11_col6, #T_3f4ce_row11_col7, #T_3f4ce_row12_col0, #T_3f4ce_row12_col1, #T_3f4ce_row12_col2, #T_3f4ce_row12_col3, #T_3f4ce_row12_col4, #T_3f4ce_row12_col5, #T_3f4ce_row12_col6, #T_3f4ce_row12_col7, #T_3f4ce_row13_col0, #T_3f4ce_row13_col1, #T_3f4ce_row13_col2, #T_3f4ce_row13_col3, #T_3f4ce_row13_col4, #T_3f4ce_row13_col5, #T_3f4ce_row13_col6, #T_3f4ce_row13_col7 {
#   text-align: left;
# }
# #T_3f4ce_row0_col1, #T_3f4ce_row0_col2, #T_3f4ce_row0_col3, #T_3f4ce_row0_col4, #T_3f4ce_row0_col5, #T_3f4ce_row0_col6, #T_3f4ce_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3f4ce_row0_col8, #T_3f4ce_row2_col8, #T_3f4ce_row3_col8, #T_3f4ce_row4_col8, #T_3f4ce_row5_col8, #T_3f4ce_row6_col8, #T_3f4ce_row7_col8, #T_3f4ce_row8_col8, #T_3f4ce_row9_col8, #T_3f4ce_row10_col8, #T_3f4ce_row11_col8, #T_3f4ce_row12_col8, #T_3f4ce_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3f4ce_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3f4ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f4ce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3f4ce_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3f4ce_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3f4ce_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3f4ce_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3f4ce_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3f4ce_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3f4ce_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3f4ce_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f4ce_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_3f4ce_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_3f4ce_row0_col1" class="data row0 col1" >0.6190</td>
#       <td id="T_3f4ce_row0_col2" class="data row0 col2" >0.6625</td>
#       <td id="T_3f4ce_row0_col3" class="data row0 col3" >0.6190</td>
#       <td id="T_3f4ce_row0_col4" class="data row0 col4" >0.6201</td>
#       <td id="T_3f4ce_row0_col5" class="data row0 col5" >0.6182</td>
#       <td id="T_3f4ce_row0_col6" class="data row0 col6" >0.2375</td>
#       <td id="T_3f4ce_row0_col7" class="data row0 col7" >0.2387</td>
#       <td id="T_3f4ce_row0_col8" class="data row0 col8" >0.2690</td>
#     </tr>
#     <tr>
#       <th id="T_3f4ce_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_3f4ce_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_3f4ce_row1_col1" class="data row1 col1" >0.6138</td>
#       <td id="T_3f4ce_row1_col2" class="data row1 col2" >0.6495</td>
#       <td id="T_3f4ce_row1_col3" class="data row1 col3" >0.6138</td>
#       <td id="T_3f4ce_row1_col4" class="data row1 col4" >0.6159</td>
#       <td id="T_3f4ce_row1_col5" class="data row1 col5" >0.6110</td>
#       <td id="T_3f4ce_row1_col6" class="data row1 col6" >0.2254</td>
#       <td id="T_3f4ce_row1_col7" class="data row1 col7" >0.2284</td>
#       <td id="T_3f4ce_row1_col8" class="data row1 col8" >0.1110</td>
#     </tr>
#     <tr>
#       <th id="T_3f4ce_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_3f4ce_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3f4ce_row2_col1" class="data row2 col1" >0.6137</td>
#       <td id="T_3f4ce_row2_col2" class="data row2 col2" >0.6521</td>
#       <td id="T_3f4ce_row2_col3" class="data row2 col3" >0.6137</td>
#       <td id="T_3f4ce_row2_col4" class="data row2 col4" >0.6144</td>
#       <td id="T_3f4ce_row2_col5" class="data row2 col5" >0.6120</td>
#       <td id="T_3f4ce_row2_col6" class="data row2 col6" >0.2260</td>
#       <td id="T_3f4ce_row2_col7" class="data row2 col7" >0.2272</td>
#       <td id="T_3f4ce_row2_col8" class="data row2 col8" >0.3110</td>
#     </tr>
#     <tr>
#       <th id="T_3f4ce_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_3f4ce_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_3f4ce_row3_col1" class="data row3 col1" >0.6112</td>
#       <td id="T_3f4ce_row3_col2" class="data row3 col2" >0.6484</td>
#       <td id="T_3f4ce_row3_col3" class="data row3 col3" >0.6112</td>
#       <td id="T_3f4ce_row3_col4" class="data row3 col4" >0.6129</td>
#       <td id="T_3f4ce_row3_col5" class="data row3 col5" >0.6083</td>
#       <td id="T_3f4ce_row3_col6" class="data row3 col6" >0.2201</td>
#       <td id="T_3f4ce_row3_col7" class="data row3 col7" >0.2228</td>
#       <td id="T_3f4ce_row3_col8" class="data row3 col8" >0.9100</td>
#     </tr>
#     <tr>
#       <th id="T_3f4ce_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_3f4ce_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_3f4ce_row4_col1" class="data row4 col1" >0.6112</td>
#       <td id="T_3f4ce_row4_col2" class="data row4 col2" >0.6373</td>
#       <td id="T_3f4ce_row4_col3" class="data row4 col3" >0.6112</td>
#       <td id="T_3f4ce_row4_col4" class="data row4 col4" >0.6121</td>
#       <td id="T_3f4ce_row4_col5" class="data row4 col5" >0.6100</td>
#       <td id="T_3f4ce_row4_col6" class="data row4 col6" >0.2215</td>
#       <td id="T_3f4ce_row4_col7" class="data row4 col7" >0.2227</td>
#       <td id="T_3f4ce_row4_col8" class="data row4 col8" >0.2180</td>
#     </tr>
#     <tr>
#       <th id="T_3f4ce_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_3f4ce_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_3f4ce_row5_col1" class="data row5 col1" >0.6103</td>
#       <td id="T_3f4ce_row5_col2" class="data row5 col2" >0.6510</td>
#       <td id="T_3f4ce_row5_col3" class="data row5 col3" >0.6103</td>
#       <td id="T_3f4ce_row5_col4" class="data row5 col4" >0.6123</td>
#       <td id="T_3f4ce_row5_col5" class="data row5 col5" >0.6070</td>
#       <td id="T_3f4ce_row5_col6" class="data row5 col6" >0.2181</td>
#       <td id="T_3f4ce_row5_col7" class="data row5 col7" >0.2211</td>
#       <td id="T_

# %%
tuned_model = tune_model(best_model)
tuned_model
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              23:40:39
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_52ec4_row10_col0, #T_52ec4_row10_col1, #T_52ec4_row10_col2, #T_52ec4_row10_col3, #T_52ec4_row10_col4, #T_52ec4_row10_col5, #T_52ec4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_52ec4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52ec4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_52ec4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_52ec4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_52ec4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_52ec4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_52ec4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_52ec4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52ec4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52ec4_row0_col0" class="data row0 col0" >0.6293</td>
#       <td id="T_52ec4_row0_col1" class="data row0 col1" >0.6464</td>
#       <td id="T_52ec4_row0_col2" class="data row0 col2" >0.6293</td>
#       <td id="T_52ec4_row0_col3" class="data row0 col3" >0.6293</td>
#       <td id="T_52ec4_row0_col4" class="data row0 col4" >0.6289</td>
#       <td id="T_52ec4_row0_col5" class="data row0 col5" >0.2577</td>
#       <td id="T_52ec4_row0_col6" class="data row0 col6" >0.2581</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52ec4_row1_col0" class="data row1 col0" >0.5948</td>
#       <td id="T_52ec4_row1_col1" class="data row1 col1" >0.6331</td>
#       <td id="T_52ec4_row1_col2" class="data row1 col2" >0.5948</td>
#       <td id="T_52ec4_row1_col3" class="data row1 col3" >0.5947</td>
#       <td id="T_52ec4_row1_col4" class="data row1 col4" >0.5947</td>
#       <td id="T_52ec4_row1_col5" class="data row1 col5" >0.1892</td>
#       <td id="T_52ec4_row1_col6" class="data row1 col6" >0.1892</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_52ec4_row2_col0" class="data row2 col0" >0.5913</td>
#       <td id="T_52ec4_row2_col1" class="data row2 col1" >0.6111</td>
#       <td id="T_52ec4_row2_col2" class="data row2 col2" >0.5913</td>
#       <td id="T_52ec4_row2_col3" class="data row2 col3" >0.5940</td>
#       <td id="T_52ec4_row2_col4" class="data row2 col4" >0.5904</td>
#       <td id="T_52ec4_row2_col5" class="data row2 col5" >0.1846</td>
#       <td id="T_52ec4_row2_col6" class="data row2 col6" >0.1860</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_52ec4_row3_col0" class="data row3 col0" >0.6000</td>
#       <td id="T_52ec4_row3_col1" class="data row3 col1" >0.6877</td>
#       <td id="T_52ec4_row3_col2" class="data row3 col2" >0.6000</td>
#       <td id="T_52ec4_row3_col3" class="data row3 col3" >0.6013</td>
#       <td id="T_52ec4_row3_col4" class="data row3 col4" >0.5960</td>
#       <td id="T_52ec4_row3_col5" class="data row3 col5" >0.1958</td>
#       <td id="T_52ec4_row3_col6" class="data row3 col6" >0.1989</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_52ec4_row4_col0" class="data row4 col0" >0.6174</td>
#       <td id="T_52ec4_row4_col1" class="data row4 col1" >0.7052</td>
#       <td id="T_52ec4_row4_col2" class="data row4 col2" >0.6174</td>
#       <td id="T_52ec4_row4_col3" class="data row4 col3" >0.6179</td>
#       <td id="T_52ec4_row4_col4" class="data row4 col4" >0.6174</td>
#       <td id="T_52ec4_row4_col5" class="data row4 col5" >0.2350</td>
#       <td id="T_52ec4_row4_col6" class="data row4 col6" >0.2351</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_52ec4_row5_col0" class="data row5 col0" >0.6087</td>
#       <td id="T_52ec4_row5_col1" class="data row5 col1" >0.6371</td>
#       <td id="T_52ec4_row5_col2" class="data row5 col2" >0.6087</td>
#       <td id="T_52ec4_row5_col3" class="data row5 col3" >0.6108</td>
#       <td id="T_52ec4_row5_col4" class="data row5 col4" >0.6041</td>
#       <td id="T_52ec4_row5_col5" class="data row5 col5" >0.2129</td>
#       <td id="T_52ec4_row5_col6" class="data row5 col6" >0.2170</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_52ec4_row6_col0" class="data row6 col0" >0.7391</td>
#       <td id="T_52ec4_row6_col1" class="data row6 col1" >0.7739</td>
#       <td id="T_52ec4_row6_col2" class="data row6 col2" >0.7391</td>
#       <td id="T_52ec4_row6_col3" class="data row6 col3" >0.7392</td>
#       <td id="T_52ec4_row6_col4" class="data row6 col4" >0.7389</td>
#       <td id="T_52ec4_row6_col5" class="data row6 col5" >0.4774</td>
#       <td id="T_52ec4_row6_col6" class="data row6 col6" >0.4777</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_52ec4_row7_col0" class="data row7 col0" >0.6870</td>
#       <td id="T_52ec4_row7_col1" class="data row7 col1" >0.7149</td>
#       <td id="T_52ec4_row7_col2" class="data row7 col2" >0.6870</td>
#       <td id="T_52ec4_row7_col3" class="data row7 col3" >0.6875</td>
#       <td id="T_52ec4_row7_col4" class="data row7 col4" >0.6870</td>
#       <td id="T_52ec4_row7_col5" class="data row7 col5" >0.3741</td>
#       <td id="T_52ec4_row7_col6" class="data row7 col6" >0.3743</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_52ec4_row8_col0" class="data row8 col0" >0.6957</td>
#       <td id="T_52ec4_row8_col1" class="data row8 col1" >0.7381</td>
#       <td id="T_52ec4_row8_col2" class="data row8 col2" >0.6957</td>
#       <td id="T_52ec4_row8_col3" class="data row8 col3" >0.6958</td>
#       <td id="T_52ec4_row8_col4" class="data row8 col4" >0.6957</td>
#       <td id="T_52ec4_row8_col5" class="data row8 col5" >0.3914</td>
#       <td id="T_52ec4_row8_col6" class="data row8 col6" >0.3914</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_52ec4_row9_col0" class="data row9 col0" >0.5826</td>
#       <td id="T_52ec4_row9_col1" class="data row9 col1" >0.6824</td>
#       <td id="T_52ec4_row9_col2" class="data row9 col2" >0.5826</td>
#       <td id="T_52ec4_row9_col3" class="data row9 col3" >0.5828</td>
#       <td id="T_52ec4_row9_col4" class="data row9 col4" >0.5820</td>
#       <td id="T_52ec4_row9_col5" class="data row9 col5" >0.1646</td>
#       <td id="T_52ec4_row9_col6" class="data row9 col6" >0.1650</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_52ec4_row10_col0" class="data row10 col0" >0.6346</td>
#       <td id="T_52ec4_row10_col1" class="data row10 col1" >0.6830</td>
#       <td id="T_52ec4_row10_col2" class="data row10 col2" >0.6346</td>
#       <td id="T_52ec4_row10_col3" class="data row10 col3" >0.6353</td>
#       <td id="T_52ec4_row10_col4" class="data row10 col4" >0.6335</td>
#       <td id="T_52ec4_row10_col5" class="data row10 col5" >0.2683</td>
#       <td id="T_52ec4_row10_col6" class="data row10 col6" >0.2693</td>
#     </tr>
#     <tr>
#       <th id="T_52ec4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_52ec4_row11_col0" class="data row11 col0" >0.0507</td>
#       <td id="T_52ec4_row11_col1" class="data row11 col1" >0.0489</td>
#       <td id="T_52ec4_row11_col2" class="data row11 col2" >0.0507</td>
#       <td id="T_52ec4_row11_col3" class="data row11 col3" >0.0504</td>
#       <td id="T_52ec4_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight='balanced_subsample', criterion='gini',
#                        max_depth=7, max_features='sqrt', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.001,
#                        min_samples_leaf=6, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, monotonic_cst=None,
#                        n_estimators=150, n_jobs=-1, oob_score=False,
#                        random_state=7909, verbose=0, warm_start=False)

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
avaliacao = predict_model(tuned_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_012a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_012a1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_012a1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_012a1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_012a1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_012a1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_012a1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_012a1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_012a1_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_012a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_012a1_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_012a1_row0_col1" class="data row0 col1" >0.6747</td>
#       <td id="T_012a1_row0_col2" class="data row0 col2" >0.7152</td>
#       <td id="T_012a1_row0_col3" class="data row0 col3" >0.6747</td>
#       <td id="T_012a1_row0_col4" class="data row0 col4" >0.6758</td>
#       <td id="T_012a1_row0_col5" class="data row0 col5" >0.6735</td>
#       <td id="T_012a1_row0_col6" class="data row0 col6" >0.3477</td>
#       <td id="T_012a1_row0_col7" class="data row0 col7" >0.3495</td>
#     </tr>
#   </tbody>
# </table>

# %%
testar = avaliacao.loc[:,('churn',
             'prediction_label',
             'prediction_score')]

# %%
# Out:
#           churn prediction_label  prediction_score
# 657   permanece        permanece            0.6108
# 638      migrou           migrou            0.5263
# 1393  permanece           migrou            0.5555
# 1041     migrou        permanece            0.6221
# 5        migrou           migrou            0.7211
# ...         ...              ...               ...
# 1051  permanece        permanece            0.6479
# 1440  permanece        permanece            0.5534
# 1476  permanece        permanece            0.5829
# 366   permanece        permanece            0.5240
# 1372     migrou        permanece            0.7269
#
# [495 rows x 3 columns]

# %%
final_model = finalize_model(tuned_model)
save_model(final_model, 'final_model_classification_pmm')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['anos_atuacao_municipio',
#                                               'media_vinculos', 'idade_em_anos',
#                                               'anos_formacao',
#                                               'leitos_hospitalares_cirurgico_clinico_complementar',
#                                               'leitos_insta...
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=MinMaxScaler(clip=False,
#                                                               copy=True,
#                                                               feature_range=(0,
#                                                                              1)))),
#                  ('actual_estimator',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=850,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'final_model_classification_pmm.pkl')

# %% [markdown]
# # Fazendo teste de usando regressão

# %%
df_original = pd.read_excel("database_mm_0312.xlsx")
df_original.head()
# Out:
#     ano   competen  codufmun  ibge_aloc municipio_destino uf_destino     cnes  \
# 0  2019 2019-06-01    240580     240580       JOAO CAMARA         RN  2474689
# 1  2019 2019-06-01    220020     220020       AGUA BRANCA         PI  2368455
# 2  2019 2019-10-01    520310     520310            BALIZA         GO  2500132
# 3  2019 2019-09-01    290195     290195          APUAREMA         BA  7050062
# 4  2019 2019-09-01    130340     130340         PARINTINS         AM  9640347
#
#    tp_unid                                     fantasia  \
# 0        2                          PSF 2 SAO FRANCISCO
# 1        2  POSTO DE SAUDE OTACIANA MARIA DO NASCIMENTO
# 2        2                     ESF MARLENE NERY RIBEIRO
# 3        2                                 USF OTACIANO
# 4        2   UNIDADE BASICA DE SAUDE DO BAIRRO DA UNIAO
#
#                          nomeprof  ...  orcamento_saude esgotamento_sanitario  \
# 0  MARLIO EVERTON MACEDO DE PAIVA  ...           617.07                 35.43
# 1            ANA MARIA REGO COSTA  ...           997.20                 35.77
# 2            RUBENS NOVAIS XAVIER  ...           785.85                  0.00
# 3          HERALDO ROCHA DE JESUS  ...           578.33                  0.00
# 4              KEDMA TAVARES BUAS  ...           469.07                  0.00
#
#   taxa_homicidio mortes_armasdefogo feminicidio ideb_anosiniciais  \
# 0         51.495                0.0      28.412               4.2
# 1         11.487                0.0      21.671               6.0
# 2         38.926                0.0       0.000               6.2
# 3         40.928                0.0      26.688               4.2
# 4         21.002                0.0       7.180               5.0
#
#    ideb_anosfinais investimento_infraestrutura  equipamentos_esportivos  \
# 0              3.0                    1076.540                    2.878
# 1              4.9                    3447.022                   46.112
# 2              4.9                    2781.115                   20.032
# 3              3.4                    4027.146                   13.587
# 4              4.4                    3341.453                    1.767
#
#    equpamentos_culturais
# 0                  5.756
# 1                 34.584
# 2                 20.032
# 3                 27.174
# 4                  1.767
#
# [5 rows x 51 columns]

# %%
df_media = df_original.loc[:,('uf_destino', 
                        'participou_pmmb',
                        'sexo',
                         'atuacao_previa_no_municipio',
                         'anos_atuacao_mesmo_municipio', 
                         'media_vinculos', 
                         'idade_em_anos',
                         'Prorrogado', 
                         'anos_formacao',
                         'leitos_hospitalares_cirurgico_clinico_complementar',
                         'leitos_instalacao_fisica_urgencia',
                        'leitos_instalacao_fisica_obstetrico', 
                        'agente_saude', 
                        'dentista',
                        'enfermeiro', 
                        'tec_aux_enf', 
                        'populacao', 
                        'porte', 
                        'pib_percapita',
                        'tx_pop_ocupada', 
                        'cobertura_saude', 
                        'vagas_medicina_milhab',
                        'orcamento_saude', 
                        'esgotamento_sanitario', 
                        'taxa_homicidio',
                        'ideb_anosiniciais',
                        'ideb_anosfinais', 
                        'investimento_infraestrutura',
                        'equipamentos_esportivos', 
                        'equpamentos_culturais',
                        'meses_no_local_alocado')]

# %%
from pycaret.regression import *

# %%
reg_mm = setup(data = df_media, 
                target = 'meses_no_local_alocado',
                train_size=0.7,
                normalize=True,
                normalize_method='minmax',
                remove_multicollinearity=True,
                remove_outliers=True,
                fold=10)

reg_mm
# Out:
# <style type="text/css">
# #T_80d0c_row10_col1, #T_80d0c_row16_col1, #T_80d0c_row18_col1, #T_80d0c_row20_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_80d0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80d0c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_80d0c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80d0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80d0c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_80d0c_row0_col1" class="data row0 col1" >8664</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80d0c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_80d0c_row1_col1" class="data row1 col1" >meses_no_local_alocado</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80d0c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_80d0c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80d0c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_80d0c_row3_col1" class="data row3 col1" >(1647, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80d0c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_80d0c_row4_col1" class="data row4 col1" >(1589, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80d0c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_80d0c_row5_col1" class="data row5 col1" >(1094, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80d0c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_80d0c_row6_col1" class="data row6 col1" >(495, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80d0c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_80d0c_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80d0c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_80d0c_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_80d0c_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_80d0c_row9_col1" class="data row9 col1" >33.2%</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_80d0c_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_80d0c_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_80d0c_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_80d0c_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_80d0c_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_80d0c_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_80d0c_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_80d0c_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_80d0c_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_80d0c_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_80d0c_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_80d0c_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_80d0c_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_80d0c_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_80d0c_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_80d0c_row17_col1" class="data row17 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_80d0c_row18_col0" class="data row18 col0" >Remove outliers</td>
#       <td id="T_80d0c_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_80d0c_row19_col0" class="data row19 col0" >Outliers threshold</td>
#       <td id="T_80d0c_row19_col1" class="data row19 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_80d0c_row20_col0" class="data row20 col0" >Normalize</td>
#       <td id="T_80d0c_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_80d0c_row21_col0" class="data row21 col0" >Normalize method</td>
#       <td id="T_80d0c_row21_col1" class="data row21 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_80d0c_row22_col0" class="data row22 col0" >Fold Generator</td>
#       <td id="T_80d0c_row22_col1" class="data row22 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_80d0c_row23_col0" class="data row23 col0" >Fold Number</td>
#       <td id="T_80d0c_row23_col1" class="data row23 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_80d0c_row24_col0" class="data row24 col0" >CPU Jobs</td>
#       <td id="T_80d0c_row24_col1" class="data row24 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_80d0c_row25_col0" class="data row25 col0" >Use GPU</td>
#       <td id="T_80d0c_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_80d0c_row26_col0" class="data row26 col0" >Log Experiment</td>
#       <td id="T_80d0c_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_80d0c_row27_col0" class="data row27 col0" >Experiment Name</td>
#       <td id="T_80d0c_row27_col1" class="data row27 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_80d0c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_80d0c_row28_col0" class="data row28 col0" >USI</td>
#       <td id="T_80d0c_row28_col1" class="data row28 col1" >8a95</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_reg = compare_models()
# Out:
# <style type="text/css">
# #T_9cc5e th {
#   text-align: left;
# }
# #T_9cc5e_row0_col0, #T_9cc5e_row0_col6, #T_9cc5e_row1_col0, #T_9cc5e_row1_col1, #T_9cc5e_row1_col2, #T_9cc5e_row1_col3, #T_9cc5e_row1_col4, #T_9cc5e_row1_col5, #T_9cc5e_row1_col6, #T_9cc5e_row2_col0, #T_9cc5e_row2_col1, #T_9cc5e_row2_col2, #T_9cc5e_row2_col3, #T_9cc5e_row2_col4, #T_9cc5e_row2_col5, #T_9cc5e_row3_col0, #T_9cc5e_row3_col1, #T_9cc5e_row3_col2, #T_9cc5e_row3_col3, #T_9cc5e_row3_col4, #T_9cc5e_row3_col5, #T_9cc5e_row3_col6, #T_9cc5e_row4_col0, #T_9cc5e_row4_col1, #T_9cc5e_row4_col2, #T_9cc5e_row4_col3, #T_9cc5e_row4_col4, #T_9cc5e_row4_col5, #T_9cc5e_row4_col6, #T_9cc5e_row5_col0, #T_9cc5e_row5_col1, #T_9cc5e_row5_col2, #T_9cc5e_row5_col3, #T_9cc5e_row5_col4, #T_9cc5e_row5_col5, #T_9cc5e_row5_col6, #T_9cc5e_row6_col0, #T_9cc5e_row6_col1, #T_9cc5e_row6_col2, #T_9cc5e_row6_col3, #T_9cc5e_row6_col4, #T_9cc5e_row6_col5, #T_9cc5e_row6_col6, #T_9cc5e_row7_col0, #T_9cc5e_row7_col1, #T_9cc5e_row7_col2, #T_9cc5e_row7_col3, #T_9cc5e_row7_col4, #T_9cc5e_row7_col5, #T_9cc5e_row7_col6, #T_9cc5e_row8_col0, #T_9cc5e_row8_col1, #T_9cc5e_row8_col2, #T_9cc5e_row8_col3, #T_9cc5e_row8_col4, #T_9cc5e_row8_col5, #T_9cc5e_row8_col6, #T_9cc5e_row9_col0, #T_9cc5e_row9_col1, #T_9cc5e_row9_col2, #T_9cc5e_row9_col3, #T_9cc5e_row9_col4, #T_9cc5e_row9_col5, #T_9cc5e_row9_col6, #T_9cc5e_row10_col0, #T_9cc5e_row10_col1, #T_9cc5e_row10_col2, #T_9cc5e_row10_col3, #T_9cc5e_row10_col4, #T_9cc5e_row10_col5, #T_9cc5e_row10_col6, #T_9cc5e_row11_col0, #T_9cc5e_row11_col1, #T_9cc5e_row11_col2, #T_9cc5e_row11_col3, #T_9cc5e_row11_col4, #T_9cc5e_row11_col5, #T_9cc5e_row11_col6, #T_9cc5e_row12_col0, #T_9cc5e_row12_col1, #T_9cc5e_row12_col2, #T_9cc5e_row12_col3, #T_9cc5e_row12_col4, #T_9cc5e_row12_col5, #T_9cc5e_row12_col6, #T_9cc5e_row13_col0, #T_9cc5e_row13_col1, #T_9cc5e_row13_col2, #T_9cc5e_row13_col3, #T_9cc5e_row13_col4, #T_9cc5e_row13_col5, #T_9cc5e_row13_col6, #T_9cc5e_row14_col0, #T_9cc5e_row14_col1, #T_9cc5e_row14_col2, #T_9cc5e_row14_col3, #T_9cc5e_row14_col4, #T_9cc5e_row14_col5, #T_9cc5e_row14_col6, #T_9cc5e_row15_col0, #T_9cc5e_row15_col1, #T_9cc5e_row15_col2, #T_9cc5e_row15_col3, #T_9cc5e_row15_col4, #T_9cc5e_row15_col5, #T_9cc5e_row15_col6, #T_9cc5e_row16_col0, #T_9cc5e_row16_col1, #T_9cc5e_row16_col2, #T_9cc5e_row16_col3, #T_9cc5e_row16_col4, #T_9cc5e_row16_col5, #T_9cc5e_row16_col6, #T_9cc5e_row17_col0, #T_9cc5e_row17_col1, #T_9cc5e_row17_col2, #T_9cc5e_row17_col3, #T_9cc5e_row17_col4, #T_9cc5e_row17_col5, #T_9cc5e_row17_col6 {
#   text-align: left;
# }
# #T_9cc5e_row0_col1, #T_9cc5e_row0_col2, #T_9cc5e_row0_col3, #T_9cc5e_row0_col4, #T_9cc5e_row0_col5, #T_9cc5e_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9cc5e_row0_col7, #T_9cc5e_row1_col7, #T_9cc5e_row2_col7, #T_9cc5e_row3_col7, #T_9cc5e_row4_col7, #T_9cc5e_row5_col7, #T_9cc5e_row6_col7, #T_9cc5e_row7_col7, #T_9cc5e_row9_col7, #T_9cc5e_row10_col7, #T_9cc5e_row11_col7, #T_9cc5e_row12_col7, #T_9cc5e_row13_col7, #T_9cc5e_row14_col7, #T_9cc5e_row15_col7, #T_9cc5e_row16_col7, #T_9cc5e_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9cc5e_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9cc5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cc5e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9cc5e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9cc5e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9cc5e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9cc5e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9cc5e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9cc5e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9cc5e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cc5e_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_9cc5e_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_9cc5e_row0_col1" class="data row0 col1" >11.3476</td>
#       <td id="T_9cc5e_row0_col2" class="data row0 col2" >212.7985</td>
#       <td id="T_9cc5e_row0_col3" class="data row0 col3" >14.5522</td>
#       <td id="T_9cc5e_row0_col4" class="data row0 col4" >0.5014</td>
#       <td id="T_9cc5e_row0_col5" class="data row0 col5" >0.6086</td>
#       <td id="T_9cc5e_row0_col6" class="data row0 col6" >0.7652</td>
#       <td id="T_9cc5e_row0_col7" class="data row0 col7" >0.2460</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_9cc5e_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_9cc5e_row1_col1" class="data row1 col1" >11.4977</td>
#       <td id="T_9cc5e_row1_col2" class="data row1 col2" >217.6128</td>
#       <td id="T_9cc5e_row1_col3" class="data row1 col3" >14.7153</td>
#       <td id="T_9cc5e_row1_col4" class="data row1 col4" >0.4904</td>
#       <td id="T_9cc5e_row1_col5" class="data row1 col5" >0.6100</td>
#       <td id="T_9cc5e_row1_col6" class="data row1 col6" >0.7724</td>
#       <td id="T_9cc5e_row1_col7" class="data row1 col7" >0.3610</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_9cc5e_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9cc5e_row2_col1" class="data row2 col1" >11.7192</td>
#       <td id="T_9cc5e_row2_col2" class="data row2 col2" >227.8801</td>
#       <td id="T_9cc5e_row2_col3" class="data row2 col3" >15.0650</td>
#       <td id="T_9cc5e_row2_col4" class="data row2 col4" >0.4654</td>
#       <td id="T_9cc5e_row2_col5" class="data row2 col5" >0.6222</td>
#       <td id="T_9cc5e_row2_col6" class="data row2 col6" >0.7602</td>
#       <td id="T_9cc5e_row2_col7" class="data row2 col7" >0.2560</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_9cc5e_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_9cc5e_row3_col1" class="data row3 col1" >11.8589</td>
#       <td id="T_9cc5e_row3_col2" class="data row3 col2" >229.3569</td>
#       <td id="T_9cc5e_row3_col3" class="data row3 col3" >15.1155</td>
#       <td id="T_9cc5e_row3_col4" class="data row3 col4" >0.4639</td>
#       <td id="T_9cc5e_row3_col5" class="data row3 col5" >0.6292</td>
#       <td id="T_9cc5e_row3_col6" class="data row3 col6" >0.8400</td>
#       <td id="T_9cc5e_row3_col7" class="data row3 col7" >0.0810</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_9cc5e_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_9cc5e_row4_col1" class="data row4 col1" >11.9133</td>
#       <td id="T_9cc5e_row4_col2" class="data row4 col2" >230.9964</td>
#       <td id="T_9cc5e_row4_col3" class="data row4 col3" >15.1679</td>
#       <td id="T_9cc5e_row4_col4" class="data row4 col4" >0.4597</td>
#       <td id="T_9cc5e_row4_col5" class="data row4 col5" >0.6323</td>
#       <td id="T_9cc5e_row4_col6" class="data row4 col6" >0.8328</td>
#       <td id="T_9cc5e_row4_col7" class="data row4 col7" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_9cc5e_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_9cc5e_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_9cc5e_row5_col1" class="data row5 col1" >11.8510</td>
#       <td id="T_9cc5e_row5_col2" class="data row5 col2" >232.2269</td>
#       <td id="T_9cc5e_row5_col3" class="data row5 col3" >15.1930</td>
#       <td id="T_9cc5e_row5_col4" class="data row5 col4" >0.4585</td>
#       <td id="T_9cc5e_row5_col5" class="data row5 col5" >0.6309</td>
#       <td id="T_9cc5e_row5_col6" class="data row5 col6" >0.8436</td>
#       <td id="T_9cc5e_row5_col7" class="data row5 col7" >0.0820</td>
#     </tr>
#     <tr>
#       <t

# %%
tuned_model_reg = tune_model(best_model_reg)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
